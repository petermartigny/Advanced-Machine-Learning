# %% [markdown]
# # Machine Learning: From Theory to Practise -- Project
# ## Master Data Science -- Université Paris Saclay
# ## Natural Naguage Processing Applied to Sentiment Analysis
# #### Authors: Johann Faouzi, Hicham Janati, Mélanie Finas, Peter Martigny
#
# #### Amazon Book Reviews - https://archive.ics.uci.edu/ml/datasets/Amazon+book+reviews

# %% [markdown]
# ### The goal of this project is to predict how much a reader would rate a book based on her/his textual review
# ### We will follow this methodology:
#
# #### Short exploration
#
# #### Cleaning of reviews
#
# #### Bag of words model to create features
#
# #### Classification & Regression algorithms to predict the ratings
#
# #### Using [word2vec](https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) to embed words into contextual vectors, then use average vectors or clustering to create features for ML algorithms

# %%
## Some useful package imports
import pandas as pd
from bs4 import BeautifulSoup
import time
import numpy as np

import nltk
from nltk.stem.porter import *
import string
from nltk.tokenize import TweetTokenizer
token = TweetTokenizer()
stemmer = PorterStemmer() 
from nltk.corpus import stopwords # Import the stop word list
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load the datasets

# %%
# Load the first book
data = pd.read_csv('Paula_Hawkins-The-Girl-On-The-Train.csv', sep = '\t', header = None)
# Rename columns
data.columns = ['rating', 'tail', 'title', 'review']
data['book'] = 'Paula_Hawkins-The-Girl-On-The-Train'

# Load the second book
data1 = pd.read_csv('Andy-Weir-The-Martian.csv', sep = '\t', header = None)
# Rename columns
data1.columns = ['rating', 'tail', 'title', 'review']
data1['book'] = 'Andy-Weir-The-Martian'

# Concatenate into one dataframe
data = pd.concat((data, data1))
# Reset index and remove the index column
data = data.reset_index().ix[:, 1:]


############## Concatenate the other books ########################

data1 = pd.read_csv('Donna-Tartt-The-Goldfinch.csv', sep = '\t', header = None)
data1.columns = ['rating', 'tail', 'title', 'review']
data1['book'] = 'Donna-Tartt-The-Goldfinch'

data = pd.concat((data, data1))
data = data.reset_index().ix[:, 1:]

data1 = pd.read_csv('EL-James-Fifty-Shades-of-Grey.csv', sep = '\t', header = None)
data1.columns = ['rating', 'tail', 'title', 'review']
data1['book'] = 'EL-James-Fifty-Shades-of-Grey'

data = pd.concat((data, data1))
data = data.reset_index().ix[:, 1:]

data1 = pd.read_csv('Fillian_Flynn-Gone_Girl.csv', sep = '\t', header = None)
data1.columns = ['rating', 'tail', 'title', 'review']
data1['book'] = 'Fillian_Flynn-Gone_Girl'

data = pd.concat((data, data1))
data = data.reset_index().ix[:, 1:]

data1 = pd.read_csv('John-Green-The-Fault-in-our-Stars.csv', sep = '\t', header = None)
data1.columns = ['rating', 'tail', 'title', 'review']
data1['book'] = 'John-Green-The-Fault-in-our-Stars'

data = pd.concat((data, data1))
data = data.reset_index().ix[:, 1:]

data1 = pd.read_csv('Laura-Hillenbrand-Unbroken.csv', sep = '\t', header = None)
data1.columns = ['rating', 'tail', 'title', 'review']
data1['book'] = 'Laura-Hillenbrand-Unbroken'

########## Final concatenation ##############
data = pd.concat((data, data1))
data = data.reset_index().ix[:, 1:]

print('The dataframe contains ', data.shape[0], ' rows, which consist of reviews from ', len(data.book.unique()), 
      ' different books\n')

for book in data.book.unique():
    print(book, ' has ', len(data[data.book == book]), ' reviews')
# Out:
# The dataframe contains  219242  rows, which consist of reviews from  7  different books
#
# Paula_Hawkins-The-Girl-On-The-Train  has  37139  reviews
# Andy-Weir-The-Martian  has  22571  reviews
# Donna-Tartt-The-Goldfinch  has  22861  reviews
# EL-James-Fifty-Shades-of-Grey  has  32977  reviews
# Fillian_Flynn-Gone_Girl  has  41974  reviews
# John-Green-The-Fault-in-our-Stars  has  35844  reviews
# Laura-Hillenbrand-Unbroken  has  25876  reviews

# %%
print("In total, we have {} reviews.".format(data.shape[0]))
# Out:
# In total, we have 219242 reviews.

# %%
plt.hist(data.rating)
plt.xlabel('Ratings')
plt.ylabel('Number of ratings')
plt.title('Histogram of ratings')
plt.show()

# %%
#Plot for the new dataset (preprocessed)
plt.figure(figsize=(22.0, 22.0))
cmptr=1
for book in data.book.unique():
    plt.subplot(10,3,cmptr)
    plt.hist(data[data.book == book]['rating'])
    plt.tight_layout(pad=0.6, w_pad=2, h_pad=1.0)
    plt.xlabel('Rating')
    plt.ylabel('Number of ratings')
    plt.title(book)
    cmptr+=1
plt.show()

# %% [markdown]
# We notice that some books have mostly good ratings (e.g. "Unbroken"), whereas some others have more uniform rating distributions (e.g. "Gone Girl").

# %% [markdown]
# # Toy Dataset

# %% [markdown]
# #### We will use only a part of the reviews from the book "The Girl on the Train", Paula Hawkins

# %%
# We select only one book
single_book = data[data.book == 'Paula_Hawkins-The-Girl-On-The-Train']

# # We sample 10% of the dataset, and we keep the distribution of ratings
# toy_data = pd.DataFrame()
# for rating in data.rating.unique():
#     aux_df = single_book[single_book.rating == rating]
#     rows = aux_df.sample(frac=0.1)
#     toy_data = pd.concat((toy_data, rows))

# %%
# Here we will define negative, neutral and positive reviews
def sentiment(x):
    if x < 3:
        return -1
    if x == 3:
        return 0
    else:
        return 1
single_book['sentiment'] = single_book['rating'].apply(lambda x: sentiment(x))
# Out:
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.hist(single_book.sentiment)
plt.show()

# %% [markdown]
# Before doing anything, we observe that the target variable is clearly imbalanced.
# One solution to imbalanced data, when we want to separare the data into train and test sets, is that we want to keep the same distribution of the data in both sets. This is feasable with stratified sampling using sklearn.
# However, here, since the target variable is too much imbalanced, there's a high risk that any predictor will always predict the dominant class! Indeed, whatever happens, this will produce a very decent accuracy, but it is likely to be not effective for being discriminant.
# One solution is to keep all instances of non dominant class, and sampling over the dominant classes such that all classes are equivalantly represented. We will then have more confidance in our classification algorithm. The downside is that we loose some data...

# %%
print(single_book.sentiment.value_counts())
print('Minimum representation for classes:', single_book.sentiment.value_counts().min())
# Out:
#  1    25577
# -1     7399
#  0     4163
# Name: sentiment, dtype: int64
# Minimum representation for classes: 4163

# %%
# Index of positive, negative and neutral data
index_positive = list(single_book[single_book.sentiment == 1].index)
index_negative = list(single_book[single_book.sentiment == -1].index)
index_neutral = list(single_book[single_book.sentiment == 0].index)

# Sample over the negative and positive data
min_class = single_book.sentiment.value_counts().min()
print(min_class)
index_positive_sample = list(single_book.ix[index_positive].sample(min_class).index)
index_negative_sample = list(single_book.ix[index_negative].sample(min_class).index)
index_final = index_negative_sample + index_positive_sample + index_neutral

# We define our toy dataset with balanced classes
toy_data = single_book.ix[index_final]
# Reset the index
toy_data = toy_data.reset_index().ix[:, 1:]

# Plot the histogram of classes
plt.hist(toy_data.sentiment)
plt.title('HIstogram of balanced classes')
plt.xlabel('Sentiment')
plt.ylabel('Number of occurrences')
plt.show()
# Out:
# 4163

# %%
# Size of the resulting toy dataset
print('Our toy dataset has now {} rows'.format(toy_data.shape[0]))
# Out:
# Our toy dataset has now 12489 rows

# %% [markdown]
# ## Let's have a look at the reviews

# %%
toy_data.review[10]
# Out:
# '<span class="a-size-base review-text">Great mystery!</span>'

# %% [markdown]
# It looks that the reviews are in HTML format! We will remove first remove html tages. As additional pre processing, we will also remove non-letters characters, use lowercases everywhere and remove stopwords (the words that occur too often like "the", "a", ... as they might not contain a lot of information and removing them reduces a lot the dimension of the problem.

# %%
def process(x):
    '''
    Function to clear the html tags, then remove non-letters characters, 
    lowercase, remove stopwords, then join the resulting as a full text
    '''

    # Clean html tags
    review = BeautifulSoup(x, "html.parser").get_text() 
    
    # Remove non letters     
    letters = re.sub("[^a-zA-Z]", " ", review) 
    
    # Lowercase and split to words
    words = letters.lower().split()                              
    
    # Join to produce the cleaned texts 

    return(" ".join(words))

# %% [markdown]
# We create the column with clean reviews (according to your machine, this can take a little time):

# %%
toy_data['processed'] = toy_data['review'].apply(lambda x: process(x))

# %%
# An example
toy_data.processed[10]
# Out:
# 'great mystery'

# %% [markdown]
# # Strategy 1:  Bag of Words Model

# %% [markdown]
# In the model of Bag of words, we simplify the text by summarizing it as a list of distinct words, each being described by its relative frequency. Hence, we get rid of word order dependency, and observe only if a word occurs often for positive ratings or for negative ratings, and we would like to investigate if this is sufficient to predict well the ratings.

# %% [markdown]
# We first use the Count Vectorizer from scikit learn. Moreover, we will restraint to the $5000$ most frequent words (computation time).

# %%
print("Wait, bags of words are being created!!\n")
from sklearn.feature_extraction.text import CountVectorizer
# Define the function that will compute the frequencies for all words
vectorizer = CountVectorizer(analyzer = "word", tokenizer = None, preprocessor = None, stop_words = None, max_features = 5000) 
# Use the fit_transform method to learn the vocabulary and then transform the training data into vectors
train_data_features = vectorizer.fit_transform(toy_data['processed'])
# Convert the result to an array
train_data_features = train_data_features.toarray()

print('The model has been learned!')
# Out:
# Wait, bags of words are being created!!
#
# The model has been learned!

# %% [markdown]
# As the words usually appear in only a few reviews, the matrix produced is likely to be very sparse!

# %%
# Examine the size and the sparsity of the tfidf_matrix
size = train_data_features.shape
sparsity = np.count_nonzero(train_data_features) / train_data_features.size

print('The matrix is of shape '+str(size)+' and its sparsity is '+str(sparsity))
# Out:
# The matrix is of shape (12489, 5000) and its sparsity is 0.004717111057730803

# %% [markdown]
# We observe that the matrix is constituted of around $99.6 \%$ zeros!

# %%
print('There are ', train_data_features.shape[0], ' rows and ', train_data_features.shape[1], ' features')
# Out:
# There are  12489  rows and  5000  features

# %%
# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print(vocab)
# Out:
# ['aa', 'abandoned', 'abdic', 'ability', 'able', 'abound', 'about', 'above', 'abrupt', 'absent', 'absolute', 'absolutely', 'absorbed', 'absorbing', 'absurd', 'abuse', 'abused', 'abusive', 'abyss', 'accept', 'acceptable', 'accident', 'acclaim', 'acclaimed', 'accomplished', 'according', 'account', 'accounts', 'accurate', 'accurately', 'achieve', 'achieved', 'acquainted', 'across', 'act', 'acted', 'acting', 'action', 'actions', 'active', 'actively', 'activities', 'actors', 'actresses', 'acts', 'actual', 'actually', 'adaptation', 'add', 'added', 'addict', 'addicted', 'addicting', 'addiction', 'addictions', 'addictive', 'addicts', 'adding', 'addition', 'additional', 'adds', 'adequately', 'adjust', 'adjusted', 'admirable', 'admiration', 'admire', 'admit', 'admittedly', 'adore', 'adult', 'adulterer', 'adulterers', 'adultery', 'adults', 'advance', 'advanced', 'advantage', 'adventure', 'advertised', 'advice', 'affair', 'affairs', 'affects', 'affinity', 'afford', 'afraid', 'after', 'afternoon', 'afterwards', 'again', 'against', 'agatha', 'age', 'ages', 'aggressive', 'ago', 'agree', 'ah', 'aha', 'ahead', 'aid', 'air', 'airplane', 'airport', 'akin', 'al', 'alas', 'alcohol', 'alcoholic', 'alcoholics', 'alcoholism', 'alert', 'alertspoiler', 'alfred', 'alike', 'alive', 'all', 'alley', 'alliance', 'allow', 'allowed', 'allowing', 'allows', 'almost', 'alone', 'along', 'alot', 'already', 'alright', 'also', 'alternate', 'alternated', 'alternately', 'alternates', 'alternating', 'although', 'altogether', 'always', 'am', 'amateur', 'amazed', 'amazing', 'amazingly', 'amazon', 'american', 'amnesia', 'among', 'amongst', 'amount', 'amusing', 'amy', 'an', 'analysis', 'analytical', 'analyzing', 'and', 'andy', 'anger', 'angered', 'angle', 'angles', 'angry', 'angst', 'anna', 'anne', 'annoy', 'annoyed', 'annoying', 'annoyingly', 'another', 'answer', 'answered', 'answers', 'anti', 'anticipate', 'anticipated', 'anticipating', 'anticipation', 'anticlimactic', 'anxiety', 'anxious', 'any', 'anybody', 'anyhow', 'anymore', 'anyone', 'anything', 'anytime', 'anyway', 'anywhere', 'apart', 'apologizing', 'apparent', 'apparently', 'appeal', 'appealing', 'appeals', 'appear', 'appearances', 'appeared', 'appears', 'applaud', 'appointment', 'appreciate', 'appreciated', 'appreciation', 'approach', 'approached', 'approaching', 'appropriate', 'appropriately', 'apt', 'are', 'area', 'areas', 'aren', 'armchair', 'arms', 'around', 'arranged', 'arresting', 'arrived', 'art', 'artfully', 'as', 'ashamed', 'ashbury', 'aside', 'ask', 'asked', 'asking', 'asleep', 'aspect', 'aspects', 'assigned', 'assignment', 'associated', 'assume', 'assumed', 'assuming', 'assumptions', 'astray', 'at', 'atmosphere', 'atmospheric', 'attached', 'attempt', 'attempted', 'attempting', 'attempts', 'attention', 'attentive', 'attitude', 'attracted', 'attraction', 'attractive', 'attributed', 'attributes', 'audible', 'audience', 'audio', 'audiobook', 'audiobooks', 'authentic', 'author', 'authoress', 'authorities', 'authors', 'automatically', 'available', 'average', 'avid', 'avoid', 'avoided', 'await', 'awaiting', 'awake', 'award', 'aware', 'awareness', 'away', 'awe', 'awesome', 'awful', 'awfully', 'awhile', 'awkward', 'awry', 'babies', 'baby', 'back', 'backdrop', 'background', 'backgrounds', 'backs', 'backstory', 'backtrack', 'backward', 'backwards', 'backyard', 'backyards', 'bad', 'badly', 'baffled', 'bag', 'baggage', 'balance', 'balanced', 'balcony', 'ball', 'balls', 'baloney', 'bam', 'banal', 'bang', 'bar', 'bare', 'barely', 'barren', 'base', 'based', 'basic', 'basically', 'basing', 'basis', 'battle', 'battling', 'bc', 'be', 'beach', 'beans', 'bear', 'beat', 'beautiful', 'beautifully', 'beauty', 'became', 'because', 'become', 'becomes', 'becoming', 'bed', 'bedtime', 'been', 'before', 'began', 'begging', 'begin', 'begining', 'beginning', 'begins', 'begs', 'behave', 'behaved', 'behavior', 'behaviors', 'behaviour', 'behind', 'being', 'beings', 'beliefs', 'believability', 'believable', 'believe', 'believed', 'believ ...

# %%
# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print(count, tag)
# Out:
# 5 aa
# 3 abandoned
# 5 abdic
# 18 ability
# 166 able
# 3 abound
# 1265 about
# 21 above
# 3 abrupt
# 4 absent
# 7 absolute
# 93 absolutely
# 22 absorbed
# 27 absorbing
# 9 absurd
# 37 abuse
# 12 abused
# 23 abusive
# 3 abyss
# 10 accept
# 5 acceptable
# 6 accident
# 3 acclaim
# 4 acclaimed
# 8 accomplished
# 3 according
# 9 account
# 14 accounts
# 13 accurate
# 5 accurately
# 4 achieve
# 4 achieved
# 5 acquainted
# 31 across
# 12 act
# 7 acted
# 3 acting
# 60 action
# 54 actions
# 7 active
# 4 actively
# 3 activities
# 8 actors
# 3 actresses
# 8 acts
# 27 actual
# 166 actually
# 4 adaptation
# 52 add
# 24 added
# 3 addict
# 8 addicted
# 17 addicting
# 39 addiction
# 5 addictions
# 14 addictive
# 3 addicts
# 19 adding
# 13 addition
# 3 additional
# 19 adds
# 4 adequately
# 4 adjust
# 3 adjusted
# 8 admirable
# 4 admiration
# 10 admire
# 44 admit
# 6 admittedly
# 5 adore
# 8 adult
# 5 adulterer
# 3 adulterers
# 7 adultery
# 5 adults
# 8 advance
# 3 advanced
# 3 advantage
# 6 adventure
# 6 advertised
# 6 advice
# 24 affair
# 9 affairs
# 4 affects
# 3 affinity
# 4 afford
# 7 afraid
# 421 after
# 20 afternoon
# 3 afterwards
# 197 again
# 15 against
# 9 agatha
# 13 age
# 10 ages
# 5 aggressive
# 18 ago
# 37 agree
# 5 ah
# 4 aha
# 37 ahead
# 3 aid
# 9 air
# 9 airplane
# 5 airport
# 3 akin
# 4 al
# 12 alas
# 111 alcohol
# 302 alcoholic
# 16 alcoholics
# 130 alcoholism
# 12 alert
# 4 alertspoiler
# 26 alfred
# 18 alike
# 13 alive
# 1807 all
# 8 alley
# 4 alliance
# 6 allow
# 5 allowed
# 9 allowing
# 12 allows
# 201 almost
# 25 alone
# 185 along
# 7 alot
# 76 already
# 7 alright
# 345 also
# 7 alternate
# 3 alternated
# 6 alternately
# 12 alternates
# 67 alternating
# 195 although
# 3 altogether
# 148 always
# 316 am
# 3 amateur
# 9 amazed
# 134 amazing
# 8 amazingly
# 33 amazon
# 6 american
# 7 amnesia
# 34 among
# 3 amongst
# 19 amount
# 4 amusing
# 5 amy
# 1242 an
# 8 analysis
# 3 analytical
# 3 analyzing
# 11123 and
# 3 andy
# 9 anger
# 3 angered
# 4 angle
# 4 angles
# 14 angry
# 14 angst
# 258 anna
# 5 anne
# 3 annoy
# 42 annoyed
# 83 annoying
# 3 annoyingly
# 313 another
# 14 answer
# 7 answered
# 15 answers
# 11 anti
# 10 anticipate
# 8 anticipated
# 4 anticipating
# 6 anticipation
# 4 anticlimactic
# 6 anxiety
# 20 anxious
# 483 any
# 7 anybody
# 3 anyhow
# 16 anymore
# 268 anyone
# 132 anything
# 8 anytime
# 42 anyway
# 16 anywhere
# 34 apart
# 3 apologizing
# 7 apparent
# 11 apparently
# 13 appeal
# 15 appealing
# 3 appeals
# 20 appear
# 4 appearances
# 10 appeared
# 12 appears
# 3 applaud
# 4 appointment
# 22 appreciate
# 11 appreciated
# 3 appreciation
# 27 approach
# 4 approached
# 4 approaching
# 3 appropriate
# 4 appropriately
# 5 apt
# 1399 are
# 3 area
# 6 areas
# 38 aren
# 3 armchair
# 3 arms
# 196 around
# 5 arranged
# 3 arresting
# 7 arrived
# 10 art
# 3 artfully
# 2135 as
# 5 ashamed
# 4 ashbury
# 28 aside
# 10 ask
# 7 asked
# 8 asking
# 7 asleep
# 30 aspect
# 17 aspects
# 2 assigned
# 2 assignment
# 3 associated
# 6 assume
# 4 assumed
# 4 assuming
# 11 assumptions
# 2 astray
# 1660 at
# 4 atmosphere
# 4 atmospheric
# 6 attached
# 13 attempt
# 6 attempted
# 4 attempting
# 12 attempts
# 352 attention
# 3 attentive
# 4 attitude
# 4 attracted
# 7 attraction
# 11 attractive
# 2 attributed
# 3 attributes
# 24 audible
# 5 audience
# 34 audio
# 12 audiobook
# 2 audiobooks
# 7 authentic
# 785 author
# 2 authoress
# 3 authorities
# 41 authors
# 2 automatically
# 9 available
# 24 average
# 19 avid
# 16 avoid
# 2 avoided
# 3 await
# 2 awaiting
# 3 awake
# 2 award
# 16 aware
# 2 awareness
# 162 away
# 3 awe
# 88 awesome
# 38 awful
# 2 awfully
# 62 awhile
# 5 awkward
# 2 awry
# 3 babies
# 62 baby
# 414 back
# 4 backdrop
# 11 background
# 3 backgrounds
# 8 backs
# 5 backstory
# 2 backtrack
# 4 backward
# 6 backwards
# 2 backyard
# 4 backyards
# 269 bad
# 18 badly
# 5 baffled
# 7 bag
# 4 baggage
# 6 balance
# 2 balanced
# 3 balcony
# 3 ball
# 2 balls
# 2 baloney
# 5 bam
# 3 banal
# 3 bang
# 3 bar
# 2 bare
# 27 barely
# 3 barren
# 2 base
# 59 based
# 17 basic
# 22 basically
# 2 basing
# 7 basis
# 12 battle
# 4 battling
# 3 bc
# 1485 be
# 114 beach
# 3 beans
# 5 bear
# 5 beat
# 20 beautiful
# 21 beautifully
# 9 beauty
# 165 became
# 790 because
# 90 become
# 109 becomes
# 18 becoming
# 13 bed
# 12 bedtime
# 443 been
# 264 before
# 53 began
# 3 begging
# 30 begin
# 3 begining
# 400 beginning
# 32 begins
# 3 begs
# 4 behave
# 3 behaved
# 44 behavior
# 10 behaviors
# 3 behaviour
# 35 behind
# 310 being
# 8 beings
# 3 beliefs
# 4 believability
# 134 believable
# 138 believe
# 13 believed
# 20 believes
# 8 believing
# 5 belong
# 2 belonged
# 2 beloved
# 2 ben
# 3 bend
# 3 bends
# 4 beneath
# 3 benefit
# 2 benefits
# 2 bent
# 2 bentley
# 2 bereaved
# 3 beside
# 6 besides
# 497 best
# 36 bestseller
# 3 bestsellers
# 4 bet
# 2 betray
# 14 betrayal
# 2 betrayed
# 495 better
# 197 between
# 3 beware
# 17 beyond
# 2 bias
# 119 big
# 6 bigger
# 14 biggest
# 3 bile
# 7 bill
# 2 billed
# 10 binding
# 5 binge
# 9 binges
# 2 bipolar
# 2 bird
# 2 birds
# 576 bit
# 2 bitch
# 2 bitchy
# 5 biter
# 2 bites
# 11 bits
# 5 bitter
# 9 bizarre
# 2 bk
# 30 black
# 9 blacked
# 7 blacking
# 44 blackout
# 81 blackouts
# 9 blacks
# 11 blah
# 12 blame
# 2 blamed
# 3 blames
# 10 bland
# 2 blanket
# 3 blast
# 8 bleak
# 3 bleinham
# 2 blend
# 3 blenheim
# 3 blew
# 5 blind
# 2 blinded
# 2 bliss
# 3 blissfully
# 3 blizzard
# 3 block
# 8 blockbuster
# 4 blog
# 6 blogspot
# 2 blonde
# 6 blood
# 6 bloody
# 7 blow
# 5 blowing
# 6 blown
# 2 blue
# 2 blunders
# 7 blunt
# 3 blur
# 5 blurb
# 2 blurbs
# 7 board
# 3 boat
# 11 body
# 5 bogged
# 3 bomb
# 3 bone
# 5 boo
# 7661 book
# 8 bookclub
# 542 books
# 3 bookstore
# 11 booze
# 5 borderline
# 5 bore
# 58 bored
# 5 boredom
# 243 boring
# 2 boringly
# 2 born
# 9 borrow
# 5 borrowed
# 2 boston
# 120 both
# 17 bother
# 14 bothered
# 4 bothering
# 2 bothers
# 3 bothersome
# 13 bottle
# 2 bottles
# 16 bottom
# 65 bought
# 2 bounce
# 2 bounced
# 4 bounces
# 3 bouncing
# 4 bound
# 2 bounds
# 2 bow
# 2 box
# 12 boy
# 9 boyfriend
# 2 boys
# 8 brain
# 3 brand
# 4 brave
# 7 bravo
# 2 bread
# 18 break
# 2 breakaway
# 3 breakdown
# 3 breakfast
# 4 breaking
# 2 breakneck
# 9 breaks
# 3 breakup
# 4 brealey
# 11 breath
# 2 breathe
# 2 breathing
# 3 breathless
# 2 breathtaking
# 2 breeze
# 5 bridget
# 6 brief
# 3 briefly
# 5 bright
# 3 brilliance
# 47 brilliant
# 17 brilliantly
# 24 bring
# 7 bringing
# 17 brings
# 2 brisk
# 39 british
# 8 broke
# 27 broken
# 4 brother
# 25 brought
# 2 brown
# 2 bruised
# 4 brutal
# 3 btw
# 2 bucks
# 2 buddies
# 2 buddy
# 2 buff
# 4 buffs
# 2 bugged
# 49 build
# 27 building
# 3 buildings
# 59 builds
# 4 buildup
# 31 built
# 2 bulk
# 2 bully
# 3 bumbling
# 3 bummed
# 2 bummer
# 4 bump
# 2 bumped
# 23 bunch
# 2 bundle
# 3 buried
# 5 burn
# 2 bursts
# 4 bus
# 5 business
# 12 busy
# 4 busybody
# 4280 but
# 67 buy
# 25 buying
# 17 buzz
# 2 buzzy
# 989 by
# 2 caffeinated
# 2 cake
# 2 calendar
# 3 caliber
# 43 call
# 18 called
# 9 calling
# 19 calls
# 95 came
# 936 can
# 3 canned
# 113 cannot
# 10 cant
# 11 capable
# 2 capitalize
# 3 captivate
# 22 captivated
# 3 captivates
# 71 captivating
# 4 captive
# 9 capture
# 20 captured
# 13 captures
# 2 capturing
# 17 car
# 4 card
# 2 cardboard
# 219 care
# 26 cared
# 4 career
# 2 careers
# 13 careful
# 15 carefully
# 9 cares
# 2 caricatures
# 18 caring
# 6 carried
# 4 carries
# 2 carry
# 2 carrying
# 65 case
# 7 cases
# 3 cash
# 26 cast
# 2 casting
# 4 casual
# 25 catch
# 11 catches
# 5 catching
# 9 category
# 2 cathartic
# 26 cathy
# 2 catty
# 65 caught
# 20 cause
# 19 caused
# 6 causes
# 4 causing
# 3 caution
# 4 cautionary
# 2 cbs
# 4 cd
# 2 cent
# 11 center
# 11 centered
# 10 centers
# 24 central
# 2 century
# 41 certain
# 110 certainly
# 2 chain
# 10 chair
# 9 challenge
# 2 challenged
# 6 challenges
# 13 challenging
# 34 chance
# 3 chances
# 55 change
# 29 changed
# 48 changes
# 57 changing
# 2 channels
# 306 chapter
# 308 chapters
# 2 charachters
# 1444 character
# 10 characteristics
# 17 characterization
# 12 characterizations
# 2712 characters
# 3 charge
# 4 charges
# 4 charm
# 3 chart
# 3 chase
# 2 chatter
# 6 cheap
# 6 cheat
# 21 cheated
# 5 cheater
# 2 cheaters
# 19 cheating
# 5 cheats
# 28 check
# 6 checking
# 2 checks
# 14 cheer
# 4 cheering
# 4 cheesy
# 2 chew
# 3 chic
# 4 chicago
# 8 chick
# 36 child
# 2 childless
# 7 children
# 15 chilling
# 3 chills
# 35 choice
# 42 choices
# 18 choose
# 4 choosing
# 5 choppy
# 4 chore
# 6 chores
# 25 chose
# 10 chosen
# 7 christie
# 7 chronological
# 5 chronologically
# 5 chronology
# 3 circumstance
# 18 circumstances
# 10 city
# 3 claimed
# 3 clarify
# 5 clarity
# 15 class
# 12 classic
# 3 classics
# 3 classify
# 3 classy
# 6 claustrophobia
# 4 clean
# 3 cleaning
# 61 clear
# 7 clearer
# 29 clearly
# 95 clever
# 35 cleverly
# 2 cleverness
# 2 clich
# 12 cliche
# 4 cliched
# 2 click
# 3 clicks
# 3 client
# 2 cliff
# 4 climactic
# 6 climatic
# 47 climax
# 3 clingy
# 3 clock
# 2 clone
# 80 close
# 7 closed
# 4 closely
# 8 closer
# 3 closest
# 2 closet
# 3 closing
# 5 closure
# 13 clothes
# 2 clouded
# 4 cloudy
# 188 club
# 6 clubs
# 13 clue
# 5 clueless
# 50 clues
# 4 clunky
# 3 co
# 2 coarse
# 14 coaster
# 2 coben
# 2 code
# 4 coffee
# 2 coherence
# 3 coherent
# 2 coincidence
# 6 coincidences
# 2 coincidental
# 2 coincidentally
# 20 cold
# 3 collection
# 7 college
# 2 collide
# 4 color
# 2 colorful
# 10 com
# 10 combination
# 2 combine
# 5 combined
# 123 come
# 2 comedic
# 69 comes
# 5 comfort
# 8 comfortable
# 2 comforting
# 168 coming
# 2 command
# 7 comment
# 4 commentary
# 5 comments
# 2 commit
# 2 commitment
# 15 committed
# 28 common
# 2 community
# 44 commute
# 55 commuter
# 4 commuters
# 8 commutes
# 16 commuting
# 2 companion
# 5 comparable
# 38 compare
# 111 compared
# 2 compares
# 18 comparing
# 49 comparison
# 52 comparisons
# 13 compassion
# 2 compel
# 21 compelled
# 160 compelling
# 3 compels
# 3 competent
# 6 complain
# 5 complained
# 6 complaining
# 22 complaint
# 3 complaints
# 48 complete
# 11 completed
# 126 completely
# 4 completion
# 94 complex
# 2 complexities
# 14 complexity
# 40 complicated
# 4 complication
# 2 compliment
# 4 comprehend
# 2 comprised
# 3 compromised
# 3 compulsion
# 12 compulsive
# 3 conceit
# 2 conceive
# 9 conceived
# 4 concentrate
# 2 concentrated
# 4 concentration
# 35 concept
# 2 concepts
# 2 concern
# 11 concerned
# 3 concerning
# 2 concerns
# 2 conclude
# 2 concluded
# 85 conclusion
# 4 conclusions
# 2 concocted
# 4 concrete
# 2 condensed
# 9 condition
# 4 conditions
# 4 confess
# 7 confession
# 5 confidence
# 6 confirmed
# 4 conflict
# 3 confront
# 4 confronted
# 7 confuse
# 86 confused
# 312 confusing
# 3 confusingly
# 22 confusion
# 5 congratulations
# 6 conjured
# 26 connect
# 27 connected
# 4 connecting
# 20 connection
# 9 connections
# 3 conquer
# 4 conscience
# 5 consciousness
# 9 consequences
# 28 consider
# 12 considered
# 9 considering
# 6 consistent
# 7 consistently
# 34 constant
# 53 constantly
# 16 constructed
# 6 consumed
# 3 contact
# 2 contain
# 2 contained
# 7 contains
# 9 contemporary
# 17 content
# 4 contents
# 3 context
# 3 continual
# 6 continually
# 50 continue
# 30 continued
# 31 continues
# 11 continuing
# 3 continuity
# 8 continuous
# 4 continuously
# 2 contracted
# 3 contrary
# 2 contrast
# 2 contribute
# 37 contrived
# 25 control
# 7 controlling
# 2 convenience
# 9 convenient
# 8 conveniently
# 4 convention
# 4 converge
# 6 conversation
# 6 conversations
# 2 conveyed
# 3 conveys
# 5 convince
# 9 convinced
# 9 convincing
# 14 convoluted
# 10 cool
# 4 cop
# 3 cope
# 3 copies
# 4 cops
# 24 copy
# 3 copycat
# 2 corbett
# 6 core
# 8 corkscrew
# 6 corner
# 14 correct
# 6 correctly
# 3 cost
# 2 couch
# 1006 could
# 1188 couldn
# 13 couldnt
# 7 count
# 3 counted
# 2 counterparts
# 2 counting
# 3 countless
# 3 country
# 248 couple
# 3 coupled
# 15 couples
# 2 coupon
# 3 courage
# 62 course
# 2 cousin
# 31 cover
# 2 covered
# 2 covering
# 3 coworkers
# 4 cozy
# 2 crack
# 3 cracking
# 3 craft
# 49 crafted
# 8 crap
# 2 crash
# 2 crave
# 2 craving
# 3 crawl
# 3 craziness
# 93 crazy
# 2 cream
# 18 create
# 25 created
# 15 creates
# 17 creating
# 2 creation
# 32 creative
# 4 creatively
# 3 creativity
# 2 creature
# 11 credibility
# 12 credible
# 8 credit
# 2 credits
# 2 credulity
# 5 creeps
# 34 creepy
# 2 crescendo
# 3 cried
# 51 crime
# 10 criminal
# 7 cringe
# 4 cringed
# 4 cringing
# 3 crisis
# 3 crisp
# 2 criteria
# 4 critic
# 16 critical
# 10 criticism
# 3 criticize
# 5 critics
# 2 critique
# 2 critiques
# 8 cross
# 4 crossed
# 2 crosses
# 4 crowd
# 5 crucial
# 4 crude
# 3 cruel
# 3 cruise
# 2 crushed
# 2 cry
# 25 culprit
# 2 cultural
# 5 culture
# 2 cumbersome
# 14 cup
# 20 curiosity
# 20 curious
# 3 curl
# 2 curled
# 23 current
# 9 currently
# 6 curve
# 2 customer
# 7 cut
# 2 cuts
# 84 daily
# 9 damage
# 27 damaged
# 3 damien
# 5 damn
# 10 danger
# 8 dangerous
# 4 dangers
# 7 dare
# 2 daring
# 192 dark
# 9 darker
# 4 darkest
# 3 darkly
# 7 darkness
# 6 darn
# 2 dash
# 20 date
# 4 dated
# 120 dates
# 26 daughter
# 2 davinci
# 3 dawn
# 376 day
# 5 daydreams
# 217 days
# 2 daytime
# 2 de
# 26 dead
# 2 deadline
# 28 deal
# 12 dealing
# 7 dealt
# 6 dear
# 12 death
# 3 deaths
# 3 debating
# 37 debut
# 9 deceit
# 3 deceive
# 70 decent
# 7 deception
# 4 deceptive
# 12 decide
# 42 decided
# 13 decides
# 3 decipher
# 15 decision
# 43 decisions
# 3 dedicate
# 3 deed
# 3 deemed
# 32 deep
# 21 deeper
# 30 deeply
# 4 def
# 4 defense
# 4 defiantly
# 4 definately
# 15 defined
# 3 definetly
# 27 definite
# 395 definitely
# 3 definition
# 3 deft
# 5 deftly
# 11 degree
# 4 deleted
# 3 delicious
# 6 deliciously
# 4 delighted
# 7 delightful
# 3 delightfully
# 12 deliver
# 13 delivered
# 12 delivers
# 6 delivery
# 7 delusional
# 3 delusions
# 7 delve
# 4 delves
# 3 demand
# 3 demands
# 14 demons
# 5 denial
# 15 denouement
# 3 depend
# 7 dependent
# 5 depending
# 5 depicted
# 3 depicting
# 8 depiction
# 52 depressed
# 284 depressing
# 26 depression
# 3 depressive
# 41 depth
# 4 depths
# 3 deranged
# 4 derivative
# 4 descent
# 22 describe
# 27 described
# 15 describes
# 13 describing
# 26 description
# 34 descriptions
# 16 descriptive
# 11 deserve
# 15 deserved
# 17 deserves
# 3 deserving
# 4 designed
# 4 desirable
# 18 desire
# 7 desired
# 5 desires
# 7 despair
# 23 desperate
# 11 desperately
# 10 desperation
# 13 despicable
# 3 despise
# 61 despite
# 4 destination
# 3 destroying
# 4 destruct
# 4 destruction
# 19 destructive
# 37 detail
# 13 detailed
# 5 detailing
# 76 details
# 17 detective
# 7 detectives
# 3 determination
# 14 determine
# 7 determined
# 6 detract
# 4 detracted
# 4 devastated
# 5 devastating
# 28 develop
# 198 developed
# 22 developing
# 217 development
# 21 develops
# 19 device
# 5 devious
# 6 devoid
# 3 devote
# 4 devour
# 11 devoured
# 4 dialog
# 41 dialogue
# 3 diaries
# 13 diary
# 1184 did
# 905 didn
# 12 didnt
# 10 die
# 5 died
# 3 dies
# 13 difference
# 7 differences
# 563 different
# 6 differentiate
# 13 differently
# 235 difficult
# 17 difficulty
# 4 dig
# 3 digging
# 6 dimension
# 30 dimensional
# 3 dimensions
# 3 diminish
# 5 dinner
# 5 direct
# 26 direction
# 7 directions
# 4 directly
# 3 dirt
# 3 dis
# 8 disagree
# 38 disappearance
# 18 disappeared
# 22 disappears
# 29 disappoint
# 206 disappointed
# 78 disappointing
# 39 disappointment
# 3 disappoints
# 4 disaster
# 5 disbelief
# 3 discern
# 4 disclaimer
# 4 disconcerting
# 3 disconnected
# 20 discover
# 11 discovered
# 3 discovering
# 7 discovers
# 5 discovery
# 14 discuss
# 6 discussed
# 25 discussion
# 10 disease
# 8 disfunctional
# 5 disgust
# 11 disgusted
# 11 disgusting
# 3 disillusioned
# 20 disjointed
# 4 dislikable
# 23 dislike
# 30 disliked
# 3 dislikes
# 3 disliking
# 4 dismal
# 3 disorder
# 4 display
# 3 dissapointed
# 3 dissatisfied
# 7 distance
# 8 distinct
# 6 distinctive
# 5 distinctly
# 9 distinguish
# 3 distinguishing
# 4 distract
# 3 distracted
# 5 distracting
# 8 distraction
# 18 disturbed
# 36 disturbing
# 4 dive
# 3 diverse
# 3 diversion
# 6 divided
# 14 divorce
# 32 divorced
# 5 divorcee
# 5 dizzy
# 401 do
# 3 doctor
# 3 doerr
# 253 does
# 150 doesn
# 6 dog
# 57 doing
# 8 domestic
# 3 dominated
# 627 don
# 357 done
# 15 dont
# 7 door
# 27 doors
# 4 dots
# 4 double
# 28 doubt
# 3 doubting
# 4 doubts
# 2124 down
# 9 downer
# 4 downfall
# 7 downhill
# 7 download
# 18 downloaded
# 3 downright
# 5 downside
# 9 downward
# 7 dozen
# 6 dr
# 28 drag
# 72 dragged
# 7 dragging
# 7 draggy
# 4 dragon
# 16 drags
# 3 drained
# 61 drama
# 21 dramatic
# 9 drank
# 22 draw
# 3 drawback
# 4 drawing
# 114 drawn
# 16 draws
# 3 dread
# 9 dreadful
# 3 dreading
# 11 dream
# 3 dreaming
# 11 dreams
# 4 dreamworks
# 12 dreary
# 3 dressing
# 24 drew
# 40 drink
# 8 drinker
# 158 drinking
# 25 drinks
# 5 drip
# 15 drive
# 3 drivel
# 20 driven
# 6 drives
# 9 driving
# 9 drop
# 5 dropped
# 13 drove
# 4 drowning
# 6 drug
# 4 drugs
# 189 drunk
# 36 drunken
# 11 drunkenness
# 5 drunks
# 5 dry
# 3 dual
# 53 due
# 44 dull
# 18 dumb
# 17 dun
# 33 dunnit
# 60 during
# 4 dust
# 3 duties
# 5 dying
# 3 dynamic
# 11 dysfunction
# 59 dysfunctional
# 517 each
# 8 eager
# 6 eagerly
# 4 ear
# 21 earlier
# 99 early
# 4 earned
# 10 earth
# 24 easier
# 46 easily
# 438 easy
# 4 eat
# 4 eating
# 4 ebook
# 165 edge
# 5 edgy
# 11 editing
# 3 edition
# 4 editor
# 5 educated
# 3 eerie
# 8 effect
# 7 effective
# 6 effects
# 33 effort
# 4 effortlessly
# 8 eh
# 102 either
# 5 elaborate
# 3 electronic
# 13 element
# 20 elements
# 113 else
# 3 email
# 4 embarrassed
# 4 embedded
# 3 embrace
# 7 emerge
# 3 emerges
# 4 emily
# 11 emotion
# 40 emotional
# 11 emotionally
# 31 emotions
# 6 empathetic
# 15 empathize
# 34 empathy
# 3 emphasis
# 3 emphasize
# 4 employed
# 3 employs
# 5 empty
# 3 enabler
# 5 encounters
# 7 encourage
# 3 encouraged
# 1685 end
# 6 endearing
# 3 endeavor
# 108 ended
# 1026 ending
# 8 endings
# 14 endless
# 56 ends
# 3 enemies
# 5 enemy
# 7 engage
# 80 engaged
# 126 engaging
# 18 england
# 28 english
# 30 engrossed
# 55 engrossing
# 3 enhanced
# 300 enjoy
# 209 enjoyable
# 1049 enjoyed
# 18 enjoying
# 13 enjoyment
# 31 enjoys
# 6 enormous
# 274 enough
# 3 ensues
# 8 entangled
# 4 enter
# 7 entertain
# 34 entertained
# 246 entertaining
# 18 entertainment
# 18 enthralled
# 16 enthralling
# 12 enticing
# 117 entire
# 24 entirely
# 6 entirety
# 3 entranced
# 4 entries
# 8 entwined
# 3 environment
# 3 envisions
# 8 episode
# 3 episodes
# 4 equal
# 13 equally
# 3 ereader
# 8 errors
# 11 escape
# 4 escaped
# 138 especially
# 4 esque
# 5 essence
# 3 essential
# 6 essentially
# 7 established
# 11 esteem
# 41 etc
# 509 even
# 25 evening
# 3 evenings
# 21 event
# 110 events
# 44 eventually
# 193 ever
# 335 every
# 8 everybody
# 50 everyday
# 179 everyone
# 125 everything
# 11 everywhere
# 4 evidence
# 6 evident
# 7 evie
# 19 evil
# 3 evils
# 3 evoke
# 6 evolve
# 14 evolved
# 10 evolves
# 165 ex
# 6 exact
# 47 exactly
# 4 exaggerated
# 23 example
# 3 examples
# 3 exasperating
# 4 exceeded
# 405 excellent
# 11 excellently
# 62 except
# 10 exception
# 7 exceptional
# 5 exceptionally
# 12 excessive
# 4 exchange
# 35 excited
# 24 excitement
# 158 exciting
# 3 excruciatingly
# 6 excuse
# 3 excuses
# 9 executed
# 5 execution
# 5 exhausted
# 7 exhausting
# 4 exhilarating
# 4 exist
# 7 existence
# 91 expect
# 6 expectation
# 54 expectations
# 143 expected
# 54 expecting
# 51 experience
# 12 experienced
# 18 experiences
# 6 experiencing
# 4 expert
# 7 expertly
# 11 explain
# 7 explained
# 6 explaining
# 3 explains
# 7 explanation
# 3 explicit
# 5 exploration
# 4 explore
# 3 explored
# 5 explores
# 6 exploring
# 7 exposed
# 3 exposing
# 5 exposition
# 6 expressed
# 4 extent
# 8 extra
# 3 extraneous
# 5 extraordinary
# 11 extreme
# 64 extremely
# 13 eye
# 54 eyes
# 4 fab
# 32 fabulous
# 20 face
# 4 facebook
# 5 faces
# 4 facets
# 3 facing
# 135 fact
# 8 factor
# 10 facts
# 10 fail
# 23 failed
# 9 failure
# 29 fair
# 58 fairly
# 4 fairy
# 3 fake
# 30 fall
# 7 fallen
# 9 falling
# 12 falls
# 3 false
# 12 familiar
# 43 family
# 74 fan
# 5 fanciful
# 22 fans
# 4 fantasies
# 6 fantasizes
# 3 fantasizing
# 115 fantastic
# 44 fantasy
# 134 far
# 3 farther
# 7 fascinated
# 66 fascinating
# 4 fascination
# 4 fashioned
# 398 fast
# 16 faster
# 4 fastest
# 8 fat
# 5 fatal
# 5 fateful
# 3 fathom
# 14 fault
# 4 faults
# 7 faulty
# 6 favor
# 72 favorite
# 15 favorites
# 15 fear
# 5 fears
# 3 feat
# 4 feature
# 5 featured
# 9 features
# 3 featuring
# 7 fed
# 312 feel
# 109 feeling
# 48 feelings
# 51 feels
# 10 feet
# 29 fell
# 8 fellow
# 358 felt
# 167 female
# 12 females
# 3 feminist
# 18 fetched
# 333 few
# 58 fiction
# 7 fictional
# 3 field
# 9 fifty
# 3 fighting
# 3 figuratively
# 247 figure
# 236 figured
# 17 figuring
# 14 fill
# 46 filled
# 3 filler
# 39 film
# 5 films
# 45 final
# 6 finale
# 142 finally
# 374 find
# 21 finding
# 14 finds
# 45 fine
# 5 finger
# 4 fingers
# 405 finish
# 354 finished
# 46 finishing
# 11 fire
# 10 fired
# 848 first
# 17 fit
# 8 fits
# 5 fitting
# 51 five
# 3 fix
# 3 fizzled
# 3 flair
# 12 flash
# 3 flashback
# 14 flashbacks
# 4 flashes
# 45 flat
# 6 flatmate
# 9 flaw
# 183 flawed
# 3 flawless
# 48 flaws
# 3 flesh
# 12 fleshed
# 3 fleshing
# 5 flew
# 20 flight
# 10 flip
# 5 flipped
# 24 flipping
# 24 flow
# 15 flowed
# 9 flows
# 3 fluff
# 7 fly
# 3 flying
# 101 flynn
# 22 focus
# 9 focused
# 3 focuses
# 9 fog
# 6 foibles
# 10 folks
# 211 follow
# 4 followed
# 32 following
# 9 follows
# 7 fond
# 10 fool
# 17 fooled
# 6 foolish
# 3 footing
# 2771 for
# 27 force
# 28 forced
# 4 forcing
# 3 foresee
# 9 foreshadowing
# 28 forever
# 28 forget
# 3 forgetting
# 3 forgiving
# 4 forgot
# 8 forgotten
# 15 form
# 46 format
# 4 formed
# 25 former
# 4 formula
# 7 formulaic
# 140 forth
# 6 fortunately
# 140 forward
# 4 forwards
# 4 foul
# 633 found
# 55 four
# 7 fourth
# 3 frailties
# 14 frame
# 10 frames
# 19 frankly
# 13 free
# 3 french
# 8 frequent
# 15 frequently
# 11 fresh
# 3 friday
# 92 friend
# 125 friends
# 6 frightening
# 1526 from
# 13 front
# 34 frustrated
# 43 frustrating
# 11 frustration
# 6 fueled
# 4 fulfill
# 3 fulfilled
# 146 full
# 31 fully
# 264 fun
# 3 fundamentally
# 12 funny
# 38 further
# 6 furthermore
# 18 fuss
# 41 future
# 8 gain
# 8 gained
# 5 gains
# 3 gal
# 5 gallery
# 6 galore
# 7 game
# 3 games
# 8 gaps
# 6 garbage
# 7 garden
# 4 gardens
# 4 garnered
# 5 gaslight
# 3 gasp
# 3 gathers
# 134 gave
# 6 gem
# 4 gender
# 15 general
# 22 generally
# 3 generated
# 3 generous
# 7 genius
# 83 genre
# 5 genuine
# 3 genuinely
# 973 get
# 144 gets
# 174 getting
# 11 gg
# 15 gift
# 85 gillian
# 3 gimmicky
# 16 gin
# 2003 girl
# 13 girls
# 208 give
# 78 given
# 49 gives
# 61 giving
# 157 glad
# 5 gladly
# 9 glass
# 4 glimmer
# 17 glimpse
# 4 glimpsed
# 13 glimpses
# 3 gloomy
# 8 glowing
# 21 glued
# 247 go
# 5 goal
# 14 god
# 114 goes
# 511 going
# 3 gold
# 10 golden
# 3 golf
# 1414 gone
# 4 gonna
# 2695 good
# 9 goodness
# 6 goodreads
# 4 gore
# 524 got
# 22 gotten
# 28 grab
# 27 grabbed
# 4 grabber
# 3 grabbing
# 40 grabs
# 8 grace
# 4 grade
# 19 gradually
# 3 grain
# 5 grammatical
# 3 grammatically
# 7 grand
# 4 granted
# 11 graphic
# 4 grasp
# 4 grateful
# 3 gratuitous
# 4 gray
# 2099 great
# 6 greatest
# 14 greatly
# 13 grew
# 5 grief
# 4 grim
# 5 grip
# 11 gripped
# 137 gripping
# 6 grips
# 4 grisham
# 5 gritty
# 8 ground
# 33 group
# 13 grow
# 4 growing
# 3 grown
# 7 grows
# 4 growth
# 3 gruesome
# 3 guarantee
# 3 guard
# 147 guess
# 71 guessed
# 6 guesses
# 669 guessing
# 5 guest
# 3 guide
# 9 guilt
# 32 guilty
# 53 guy
# 12 guys
# 4 gym
# 17 ha
# 1334 had
# 32 hadn
# 3 hailed
# 11 hair
# 8 haired
# 213 half
# 70 halfway
# 21 hand
# 6 handful
# 11 handle
# 13 handled
# 14 hands
# 25 hang
# 15 hanging
# 4 hangover
# 5 hangs
# 3 hapless
# 147 happen
# 235 happened
# 48 happening
# 6 happenings
# 87 happens
# 7 happier
# 8 happily
# 10 happiness
# 93 happy
# 4 harassed
# 5 harassing
# 752 hard
# 3 hardcover
# 9 harder
# 34 hardly
# 5 harm
# 3 harrowing
# 4 harsh
# 776 has
# 14 hasn
# 3 hasty
# 3 hat
# 74 hate
# 84 hated
# 3 hates
# 6 hating
# 3 hatred
# 7 haunted
# 14 haunting
# 1476 have
# 56 haven
# 107 having
# 8 hawkin
# 467 hawkins
# 5 haze
# 126 he
# 77 head
# 15 headed
# 6 heading
# 15 headings
# 13 heads
# 5 health
# 3 heap
# 35 hear
# 77 heard
# 23 hearing
# 31 heart
# 5 heartbreaking
# 3 hearted
# 3 heat
# 3 heavier
# 10 heavily
# 13 heavy
# 7 heck
# 181 held
# 9 hell
# 86 help
# 17 helped
# 5 helpful
# 13 helpless
# 13 helps
# 1856 her
# 119 here
# 12 hero
# 5 heroes
# 3 heroic
# 63 heroine
# 7 heroines
# 6 herring
# 15 herrings
# 5 hers
# 159 herself
# 8 hesitant
# 7 hey
# 11 hidden
# 8 hide
# 3 hiding
# 69 high
# 7 higher
# 4 highlight
# 3 highlighted
# 418 highly
# 3 hilarious
# 4 hill
# 42 him
# 8 hint
# 11 hints
# 4 hipwell
# 138 his
# 4 historical
# 6 history
# 32 hit
# 98 hitchcock
# 20 hitchcockian
# 3 hits
# 3 hmmm
# 5 ho
# 63 hold
# 12 holding
# 38 holds
# 10 hole
# 13 holes
# 10 holiday
# 12 hollywood
# 3 holmes
# 3 holy
# 98 home
# 23 homes
# 30 honest
# 43 honestly
# 3 honesty
# 4 hook
# 132 hooked
# 12 hooks
# 12 hoopla
# 122 hope
# 15 hoped
# 8 hopeful
# 9 hopefully
# 8 hopeless
# 4 hopelessly
# 4 hopelessness
# 30 hopes
# 73 hoping
# 3 hopping
# 4 horny
# 40 horrible
# 4 horribly
# 7 horrid
# 4 horrific
# 7 horror
# 22 hot
# 21 hour
# 78 hours
# 87 house
# 64 houses
# 3 housewife
# 3 housewives
# 658 how
# 289 however
# 6 http
# 36 huge
# 4 huh
# 4 hum
# 80 human
# 11 humanity
# 5 humans
# 3 humble
# 17 humor
# 4 hundred
# 5 hundreds
# 9 hung
# 3 hunger
# 4 hungover
# 8 hurry
# 7 hurt
# 251 husband
# 8 husbands
# 157 hype
# 17 hyped
# 4 hypnotic
# 84 idea
# 14 ideal
# 3 idealized
# 6 ideas
# 4 identical
# 8 identified
# 31 identify
# 7 identifying
# 3 identities
# 13 identity
# 5 idiot
# 3 idyllic
# 1018 if
# 3 ignore
# 3 ignoring
# 3 ii
# 9 ill
# 10 illness
# 4 illusion
# 3 illusions
# 6 image
# 4 imagery
# 12 imaginary
# 49 imagination
# 12 imaginative
# 45 imagine
# 25 imagined
# 18 imagines
# 14 imagining
# 3 immature
# 46 immediately
# 20 immensely
# 4 immerse
# 5 immersed
# 3 immoral
# 4 imo
# 6 impact
# 3 impatient
# 7 imperfect
# 3 imperfections
# 12 implausible
# 39 important
# 31 impossible
# 24 impressed
# 5 impression
# 4 impressions
# 8 impressive
# 4 improbable
# 9 improve
# 6 improved
# 3 improvement
# 4300 in
# 8 inability
# 4 inane
# 4 incidents
# 3 inclined
# 5 included
# 28 including
# 3 incompetent
# 3 increases
# 6 increasingly
# 19 incredible
# 39 incredibly
# 19 indeed
# 3 independent
# 3 indicated
# 3 indication
# 3 indistinguishable
# 17 individual
# 13 individuals
# 5 induced
# 7 inevitable
# 4 inevitably
# 3 infant
# 4 infertility
# 15 infidelity
# 6 info
# 50 information
# 4 infuriating
# 3 ingenious
# 3 ingredients
# 4 inhabitants
# 10 initial
# 32 initially
# 21 inner
# 4 innocent
# 7 innovative
# 3 input
# 6 insane
# 3 insanely
# 3 insanity
# 7 insecure
# 6 insecurities
# 3 insecurity
# 8 insert
# 4 inserting
# 6 inserts
# 32 inside
# 26 insight
# 8 insightful
# 9 insights
# 6 insinuates
# 4 inspiration
# 5 inspired
# 7 instance
# 5 instant
# 4 instantly
# 73 instead
# 3 insulting
# 5 intelligence
# 6 intelligent
# 17 intended
# 39 intense
# 4 intensely
# 8 intensity
# 5 intent
# 3 intention
# 4 intentions
# 3 inter
# 3 interact
# 8 interaction
# 9 interactions
# 3 interacts
# 6 interchangeable
# 3 interconnected
# 394 interest
# 198 interested
# 996 interesting
# 10 interestingly
# 5 interests
# 17 internal
# 3 interplay
# 5 interrupted
# 5 intersect
# 10 intertwine
# 31 intertwined
# 3 interview
# 4 interweaving
# 7 interwoven
# 4 intimately
# 930 into
# 3 intoxicating
# 3 intrest
# 3 intricacy
# 14 intricate
# 4 intricately
# 58 intrigue
# 54 intrigued
# 230 intriguing
# 3 intriquing
# 13 introduced
# 3 introduces
# 5 introducing
# 6 introduction
# 4 introspective
# 3 inventing
# 9 inventive
# 3 invents
# 3 invest
# 21 invested
# 3 investigate
# 27 investigation
# 5 investigator
# 106 involved
# 5 involvement
# 10 involves
# 11 involving
# 5 ironically
# 6 irrational
# 10 irritated
# 15 irritating
# 4563 is
# 7 ish
# 99 isn
# 11 issue
# 70 issues
# 12091 it
# 214 its
# 56 itself
# 5 jacket
# 4 james
# 67 jason
# 9 jealous
# 5 jealousy
# 4 jeff
# 99 jess
# 3 jesse
# 4 jilted
# 182 job
# 3 jobless
# 5 jobs
# 4 join
# 5 jones
# 7 journal
# 3 journalist
# 36 journey
# 4 journeys
# 16 joy
# 6 judge
# 3 judgement
# 5 judgemental
# 5 judgment
# 3 juicy
# 4 jumbled
# 17 jump
# 24 jumped
# 32 jumping
# 37 jumps
# 1214 just
# 7 justice
# 3 justify
# 3 juvenile
# 11 kamal
# 2 kate
# 6 keen
# 590 keep
# 77 keeping
# 446 keeps
# 2 keira
# 1269 kept
# 33 key
# 5 kick
# 3 kicked
# 2 kicking
# 2 kicks
# 2 kid
# 4 kidding
# 7 kids
# 7 kill
# 29 killed
# 137 killer
# 3 killers
# 4 killing
# 223 kind
# 9 kinda
# 116 kindle
# 7 kinds
# 5 king
# 3 kiss
# 22 kissing
# 3 kitchen
# 124 knew
# 8 knock
# 4 knocked
# 2 knots
# 593 know
# 35 knowing
# 8 knowledge
# 26 known
# 56 knows
# 7 kudos
# 6 la
# 3 label
# 3 labeled
# 7 laborious
# 31 lack
# 20 lacked
# 11 lacking
# 2 lackluster
# 14 lacks
# 4 laden
# 9 ladies
# 17 lady
# 14 laid
# 10 lame
# 3 land
# 2 landing
# 7 landlady
# 5 landlord
# 3 landscape
# 25 language
# 5 lapses
# 9 large
# 2 largely
# 3 larger
# 314 last
# 2 lasting
# 56 late
# 12 lately
# 50 later
# 3 latest
# 4 latter
# 4 laugh
# 2 laughable
# 3 laughed
# 2 laughing
# 6 law
# 2 lay
# 8 layer
# 4 layered
# 15 layers
# 2 layout
# 13 lazy
# 70 lead
# 27 leading
# 20 leads
# 8 league
# 2 leaked
# 6 leaps
# 44 learn
# 16 learned
# 7 learning
# 14 learns
# 121 least
# 60 leave
# 30 leaves
# 14 leaving
# 29 led
# 2 leery
# 152 left
# 3 lend
# 2 lends
# 7 length
# 3 lengthy
# 114 less
# 4 lesser
# 8 lesson
# 2 lessons
# 112 let
# 3 letdown
# 12 lets
# 11 letting
# 35 level
# 13 levels
# 11 liar
# 4 liars
# 2 libby
# 43 library
# 3 librarything
# 12 lie
# 2 lied
# 46 lies
# 498 life
# 3 lifeless
# 20 lifetime
# 3 lifted
# 2 lifting
# 63 light
# 4 lighter
# 3 lightly
# 2 lights
# 5 lightweight
# 2 likability
# 117 likable
# 1585 like
# 2 likeability
# 85 likeable
# 587 liked
# 32 likely
# 47 likes
# 28 liking
# 8 limited
# 2 limits
# 234 line
# 4 linear
# 27 lines
# 2 linger
# 3 linked
# 2 links
# 2 lip
# 2 liquor
# 174 list
# 6 listed
# 25 listen
# 37 listened
# 3 listener
# 33 listening
# 3 listing
# 16 lists
# 8 lit
# 39 literally
# 42 literary
# 40 literature
# 787 little
# 110 live
# 51 lived
# 4 lively
# 315 lives
# 54 living
# 190 ll
# 2 loads
# 3 loaned
# 2 loathe
# 16 loathing
# 2 loathsome
# 10 local
# 6 location
# 5 locked
# 5 logic
# 4 logical
# 8 lol
# 99 london
# 6 loneliness
# 19 lonely
# 406 long
# 3 longed
# 40 longer
# 2 longest
# 2 longing
# 141 look
# 29 looked
# 225 looking
# 15 looks
# 4 loop
# 27 loose
# 3 loosely
# 2 looseness
# 2 looses
# 2 lord
# 23 lose
# 12 loser
# 6 losers
# 3 loses
# 14 losing
# 22 loss
# 3 losses
# 124 lost
# 310 lot
# 239 lots
# 5 loud
# 4 louise
# 2 lounging
# 4 lovable
# 495 love
# 2 loveable
# 1008 loved
# 8 lovely
# 14 lover
# 14 lovers
# 27 loves
# 16 loving
# 20 low
# 4 lower
# 4 luck
# 3 luckiest
# 6 luckily
# 4 lucky
# 2 lull
# 3 lunch
# 2 lush
# 3 lust
# 2 luster
# 27 lying
# 2 lyrics
# 9 mad
# 3 maddening
# 384 made
# 6 madness
# 4 magazine
# 3 magazines
# 4 magnificent
# 744 main
# 10 mainly
# 2 mainstream
# 3 maintain
# 2 maintained
# 2 maintains
# 32 major
# 11 majority
# 366 make
# 224 makes
# 113 making
# 38 male
# 5 males
# 83 man
# 10 manage
# 7 managed
# 8 manages
# 2 manic
# 12 manipulated
# 11 manipulation
# 12 manipulative
# 2 mankind
# 16 manner
# 575 many
# 3 map
# 2 march
# 6 marital
# 20 mark
# 2 marked
# 2 marketed
# 9 marketing
# 2 marks
# 48 marriage
# 5 marriages
# 46 married
# 2 marry
# 2 marrying
# 2 marvelous
# 3 marvelously
# 3 mary
# 2 mask
# 3 mass
# 2 masses
# 2 massive
# 5 master
# 13 masterful
# 6 masterfully
# 13 masterpiece
# 6 match
# 4 mate
# 10 material
# 37 matter
# 5 matters
# 3 mature
# 2 maturity
# 132 may
# 151 maybe
# 2 mayhem
# 2 mc
# 2 mccarthy
# 2330 me
# 13 meagan
# 25 mean
# 4 meandering
# 2 meanders
# 10 meaning
# 3 meaningful
# 3 meaningless
# 14 means
# 15 meant
# 2 meantime
# 3 measure
# 4 meat
# 2 mechanical
# 2 meddles
# 2 meddlesome
# 3 meddling
# 6 media
# 17 mediocre
# 24 meet
# 8 meeting
# 10 meets
# 2 meg
# 358 megan
# 10 meghan
# 15 meh
# 3 melancholy
# 6 melodrama
# 2 melodramatic
# 3 member
# 10 members
# 12 memorable
# 39 memories
# 43 memory
# 116 men
# 38 mental
# 14 mentally
# 11 mention
# 17 mentioned
# 2 mentions
# 2 mercifully
# 8 merely
# 3 merge
# 2 merging
# 4 merit
# 2 mesmerising
# 7 mesmerized
# 17 mesmerizing
# 50 mess
# 10 message
# 27 messed
# 6 messes
# 5 messy
# 12 met
# 6 method
# 3 methodically
# 4 metro
# 12 mid
# 120 middle
# 6 midnight
# 2 midpoint
# 11 midway
# 126 might
# 5 mild
# 8 mildly
# 4 mile
# 3 miles
# 2 mill
# 182 mind
# 2 minded
# 6 mindless
# 22 minds
# 4 mindset
# 12 mine
# 4 minimum
# 16 minor
# 14 minority
# 2 minus
# 56 minute
# 10 minutes
# 2 miraculously
# 2 mired
# 2 misadventures
# 5 misdirection
# 33 miserable
# 2 miserably
# 10 misery
# 2 misfit
# 4 misfortune
# 2 mislead
# 8 misleading
# 2 misled
# 3 misplaced
# 37 miss
# 29 missed
# 2 misses
# 105 missing
# 2 missteps
# 17 mistake
# 4 mistaken
# 23 mistakes
# 18 mistress
# 11 mix
# 23 mixed
# 3 mixing
# 3 mixture
# 3 mode
# 5 moderately
# 18 modern
# 6 mom
# 48 moment
# 34 moments
# 9 momentum
# 77 money
# 4 monologue
# 4 monologues
# 13 monotonous
# 2 monstrous
# 21 month
# 3 monthly
# 37 months
# 10 mood
# 3 moody
# 2 mopey
# 5 moral
# 4 morality
# 2 morally
# 3 morals
# 6 morbid
# 1102 more
# 3 moriarty
# 62 morning
# 328 most
# 42 mostly
# 16 mother
# 3 mothers
# 3 motif
# 7 motion
# 5 motivated
# 8 motivation
# 14 motivations
# 4 motive
# 8 motives
# 3 mould
# 4 mouth
# 43 move
# 63 moved
# 61 moves
# 323 movie
# 10 movies
# 102 moving
# 66 ms
# 852 much
# 5 muddled
# 6 multi
# 76 multiple
# 9 mundane
# 215 murder
# 25 murdered
# 55 murderer
# 3 musings
# 222 must
# 3 muster
# 1758 my
# 220 myself
# 104 mysteries
# 25 mysterious
# 3 mysteriously
# 902 mystery
# 7 nail
# 4 nailed
# 43 name
# 22 named
# 81 names
# 8 narcissistic
# 5 narcissists
# 10 narrate
# 33 narrated
# 23 narrating
# 75 narration
# 8 narrations
# 120 narrative
# 24 narratives
# 141 narrator
# 132 narrators
# 4 nasty
# 4 natural
# 15 nature
# 5 nd
# 78 near
# 3 nearby
# 32 nearly
# 5 neat
# 6 neatly
# 16 necessarily
# 16 necessary
# 5 neck
# 125 need
# 73 needed
# 4 needing
# 3 needless
# 31 needs
# 15 needy
# 31 negative
# 3 neglected
# 9 neighbor
# 21 neighborhood
# 3 neighborhoods
# 10 neighbors
# 19 neither
# 4 nerves
# 5 nervous
# 4 netflix
# 12 neurotic
# 2 neurotics
# 386 never
# 14 nevertheless
# 202 new
# 7 news
# 2 newspaper
# 343 next
# 119 nice
# 33 nicely
# 2 nick
# 3 nicknames
# 151 night
# 5 nightmare
# 3 nightmares
# 23 nights
# 2 nit
# 2 njoyed
# 589 no
# 7 nobody
# 6 noir
# 2 noise
# 30 non
# 105 none
# 24 nonetheless
# 2 nonfiction
# 3 nonsense
# 2 nonstop
# 4 nope
# 29 nor
# 2 norm
# 26 normal
# 37 normally
# 4 nose
# 3 nostalgic
# 2 nosy
# 3484 not
# 2 notable
# 2 notch
# 12 note
# 7 noted
# 4 notes
# 5 noteworthy
# 173 nothing
# 19 notice
# 10 noticed
# 7 notices
# 2 noting
# 705 novel
# 2 novelist
# 114 novels
# 186 now
# 12 nowhere
# 3 nt
# 3 nuance
# 5 nuanced
# 3 nuances
# 57 number
# 2 numbers
# 5 numbing
# 5 numerous
# 2 nursery
# 2 nursing
# 5 nut
# 8 nuts
# 15 ny
# 3 nyc
# 2 nymphomaniac
# 10 nyt
# 4 nytimes
# 2 obfuscation
# 4 object
# 2 objective
# 5 objects
# 3 oblivion
# 2 obnoxious
# 7 observation
# 13 observations
# 3 observe
# 9 observed
# 12 observer
# 22 observes
# 7 observing
# 3 obsess
# 29 obsessed
# 2 obsesses
# 7 obsessing
# 19 obsession
# 5 obsessions
# 10 obsessive
# 2 obsessively
# 52 obvious
# 22 obviously
# 2 occasion
# 4 occasional
# 8 occasionally
# 2 occasions
# 4 occupants
# 7 occupied
# 2 occur
# 10 occurred
# 3 occurrences
# 2 occurring
# 10 occurs
# 18 odd
# 8 oddly
# 3 odds
# 7662 of
# 219 off
# 4 offended
# 2 offense
# 6 offensive
# 8 offer
# 3 offered
# 5 offering
# 7 offers
# 6 office
# 3 officers
# 2 officials
# 112 often
# 42 oh
# 182 ok
# 110 okay
# 76 old
# 6 older
# 2 oldest
# 12 omg
# 2 ominous
# 2 omitted
# 2588 on
# 410 once
# 1767 one
# 24 ones
# 2 oneself
# 5 ongoing
# 3 onion
# 2 online
# 439 only
# 5 onset
# 9 onto
# 3 oops
# 18 open
# 5 opened
# 10 opening
# 2 opens
# 19 opera
# 77 opinion
# 11 opinions
# 3 opportunities
# 14 opportunity
# 7 opposite
# 2 option
# 2 optioned
# 2 options
# 853 or
# 38 order
# 9 ordered
# 2 ordering
# 2 ordinarily
# 18 ordinary
# 6 organization
# 2 organized
# 2 oriented
# 36 original
# 2 originality
# 7 originally
# 3 ot
# 399 other
# 149 others
# 44 otherwise
# 2 ought
# 138 our
# 13 ourselves
# 1438 out
# 2 outbound
# 60 outcome
# 4 outcomes
# 3 outlandish
# 2 outlook
# 10 outs
# 3 outset
# 22 outside
# 13 outstanding
# 293 over
# 2 overactive
# 206 overall
# 6 overcome
# 2 overcoming
# 5 overdone
# 3 overhyped
# 3 overlap
# 3 overlapping
# 26 overly
# 2 overnight
# 15 overrated
# 2 overseas
# 2 overuse
# 2 overview
# 4 overweight
# 4 overwhelmed
# 8 overwhelming
# 194 own
# 2 oz
# 128 pace
# 165 paced
# 20 pacing
# 6 packed
# 2 pad
# 904 page
# 3 pager
# 316 pages
# 2 pageturner
# 21 paid
# 24 pain
# 17 painful
# 10 painfully
# 2 pains
# 5 painted
# 2 painting
# 2 paintings
# 2 paints
# 2 pair
# 2 pale
# 2 pales
# 2 pan
# 4 pants
# 12 paper
# 3 paperback
# 6 par
# 13 paragraph
# 6 paragraphs
# 5 parallel
# 3 parallels
# 3 paranoia
# 3 paranoid
# 3 parents
# 3 park
# 191 part
# 2 participant
# 2 participants
# 26 particular
# 71 particularly
# 3 partly
# 2 partner
# 83 parts
# 15 party
# 2 pas
# 41 pass
# 4 passages
# 23 passed
# 6 passenger
# 8 passengers
# 42 passes
# 23 passing
# 3 passion
# 2 passionately
# 5 passive
# 134 past
# 2 pasts
# 3 pat
# 12 path
# 112 pathetic
# 2 pathetically
# 6 pathological
# 2 pathologies
# 3 pathos
# 5 paths
# 20 patience
# 10 patient
# 2 patiently
# 6 patio
# 3 patricia
# 5 pattern
# 5 patterns
# 4 patterson
# 4 paul
# 261 paula
# 88 pay
# 9 paying
# 4 payoff
# 3 peace
# 2 peaceful
# 3 peak
# 4 peaked
# 2 peculiar
# 2 pedantic
# 2 pedestrian
# 2 peek
# 3 peeking
# 2 peeks
# 2 peel
# 2 peeling
# 3 peeping
# 2 peered
# 4 peeve
# 2 peeved
# 3 penny
# 610 people
# 7 peoples
# 5 per
# 3 perceive
# 4 perceived
# 2 percent
# 12 perception
# 3 perceptions
# 152 perfect
# 3 perfection
# 27 perfectly
# 2 perfunctory
# 81 perhaps
# 15 period
# 11 periods
# 3 permanent
# 3 perp
# 9 perpetrator
# 2 perplexed
# 2 perplexing
# 3 perseverance
# 2 persevere
# 8 persevered
# 2 persisted
# 3 persistent
# 343 person
# 40 personal
# 34 personalities
# 40 personality
# 26 personally
# 21 persons
# 141 perspective
# 144 perspectives
# 2 pessimistic
# 3 pet
# 2 petty
# 2 pg
# 6 phenomenal
# 2 phenomenally
# 2 philandering
# 13 phone
# 2 photo
# 2 phrase
# 2 phrases
# 13 physical
# 2 physically
# 83 pick
# 110 picked
# 21 picking
# 46 picks
# 43 picture
# 5 pictures
# 38 piece
# 2 pieced
# 40 pieces
# 5 piecing
# 2 pig
# 9 pile
# 2 piles
# 2 pin
# 2 pining
# 2 pinnacle
# 4 piqued
# 2 pit
# 3 pitiable
# 15 pitiful
# 2 pitt
# 38 pity
# 4 pitying
# 71 place
# 8 placed
# 38 places
# 12 plain
# 9 plan
# 24 plane
# 7 planned
# 5 planning
# 18 plausible
# 39 play
# 14 played
# 10 players
# 10 playing
# 9 plays
# 7 pleasant
# 15 pleasantly
# 26 please
# 10 pleased
# 17 pleasure
# 26 plenty
# 8 plodded
# 16 plodding
# 919 plot
# 21 plots
# 14 plotted
# 12 plotting
# 3 plow
# 3 ploy
# 21 plus
# 3 pm
# 5 poetic
# 251 point
# 6 pointless
# 118 points
# 53 police
# 3 polished
# 4 ponderous
# 7 pool
# 53 poor
# 37 poorly
# 6 pop
# 3 popping
# 42 popular
# 16 popularity
# 3 populated
# 6 portion
# 3 portions
# 8 portrait
# 3 portray
# 15 portrayal
# 26 portrayed
# 5 portraying
# 4 portrays
# 41 positive
# 8 possibilities
# 6 possibility
# 36 possible
# 23 possibly
# 11 post
# 6 posted
# 21 potential
# 3 potentially
# 4 pounding
# 3 pour
# 40 pov
# 7 povs
# 10 power
# 11 powerful
# 4 practically
# 14 praise
# 2 praising
# 4 pray
# 2 praying
# 3 pre
# 2 preceding
# 3 precious
# 2 precisely
# 3 predicable
# 34 predict
# 6 predictability
# 337 predictable
# 5 predictably
# 14 predicted
# 2 predicting
# 3 prediction
# 14 prefer
# 2 preference
# 9 preferred
# 6 pregnancy
# 13 pregnant
# 2 prejudice
# 82 premise
# 2 preoccupation
# 3 prepare
# 21 prepared
# 2 preposterous
# 44 present
# 6 presentation
# 30 presented
# 3 presenting
# 4 presents
# 4 press
# 2 pressing
# 3 pressure
# 2 presumably
# 2 presumed
# 4 pretend
# 3 pretending
# 6 pretends
# 2 pretense
# 3 pretentious
# 251 pretty
# 3 prevalent
# 2 prevents
# 11 previous
# 5 previously
# 14 price
# 3 pride
# 8 primarily
# 20 primary
# 3 prime
# 8 principal
# 5 print
# 2 printed
# 8 prior
# 6 private
# 126 probably
# 115 problem
# 3 problematic
# 61 problems
# 3 procedural
# 3 proceed
# 3 proceeds
# 10 process
# 6 processes
# 4 produce
# 3 producing
# 5 product
# 4 profanity
# 2 professional
# 3 profile
# 11 profound
# 3 program
# 4 progress
# 19 progressed
# 12 progresses
# 6 progression
# 3 progressively
# 11 promise
# 8 promised
# 5 promises
# 12 promising
# 3 promotion
# 2 promptly
# 3 prone
# 3 pronouns
# 2 proof
# 2 propel
# 3 propels
# 3 proper
# 2 properly
# 3 props
# 3 prosaic
# 21 prose
# 119 protagonist
# 23 protagonists
# 3 proud
# 6 prove
# 6 proved
# 5 proverbial
# 2 proves
# 5 provide
# 10 provided
# 16 provides
# 5 providing
# 2 provocative
# 17 provoking
# 3 proximity
# 3 pseudo
# 7 psyche
# 2 psychiatric
# 6 psychiatrist
# 2 psychic
# 13 psycho
# 179 psychological
# 12 psychologically
# 4 psychologist
# 5 psychology
# 5 psychopath
# 3 psychopaths
# 5 psychosis
# 7 psychotic
# 7 public
# 3 publication
# 6 publicity
# 13 published
# 11 publisher
# 4 publishers
# 2 publishes
# 2 puffy
# 19 pull
# 29 pulled
# 10 pulling
# 29 pulls
# 13 pun
# 4 punch
# 2 punishment
# 10 purchase
# 32 purchased
# 4 purchasing
# 6 pure
# 3 purely
# 18 purpose
# 2 purposely
# 4 pursuit
# 10 push
# 7 pushed
# 2 pushes
# 6 pushing
# 1977 put
# 2 putit
# 9 puts
# 92 putting
# 20 puzzle
# 4 puzzled
# 3 puzzles
# 3 puzzling
# 48 qualities
# 37 quality
# 20 quarter
# 11 quarters
# 2 quest
# 41 question
# 6 questionable
# 13 questioning
# 29 questions
# 2 queue
# 2 quibbles
# 304 quick
# 4 quicker
# 160 quickly
# 3 quiet
# 2 quietly
# 3 quirks
# 10 quirky
# 37 quit
# 291 quite
# 2 quitting
# 2 quote
# 3 rabbit
# 3 race
# 2 rach
# 45 rachael
# 1266 rachel
# 3 rachell
# 2 rachels
# 11 racing
# 4 rage
# 6 raging
# 9 rail
# 4 railroad
# 3 rails
# 2 railway
# 4 rain
# 2 rains
# 19 rainy
# 2 raise
# 2 raises
# 2 rambles
# 5 rambling
# 7 ramblings
# 5 ran
# 6 random
# 7 range
# 3 rank
# 3 ranking
# 2 ranks
# 2 ranting
# 3 rapid
# 3 rapidly
# 18 rare
# 14 rarely
# 28 rate
# 31 rated
# 3 rates
# 136 rather
# 41 rating
# 8 ratings
# 2 rats
# 3 rattles
# 24 rave
# 4 raved
# 2 raves
# 17 raving
# 11 raw
# 4 rd
# 188 re
# 27 reach
# 13 reached
# 3 reaches
# 5 reaching
# 3 react
# 2 reacted
# 5 reaction
# 5212 read
# 20 readable
# 397 reader
# 139 readers
# 2 readily
# 1487 reading
# 54 reads
# 32 ready
# 429 real
# 3 realise
# 3 realised
# 2 realises
# 4 realism
# 54 realistic
# 4 realistically
# 2 realities
# 57 reality
# 2 realization
# 46 realize
# 34 realized
# 5 realizes
# 4 realizing
# 1402 really
# 2 realm
# 2 realy
# 52 rear
# 85 reason
# 3 reasonable
# 8 reasonably
# 22 reasons
# 2 rebuild
# 12 recall
# 3 recalling
# 2 recalls
# 2 recap
# 2 reccomend
# 2 reccommend
# 18 received
# 4 receiving
# 15 recent
# 18 recently
# 2 reckless
# 3 reckoned
# 2 recognizable
# 7 recognize
# 2 recommed
# 914 recommend
# 18 recommendation
# 8 recommendations
# 198 recommended
# 23 recommending
# 3 record
# 2 recovered
# 2 recovering
# 4 recovery
# 2 recurring
# 39 red
# 9 redeem
# 8 redeemable
# 6 redeemed
# 80 redeeming
# 15 redemption
# 2 redheaded
# 2 reduced
# 19 redundant
# 3 reel
# 3 reeling
# 2 reels
# 5 refer
# 3 reference
# 2 referenced
# 4 references
# 6 referred
# 2 referring
# 2 refers
# 3 reflected
# 3 reflecting
# 3 reflection
# 2 reflections
# 15 refreshing
# 5 refreshingly
# 2 refund
# 4 refused
# 2 regain
# 6 regard
# 9 regarding
# 4 regardless
# 20 regret
# 2 regretfully
# 12 regular
# 9 regularly
# 3 rejection
# 2 relapses
# 20 relatable
# 60 relate
# 16 related
# 2 relates
# 9 relating
# 3 relations
# 35 relationship
# 46 relationships
# 2 relative
# 8 relatively
# 2 relax
# 2 relaxation
# 8 relaxing
# 7 release
# 5 released
# 2 releases
# 6 relentless
# 3 relentlessly
# 4 relevant
# 2 reliability
# 17 reliable
# 2 relied
# 8 relief
# 5 relies
# 6 relieved
# 2 relished
# 4 rely
# 6 remain
# 2 remainder
# 9 remained
# 3 remaining
# 7 remains
# 6 remarkable
# 4 remarkably
# 2 remarks
# 6 remarried
# 100 remember
# 2 remembered
# 13 remembering
# 11 remembers
# 17 remind
# 100 reminded
# 2 reminder
# 3 reminding
# 39 reminds
# 27 reminiscent
# 9 remotely
# 4 removed
# 3 rendell
# 2 rendered
# 5 rent
# 2 renting
# 2 rents
# 2 repair
# 8 repeat
# 13 repeated
# 8 repeatedly
# 13 repeating
# 11 repetition
# 14 repetitious
# 83 repetitive
# 2 repetitiveness
# 4 replace
# 3 replaced
# 4 report
# 6 reported
# 2 reports
# 3 represent
# 3 represents
# 2 repugnant
# 3 reputation
# 2 require
# 10 required
# 2 requirement
# 2 requires
# 2 requisite
# 11 reread
# 3 research
# 2 researched
# 2 resented
# 2 reservation
# 2 residents
# 3 resides
# 2 resilient
# 3 resist
# 28 resolution
# 5 resolve
# 10 resolved
# 12 respect
# 2 respecting
# 2 respective
# 2 responded
# 5 response
# 3 responses
# 2 responsibilities
# 5 responsibility
# 9 responsible
# 44 rest
# 3 restless
# 2 restored
# 15 result
# 4 resulting
# 2 results
# 2 retell
# 2 retired
# 14 return
# 3 returning
# 59 reveal
# 74 revealed
# 20 revealing
# 25 reveals
# 7 revelation
# 8 revelations
# 4 revenge
# 2 reverse
# 2 reverting
# 107 review
# 7 reviewed
# 15 reviewer
# 45 reviewers
# 3 reviewing
# 262 reviews
# 2 revise
# 5 revolve
# 2 revolved
# 5 revolves
# 2 revolving
# 2 rewarded
# 2 rhyme
# 7 rhythm
# 13 rich
# 5 richly
# 2 richness
# 3 rid
# 5 ridden
# 157 ride
# 3 rider
# 67 rides
# 24 ridiculous
# 4 ridiculously
# 37 riding
# 262 right
# 3 righteous
# 11 rights
# 2 riley
# 6 ring
# 2 rings
# 4 rip
# 4 ripped
# 2 rise
# 2 rising
# 4 risk
# 2 riverhead
# 9 riveted
# 84 riveting
# 27 road
# 2 robbed
# 2 robert
# 5 rock
# 6 rode
# 15 role
# 6 roles
# 6 roll
# 3 rolled
# 14 roller
# 5 rollercoaster
# 11 rolling
# 12 romance
# 2 romances
# 7 romantic
# 5 romp
# 20 room
# 27 roommate
# 41 root
# 26 rooting
# 3 roots
# 2 rose
# 2 rotating
# 14 round
# 6 rounded
# 15 route
# 2 routes
# 3 routines
# 2 routing
# 6 row
# 2 rubbish
# 3 rude
# 9 ruin
# 7 ruined
# 2 ruining
# 5 ruins
# 5 rule
# 2 rules
# 22 run
# 4 runaway
# 9 running
# 7 runs
# 9 rush
# 17 rushed
# 2 rushing
# 6 ruth
# 2 sack
# 2 sacked
# 152 sad
# 24 sadly
# 8 sadness
# 5 safe
# 4 saga
# 148 said
# 5 sake
# 5 sale
# 2 sales
# 3 salt
# 2 sam
# 309 same
# 16 sample
# 3 san
# 2 sand
# 5 sane
# 8 sanity
# 2 sans
# 3 sappy
# 4 sarah
# 8 sat
# 4 satisfaction
# 5 satisfactory
# 12 satisfied
# 2 satisfies
# 4 satisfy
# 87 satisfying
# 4 satisfyingly
# 12 saturday
# 16 save
# 6 saved
# 5 saving
# 4 savor
# 99 saw
# 298 say
# 32 saying
# 20 says
# 3 scale
# 3 scales
# 2 scandalous
# 3 scare
# 8 scared
# 12 scary
# 2 scattered
# 8 scenario
# 12 scenarios
# 29 scene
# 5 scenery
# 27 scenes
# 5 schedule
# 5 schizophrenic
# 3 school
# 2 scooby
# 2 score
# 3 scorned
# 80 scott
# 2 scratching
# 8 scream
# 2 screams
# 12 screen
# 6 screenplay
# 3 screw
# 13 screwed
# 3 script
# 2 scrutiny
# 4 seamlessly
# 5 searching
# 4 seasoned
# 138 seat
# 3 seats
# 76 second
# 4 secondary
# 12 secret
# 27 secrets
# 8 section
# 9 sections
# 568 see
# 45 seeing
# 6 seek
# 6 seeking
# 113 seem
# 154 seemed
# 31 seemingly
# 126 seems
# 65 seen
# 122 sees
# 3 segments
# 7 seldom
# 5 selected
# 11 selection
# 3 selections
# 171 self
# 26 selfish
# 3 sell
# 176 seller
# 20 sellers
# 10 selling
# 7 semi
# 112 sense
# 7 senses
# 3 sensitive
# 3 sent
# 20 sentence
# 4 sentences
# 19 separate
# 5 separated
# 4 separating
# 11 sequel
# 3 sequence
# 5 serial
# 10 series
# 15 serious
# 16 seriously
# 5 serve
# 9 served
# 7 serving
# 7 sessions
# 68 set
# 8 sets
# 58 setting
# 7 settings
# 5 settle
# 4 settled
# 6 setup
# 167 several
# 3 severe
# 4 severely
# 17 sex
# 3 sexist
# 13 sexual
# 4 shade
# 12 shades
# 2 shadow
# 2 shady
# 2 shaggy
# 22 shake
# 3 shakes
# 5 shaking
# 5 shall
# 35 shallow
# 3 shambles
# 15 shame
# 6 shape
# 3 shaped
# 26 share
# 13 shared
# 3 sharing
# 12 sharp
# 2 sharply
# 4 shattered
# 2 shattering
# 2 shatters
# 1866 she
# 7 sheer
# 3 shelf
# 3 sherlock
# 5 shift
# 6 shifted
# 19 shifting
# 13 shifts
# 2 shine
# 2 shines
# 2 shipping
# 7 shock
# 22 shocked
# 8 shocker
# 39 shocking
# 2 shocks
# 3 shop
# 2 shopping
# 58 short
# 10 shorter
# 8 shot
# 166 should
# 2 shoulder
# 16 shouldn
# 3 shout
# 26 show
# 6 showed
# 4 shower
# 6 showing
# 7 shown
# 26 shows
# 2 shrink
# 36 sick
# 2 sickening
# 51 side
# 10 sides
# 6 sigh
# 5 sight
# 4 sign
# 16 signal
# 2 signals
# 6 significant
# 3 significantly
# 16 silly
# 2 silver
# 171 similar
# 20 similarities
# 6 similarity
# 4 similarly
# 28 simple
# 8 simplistic
# 2 simplistically
# 55 simply
# 10 simultaneously
# 138 since
# 2 sincerely
# 2 sing
# 48 single
# 3 singular
# 13 sinister
# 2 sinks
# 2 sins
# 11 sister
# 12 sit
# 3 site
# 2 sits
# 59 sitting
# 8 sittings
# 35 situation
# 22 situations
# 3 six
# 2 sixth
# 2 skeletons
# 5 skeptical
# 6 skill
# 5 skilled
# 10 skillful
# 9 skillfully
# 8 skills
# 2 skim
# 7 skimmed
# 9 skimming
# 4 skin
# 17 skip
# 11 skipped
# 8 skipping
# 2 skips
# 2 skull
# 2 sky
# 2 slam
# 2 slams
# 3 slang
# 7 slap
# 49 sleep
# 8 sleeping
# 2 sleeps
# 3 slept
# 6 sleuth
# 2 sleuths
# 2 slice
# 2 slide
# 4 slight
# 3 slightest
# 44 slightly
# 3 slipped
# 5 slog
# 3 slogging
# 6 sloppy
# 707 slow
# 2 slowed
# 5 slower
# 4 slowing
# 126 slowly
# 5 slows
# 6 smack
# 28 small
# 16 smart
# 2 smarter
# 2 smell
# 2 smidge
# 2 smoke
# 6 smooth
# 3 smoothly
# 2 snail
# 3 snap
# 2 snapped
# 2 snappy
# 2 snatched
# 3 sneak
# 4 sneaking
# 3 sneaks
# 2 sniveling
# 3 snow
# 2 snowy
# 1770 so
# 2 soak
# 5 soaked
# 21 soap
# 15 sober
# 5 sobriety
# 7 social
# 2 societal
# 8 society
# 2 socio
# 12 sociopath
# 3 sociopathic
# 5 sociopaths
# 5 socks
# 2 solace
# 5 sold
# 3 solely
# 30 solid
# 3 solidly
# 2 soliloquy
# 2 solitary
# 13 solution
# 2 solutions
# 39 solve
# 21 solved
# 2 solves
# 19 solving
# 3 somber
# 707 some
# 4 somebody
# 2 someday
# 40 somehow
# 148 someone
# 335 something
# 10 sometime
# 103 sometimes
# 168 somewhat
# 13 somewhere
# 88 soon
# 8 sooner
# 3 sooo
# 3 soooo
# 3 sooooo
# 3 soooooo
# 3 sophisticated
# 6 sordid
# 3 sorely
# 7 sorrow
# 128 sorry
# 90 sort
# 2 sorta
# 6 sorted
# 5 sorting
# 10 sorts
# 13 soul
# 6 souls
# 22 sound
# 22 sounded
# 5 sounding
# 11 sounds
# 2 sources
# 4 south
# 4 space
# 5 span
# 4 spare
# 2 sparingly
# 3 spark
# 2 sparks
# 9 speak
# 2 speaker
# 4 speakers
# 54 speaking
# 5 speaks
# 15 special
# 6 specific
# 2 specifics
# 10 spectacular
# 2 spectator
# 2 speculated
# 4 speculation
# 3 sped
# 2 speech
# 2 speechless
# 49 speed
# 4 speeding
# 3 speeds
# 13 spell
# 9 spellbinding
# 6 spellbound
# 23 spend
# 7 spending
# 11 spends
# 51 spent
# 3 spice
# 4 spies
# 4 spin
# 8 spinning
# 3 spins
# 10 spiral
# 8 spirit
# 15 spite
# 9 split
# 16 spoil
# 34 spoiler
# 21 spoilers
# 5 spoiling
# 9 spoke
# 16 spot
# 16 spots
# 10 spouses
# 3 spring
# 4 spun
# 3 squandered
# 13 st
# 3 stable
# 7 stage
# 4 stages
# 8 stalker
# 9 stalking
# 5 stalks
# 25 stand
# 9 standard
# 6 standards
# 7 standing
# 3 standpoint
# 7 stands
# 82 star
# 3 staring
# 3 starring
# 220 stars
# 336 start
# 378 started
# 8 starter
# 19 starting
# 139 starts
# 21 state
# 4 stated
# 4 statement
# 3 statements
# 8 station
# 65 stay
# 49 stayed
# 12 staying
# 10 stays
# 6 steadily
# 11 steady
# 6 steam
# 4 stellar
# 11 step
# 4 stephen
# 2 stepped
# 2 steps
# 6 stereotypes
# 3 stereotypical
# 3 stewart
# 30 stick
# 6 sticking
# 2 stickler
# 297 still
# 2 stir
# 2 stock
# 4 stomach
# 4 stood
# 272 stop
# 39 stopped
# 7 stopping
# 27 stops
# 8 store
# 157 stories
# 2 storm
# 2909 story
# 124 storyline
# 6 storylines
# 8 storyteller
# 2 storytellers
# 30 storytelling
# 66 straight
# 3 straighten
# 2 straightened
# 8 straightforward
# 2 strained
# 2 strains
# 38 strange
# 4 strangely
# 12 stranger
# 17 strangers
# 8 stream
# 36 street
# 18 strength
# 5 strengths
# 2 stress
# 16 stretch
# 4 stretched
# 4 stretches
# 3 strike
# 3 string
# 3 strings
# 57 strong
# 14 stronger
# 5 strongly
# 3 struck
# 25 structure
# 9 structured
# 38 struggle
# 21 struggled
# 26 struggles
# 21 struggling
# 3 strung
# 34 stuck
# 2 student
# 3 students
# 3 studies
# 31 study
# 2 studying
# 14 stuff
# 3 stumbles
# 5 stumbling
# 3 stumped
# 2 stun
# 2 stunned
# 7 stunning
# 47 stupid
# 2 stupidest
# 5 stupidity
# 11 stupor
# 2 stupors
# 250 style
# 5 styles
# 7 sub
# 19 subject
# 2 subjected
# 2 subjective
# 4 subjects
# 2 sublime
# 2 submerged
# 2 subplots
# 2 subsequent
# 2 subsequently
# 10 substance
# 8 subtle
# 2 subtlety
# 5 subtly
# 2 suburb
# 15 suburban
# 3 suburbia
# 8 suburbs
# 2 subway
# 5 succeed
# 5 succeeded
# 3 succeeds
# 14 success
# 6 successful
# 3 successfully
# 2 succinctly
# 239 such
# 8 suck
# 30 sucked
# 2 sucker
# 2 suckered
# 11 sucks
# 14 sudden
# 36 suddenly
# 6 suffer
# 6 suffered
# 8 suffering
# 12 suffers
# 4 suffice
# 2 sufficiently
# 26 suggest
# 11 suggested
# 4 suggestion
# 2 suggests
# 2 suits
# 2 sullied
# 7 sum
# 10 summary
# 152 summer
# 2 sums
# 6 sunday
# 2 sunlight
# 2 sunny
# 5 sunshine
# 25 super
# 14 superb
# 8 superbly
# 7 superficial
# 9 superior
# 5 support
# 3 supported
# 5 supporting
# 27 suppose
# 20 supposed
# 2 supposedly
# 3 suprise
# 2 suprised
# 2 suprising
# 289 sure
# 11 surely
# 12 surface
# 2 surgery
# 251 surprise
# 149 surprised
# 105 surprises
# 94 surprising
# 11 surprisingly
# 2 surprized
# 2 surrounded
# 9 surrounding
# 2 surroundings
# 8 survive
# 35 suspect
# 20 suspected
# 29 suspects
# 6 suspence
# 3 suspenceful
# 2 suspended
# 2 suspenful
# 509 suspense
# 511 suspenseful
# 7 suspensful
# 3 suspension
# 14 suspicion
# 11 suspicions
# 8 suspicious
# 2 sustain
# 4 sustained
# 3 swallow
# 6 sweet
# 4 swept
# 3 swift
# 2 swiftly
# 3 swing
# 3 swirling
# 14 switch
# 3 switched
# 15 switches
# 42 switching
# 2 symbol
# 62 sympathetic
# 30 sympathize
# 4 sympathized
# 3 sympathizing
# 56 sympathy
# 2 sync
# 4 synopsis
# 3 system
# 5 table
# 2 tablet
# 2 tackling
# 18 tad
# 7 tail
# 146 take
# 29 taken
# 151 takes
# 31 taking
# 98 tale
# 8 talent
# 14 talented
# 5 talents
# 3 tales
# 20 talk
# 10 talked
# 43 talking
# 4 talks
# 3 tangle
# 10 tangled
# 5 tantalizing
# 3 target
# 2 tasks
# 27 taste
# 3 tastes
# 3 tattoo
# 3 taught
# 9 taut
# 3 te
# 13 tea
# 4 teacher
# 2 teachers
# 2 teaches
# 2 teaching
# 3 tears
# 2 tease
# 2 teasing
# 18 technique
# 3 techniques
# 100 tedious
# 3 tedium
# 2 teenager
# 2 teens
# 3 teeth
# 4 telegraphed
# 6 television
# 99 tell
# 9 teller
# 138 telling
# 24 tells
# 2 tempered
# 2 temporary
# 4 tempted
# 6 ten
# 12 tend
# 4 tended
# 3 tendencies
# 7 tendency
# 3 tends
# 13 tense
# 36 tension
# 4 term
# 16 terms
# 7 terrace
# 66 terrible
# 18 terribly
# 46 terrific
# 2 terrifying
# 2 terror
# 4 test
# 4 testament
# 6 text
# 2 textbook
# 2 texted
# 5 tgott
# 18 th
# 509 than
# 35 thank
# 4 thankful
# 6 thankfully
# 20 thanks
# 3728 that
# 3 thats
# 22578 the
# 3 theaters
# 619 their
# 509 them
# 27 theme
# 13 themes
# 37 themselves
# 567 then
# 13 theories
# 6 theory
# 22 therapist
# 4 therapy
# 947 there
# 17 therefore
# 209 these
# 673 they
# 6 thickens
# 13 thin
# 140 thing
# 198 things
# 513 think
# 128 thinking
# 31 thinks
# 77 third
# 20 thirds
# 7 thirty
# 6585 this
# 6 tho
# 3 thorough
# 105 thoroughly
# 259 those
# 325 though
# 593 thought
# 7 thoughtful
# 62 thoughts
# 5 thousands
# 6 thread
# 3 threads
# 518 three
# 9 threw
# 29 thrill
# 10 thrilled
# 435 thriller
# 92 thrillers
# 111 thrilling
# 5 thrills
# 722 through
# 177 throughout
# 13 throw
# 5 throwing
# 12 thrown
# 8 throws
# 45 thru
# 3 thrust
# 5 thumbs
# 21 thus
# 9 tie
# 21 tied
# 10 ties
# 12 tight
# 5 tighter
# 8 tightly
# 24 til
# 127 till
# 1140 time
# 3 timed
# 39 timeline
# 14 timelines
# 3 timely
# 340 times
# 5 timing
# 5 tiny
# 56 tired
# 14 tiresome
# 6 tiring
# 41 title
# 6 titled
# 12 titles
# 10568 to
# 22 today
# 45 toes
# 219 together
# 357 told
# 3 tolerance
# 3 tolerate
# 184 tom
# 4 tomorrow
# 6 ton
# 15 tone
# 7 tonic
# 6 tonics
# 8 tons
# 719 too
# 332 took
# 6 tool
# 65 top
# 3 topic
# 4 topics
# 8 torn
# 3 tortuous
# 4 torture
# 3 tortured
# 4 tossed
# 30 total
# 122 totally
# 9 touch
# 6 touched
# 7 touches
# 24 tough
# 6 touted
# 46 toward
# 72 towards
# 15 town
# 3 toxic
# 3 trace
# 83 track
# 41 tracks
# 13 tragedy
# 15 tragic
# 1216 train
# 26 trains
# 3 trainwreck
# 15 traits
# 3 transfers
# 5 transparent
# 3 trapped
# 3 trash
# 12 travel
# 8 traveling
# 11 travels
# 4 tread
# 4 treadmill
# 11 treat
# 5 treated
# 3 tree
# 9 trend
# 6 triangle
# 3 tricked
# 5 tricks
# 4 tricky
# 43 tried
# 24 tries
# 41 trip
# 4 trips
# 4 trite
# 3 trope
# 70 trouble
# 18 troubled
# 5 troubles
# 7 troubling
# 102 true
# 97 truly
# 39 trust
# 10 trusted
# 3 trustworthy
# 76 truth
# 9 truths
# 85 try
# 157 trying
# 4 tuner
# 3 turmoil
# 89 turn
# 68 turned
# 620 turner
# 5 turners
# 134 turning
# 635 turns
# 5 turny
# 22 tv
# 5 twenty
# 23 twice
# 388 twist
# 85 twisted
# 25 twisting
# 919 twists
# 44 twisty
# 3 twits
# 285 two
# 4 tying
# 77 type
# 17 types
# 30 typical
# 11 typically
# 7 typos
# 14 ugh
# 5 ugly
# 7 uk
# 9 ultimate
# 41 ultimately
# 12 un
# 43 unable
# 8 unanswered
# 10 unappealing
# 3 unbalanced
# 50 unbelievable
# 3 uncaring
# 3 uncertain
# 9 uncomfortable
# 3 undecided
# 25 under
# 3 underdeveloped
# 6 underlying
# 3 underneath
# 144 understand
# 7 understandable
# 31 understanding
# 5 understands
# 4 understatement
# 14 understood
# 3 underwhelmed
# 4 underwhelming
# 4 undeserved
# 4 undone
# 5 uneasy
# 19 unemployed
# 3 uneven
# 149 unexpected
# 5 unfair
# 5 unfaithful
# 19 unfold
# 13 unfolded
# 17 unfolding
# 42 unfolds
# 6 unfortunate
# 43 unfortunately
# 17 unhappy
# 21 uninteresting
# 107 unique
# 4 uniquely
# 8 unknown
# 25 unless
# 76 unlikable
# 26 unlike
# 63 unlikeable
# 13 unlikely
# 3 unnecessarily
# 9 unnecessary
# 6 unoriginal
# 19 unpleasant
# 3 unpredictability
# 47 unpredictable
# 4 unputdownable
# 11 unravel
# 8 unraveling
# 5 unravelling
# 3 unravels
# 32 unrealistic
# 122 unreliable
# 5 unsatisfying
# 5 unsettling
# 4 unsolved
# 11 unstable
# 9 unsure
# 3 unsuspecting
# 16 unsympathetic
# 788 until
# 3 untill
# 4 unto
# 59 unusual
# 3 unusually
# 1151 up
# 3 uplifted
# 11 uplifting
# 34 upon
# 5 ups
# 6 upset
# 3 upside
# 4 uptake
# 6 urge
# 119 us
# 3 usa
# 74 use
# 109 used
# 6 useless
# 12 uses
# 25 using
# 22 usual
# 109 usually
# 7 utter
# 18 utterly
# 3 vaca
# 68 vacation
# 10 vague
# 17 value
# 5 values
# 5 vantage
# 32 various
# 6 varying
# 333 ve
# 17 vein
# 3 verbal
# 3 verge
# 3 verify
# 62 version
# 4 versions
# 3 versus
# 2594 very
# 4 vested
# 12 via
# 7 vicariously
# 4 vices
# 30 victim
# 19 victims
# 217 view
# 8 viewed
# 3 viewer
# 3 viewing
# 21 viewpoint
# 28 viewpoints
# 34 views
# 33 villain
# 3 vindicated
# 27 violence
# 20 violent
# 3 virtually
# 4 visceral
# 3 visible
# 6 vision
# 5 visit
# 3 visits
# 3 visual
# 4 visualize
# 3 vital
# 15 vivid
# 8 vividly
# 8 vocabulary
# 69 voice
# 89 voices
# 4 void
# 6 vomiting
# 4 voracious
# 4 voyeur
# 8 voyeurism
# 11 voyeuristic
# 3 vs
# 3 vulnerabilities
# 10 vulnerable
# 3 wading
# 262 wait
# 11 waited
# 58 waiting
# 8 wake
# 6 wakes
# 11 walk
# 4 walking
# 3 walks
# 5 wall
# 3 wallowed
# 6 wallowing
# 6 wander
# 4 wandering
# 4 wanna
# 3 wannabe
# 493 want
# 263 wanted
# 154 wanting
# 26 wants
# 7 warm
# 3 warn
# 10 warned
# 8 warning
# 3 warped
# 6696 was
# 304 wasn
# 5 wasnt
# 121 waste
# 40 wasted
# 9 wasting
# 33 watch
# 21 watched
# 40 watches
# 70 watching
# 5 water
# 25 watson
# 898 way
# 56 ways
# 417 we
# 99 weak
# 11 weakness
# 15 weaknesses
# 3 weather
# 13 weave
# 6 weaved
# 17 weaves
# 8 weaving
# 10 web
# 3 webs
# 9 wee
# 35 week
# 31 weekend
# 29 weeks
# 4 weight
# 33 weird
# 3 weirdly
# 5 welcome
# 1383 well
# 86 went
# 910 were
# 40 weren
# 1416 what
# 13 whatever
# 4 whats
# 7 whatsoever
# 4 wheels
# 694 when
# 9 whenever
# 281 where
# 7 whereas
# 34 whether
# 3 whew
# 570 which
# 445 while
# 3 whilst
# 3 whine
# 4 whiney
# 15 whining
# 15 whiny
# 3 whipped
# 3 whispersync
# 9 white
# 1579 who
# 4 whoa
# 54 whodunit
# 33 whodunnit
# 206 whole
# 3 wholeheartedly
# 5 wholly
# 54 whom
# 71 whose
# 326 why
# 4 wide
# 4 widely
# 189 wife
# 20 wild
# 5 wildly
# 849 will
# 8 willing
# 7 win
# 5 wind
# 7 winded
# 5 winding
# 116 window
# 11 windows
# 4 winds
# 17 wine
# 6 winner
# 3 winning
# 8 winter
# 4 wise
# 108 wish
# 23 wished
# 7 wishes
# 10 wishing
# 2510 with
# 4 withheld
# 3 withholding
# 47 within
# 135 without
# 26 witness
# 9 witnessed
# 9 witnesses
# 4 witnessing
# 7 wives
# 7 woke
# 287 woman
# 487 women
# 175 won
# 59 wonder
# 26 wondered
# 100 wonderful
# 18 wonderfully
# 122 wondering
# 3 wonders
# 4 wont
# 58 word
# 3 wordiness
# 64 words
# 7 wordy
# 3 wore
# 152 work
# 23 worked
# 12 working
# 37 works
# 83 world
# 8 worried
# 8 worry
# 36 worse
# 48 worst
# 300 worth
# 5 worthless
# 15 worthwhile
# 23 worthy
# 1335 would
# 97 wouldn
# 5 wound
# 7 wove
# 22 woven
# 73 wow
# 10 wrap
# 16 wrapped
# 3 wraps
# 31 wreck
# 3 wrecked
# 63 write
# 88 writer
# 16 writers
# 30 writes
# 489 writing
# 981 written
# 88 wrong
# 17 wrote
# 3 wrought
# 3 www
# 3 yadda
# 5 yard
# 3 yards
# 8 yarn
# 3 yawn
# 3 yay
# 11 yeah
# 82 year
# 58 years
# 3 yell
# 3 yep
# 73 yes
# 6 yesterday
# 145 yet
# 4 yikes
# 12 york
# 4012 you
# 61 young
# 480 your
# 57 yourself
# 6 zero
# 3 zimbabwe

# %% [markdown]
# Let's have a look at the most used words in our corpus:

# %%
import seaborn as sns
ex = pd.DataFrame(data = {'word': vocab, 'number of appearance': dist}).sort_values(by = 'number of appearance', 
                                                                                    ascending = False).head(40)
sns.set_style("whitegrid")
ax = sns.barplot( x="number of appearance", y="word", data=ex)

# %% [markdown]
# We remark that the most used words are stopwords, hence we will remove them!

# %%
def remove_stop_words(review):
    review = review.split()
    stops = set(stopwords.words("english"))                  
    text = [w for w in review if not w in stops]   
    return(" ".join(text))  
toy_data['processed'] = toy_data['processed'].apply(lambda x: remove_stop_words(x))

# %%
print("Wait, bags of words are being created!!\n")
from sklearn.feature_extraction.text import CountVectorizer
# Define the function that will compute the frequencies for all words
vectorizer = CountVectorizer(analyzer = "word", tokenizer = None, preprocessor = None, stop_words = None, max_features = 5000) 
# Use the fit_transform method to learn the vocabulary and then transform the training data into vectors
train_data_features = vectorizer.fit_transform(toy_data['processed'])
# Convert the result to an array
train_data_features = train_data_features.toarray()

print('The model has been learned!')
size = train_data_features.shape
sparsity = np.count_nonzero(train_data_features) / train_data_features.size
vocab = vectorizer.get_feature_names()
dist = np.sum(train_data_features, axis=0)

ex = pd.DataFrame(data = {'word': vocab, 'number of appearance': dist}).sort_values(by = 'number of appearance', 
                                                                                    ascending = False).head(40)
sns.set_style("whitegrid")
ax = sns.barplot( x="number of appearance", y="word", data=ex)
plt.title('Frequency of words')
plt.show()
# Out:
# Wait, bags of words are being created!!
#
# The model has been learned!

# %% [markdown]
# We observe that some of the most represented words are related to emotions ("great", "like", "enjoyed", "loved", ... which is important for our application).
#
# We also observe that the number of appearance is rapidly deacreasing.

# %%
ex = pd.DataFrame(data = {'word': vocab, 'number of appearance': dist}).sort_values(by = 'number of appearance', 
                                                                                    ascending = False).head(500)
sns.set_style("whitegrid")
ax = sns.barplot( x="number of appearance", y="word", data=ex)
plt.title('Frequency of words')
plt.show()

# %% [markdown]
# # Classification

# %% [markdown]
# We will now build models to predict the rating based on the reviews' features.

# %%
import time
from sklearn.model_selection import train_test_split
labels = toy_data['sentiment']

# We split the data into train and test data. Here we keep 30% of the data for testing
data_train, data_test, labels_train, labels_test = train_test_split(train_data_features, 
                                                                    labels, test_size=0.3, 
                                                                    random_state=42)

# %%
data_train.shape
# Out:
# (8742, 5000)

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

start = time.time()
# Initialize the model
print('Initialize the model')
clf = LogisticRegression()

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  1.110008955001831

# %%
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
plt.hist(labels_predicted, color = 'b')
plt.xlabel('rating')
plt.title('Predicted ratings')
plt.show()

plt.hist(labels_test, color = 'b')
plt.xlabel('rating')
plt.title('True ratings')
plt.show()
# Out:
# The accuracy is:  0.346944222044

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[368 399 497]
#  [357 397 466]
#  [368 360 535]]

# %%
from sklearn.metrics import classification_report
target_names = ['class -1', 'class 0', 'class 1']
print(classification_report(labels_test, labels_predicted, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#    class -1       0.34      0.29      0.31      1264
#     class 0       0.34      0.33      0.33      1220
#     class 1       0.36      0.42      0.39      1263
#
# avg / total       0.35      0.35      0.34      3747

# %%
start = time.time()
# Initialize the model
print('Initialize the model')
clf = LogisticRegression(C=.01)
# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)
# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)
print("Computation time: ", time.time() - start)

print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  0.6021981239318848
# The accuracy is:  0.363757672805
# Confusion matrix, without normalization
# [[343 390 531]
#  [314 401 505]
#  [275 369 619]]
#              precision    recall  f1-score   support
#
#    class -1       0.37      0.27      0.31      1264
#     class 0       0.35      0.33      0.34      1220
#     class 1       0.37      0.49      0.42      1263
#
# avg / total       0.36      0.36      0.36      3747
#
# The accuracy is:  0.363757672805

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

start = time.time()

# Initialize the model
print('Initialize the model')
clf = RandomForestClassifier(n_estimators = 20, class_weight="balanced")

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  11.336165189743042
# Confusion matrix, without normalization
# [[430 441 393]
#  [384 453 383]
#  [367 430 466]]
#              precision    recall  f1-score   support
#
#    class -1       0.36      0.34      0.35      1264
#     class 0       0.34      0.37      0.36      1220
#     class 1       0.38      0.37      0.37      1263
#
# avg / total       0.36      0.36      0.36      3747
#
# The accuracy is:  0.360021350414

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

start = time.time()
# Initialize the model
print('Initialize the model')
clf = GaussianNB()

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  2.2035560607910156
# Confusion matrix, without normalization
# [[ 160  153  951]
#  [ 125  155  940]
#  [ 106  139 1018]]
#              precision    recall  f1-score   support
#
#    class -1       0.41      0.13      0.19      1264
#     class 0       0.35      0.13      0.19      1220
#     class 1       0.35      0.81      0.49      1263
#
# avg / total       0.37      0.36      0.29      3747
#
# The accuracy is:  0.355751267681

# %% [markdown]
# #### What if we used TF-IDF instead of Count Vectorizer?
#
# In TF-IDF (Term Frequency - Inverse Document Frequency), we take into account both the frequency of the word in the text and the relative frequency within different texts.

# %%
print("Wait, bags of words are being created!!\n")
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the function that will compute the frequencies for all words
vectorizer = TfidfVectorizer(analyzer = "word", tokenizer = None, preprocessor = None, stop_words = None, max_features = 5000) 

# Use the fit_transform method to learn the vocabulary and then transform the training data into vectors
train_data_features = vectorizer.fit_transform(toy_data['processed'])

# Convert the result to an array
train_data_features = train_data_features.toarray()

# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

ex = pd.DataFrame(data = {'word': vocab, 'number of appearance': dist}).sort_values(by = 'number of appearance', 
                                                                                    ascending = False).head(40)

import seaborn as sns
sns.set_style("whitegrid")
ax = sns.barplot( x="number of appearance", y="word", data=ex)
plt.title('Frequency of words')
plt.show()
# Out:
# Wait, bags of words are being created!!

# %% [markdown]
# # Classification

# %%
labels = toy_data['sentiment']
# We split the data into train and test data. Here we keep 30% of the data for testing
data_train, data_test, labels_train, labels_test = train_test_split(train_data_features, 
                                                                    labels, test_size=0.3, 
                                                                    random_state=42)

# %% [markdown]
# #### Logistic Regression

# %%
start = time.time()
# Initialize the model
print('Initialize the model')
clf = LogisticRegression(C = 10)

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  0.562309741973877
# Confusion matrix, without normalization
# [[385 426 453]
#  [375 416 429]
#  [382 381 500]]
#              precision    recall  f1-score   support
#
#    class -1       0.34      0.30      0.32      1264
#     class 0       0.34      0.34      0.34      1220
#     class 1       0.36      0.40      0.38      1263
#
# avg / total       0.35      0.35      0.35      3747
#
# The accuracy is:  0.347211102215

# %% [markdown]
# #### Random Forest

# %%
start = time.time()

# Initialize the model
print('Initialize the model')
clf = RandomForestClassifier(n_estimators = 30, class_weight="balanced")

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  17.61738395690918
# Confusion matrix, without normalization
# [[450 445 369]
#  [441 431 348]
#  [423 434 406]]
#              precision    recall  f1-score   support
#
#    class -1       0.34      0.36      0.35      1264
#     class 0       0.33      0.35      0.34      1220
#     class 1       0.36      0.32      0.34      1263
#
# avg / total       0.34      0.34      0.34      3747
#
# The accuracy is:  0.343474779824

# %% [markdown]
# #### Naive Bayes

# %%
start = time.time()
# Initialize the model
print('Initialize the model')
clf = GaussianNB()

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  2.329176664352417
# Confusion matrix, without normalization
# [[193 187 884]
#  [166 193 861]
#  [151 166 946]]
#              precision    recall  f1-score   support
#
#    class -1       0.38      0.15      0.22      1264
#     class 0       0.35      0.16      0.22      1220
#     class 1       0.35      0.75      0.48      1263
#
# avg / total       0.36      0.36      0.31      3747
#
# The accuracy is:  0.35548438751

# %% [markdown]
# #### Remarks
#
# We remark that the features resulted from both count vectorizer and tf-idf vectorizer give approximately the same results. If the classification algorithms provide better results than a random guess ($33.33\%$ accuracy), the performance here is not very good, with a best accuracy of $30\%$ for the logistic regression.

# %% [markdown]
# # Strategy 2: Word Embedding

# %% [markdown]
# [Mikolov](https://scholar.google.com/citations?user=oBu8kMMAAAAJ) has contributed a lot in the field of [word embedding](https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) using deep learning. His first models skip-gram and CBOW have lead to lots of work to imrove the way we embed objects into vectors (including words, in our contexts).
#
# We will use the implementation of $Word2Vec$ from the package [Gensim](https://radimrehurek.com/gensim/).

# %% [markdown]
# ### Prepare the data for gensim $Word2Vec$ model

# %%
def process(x, remove_stopwords=False):
    '''
    Function to clear the html tags, then remove non-letters characters, 
    lowercase, remove stopwords, then join the resulting as a full text
    '''
    # Clean html tags
    review = BeautifulSoup(x, "html.parser").get_text() 
    # Remove non letters     
    letters = re.sub("[^a-zA-Z]", " ", review) 
    # Lowercase and split to words
    words = letters.lower().split()                             
    # It appears that searching in a set in Python is much more efficient than searching in a list
    stops = set(stopwords.words("english"))                  
    # Optionally remove stop words
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]

    return words 

import nltk.data
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# Function that splits reviews into sentences
def review_to_sentences(review, tokenizer, remove_stopwords=False ):
    '''Function to split a review into parsed sentences. Returns a 
    list of sentences, where each sentence is a list of words
    '''
    
    # Split into sentences
    raw_sentences = tokenizer.tokenize(review.strip())
    
    # Loop over each sentence
    sentences = []
    for raw_sentence in raw_sentences:
        # If a sentence is empty, skip it
        if len(raw_sentence) > 0:
            # Otherwise, call review_to_wordlist to get a list of words
            sentences.append(process(raw_sentence, remove_stopwords))
            
    # Return the list of sentences (each sentence is a list of words, so this returns a list of lists
    return sentences

# %%
# Apply the function to the whole toy dataset
start = time.time()

sentences = []  # Initialize an empty list of sentences

print("Parsing sentences from training set")
for review in toy_data["review"]:
    sentences += review_to_sentences(review, tokenizer)
      
print(time.time() - start)
# Out:
# Parsing sentences from training set
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'.. .'" looks like a filename, not markup. You shouldprobably open this file and pass the filehandle intoBeautiful Soup.
#   'Beautiful Soup.' % markup)
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You shouldprobably open this file and pass the filehandle intoBeautiful Soup.
#   'Beautiful Soup.' % markup)
# 22.03115749359131

# %% [markdown]
# ### Build the $Word2Vec$ model and save it
#
# We will embed words into $300$ dimensions vectors, with a context of size $10$. We only keep words which appear at least $40$ times.

# %%
start = time.time()
# The logging package enables to output messages during preparation

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)


# Set values for various parameters
num_features = 300    # Word vector dimensionality                      
min_word_count = 40   # Minimum word count                        
num_workers = 4       # Number of threads to run in parallel
context = 10          # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

# Initialize and train the model. This is the most costly in computation time!
from gensim.models import word2vec
print("Training model...")
model = word2vec.Word2Vec(sentences, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)

model.init_sims(replace=True)

# Save the model
model_name = "300features_40minwords_10context_toy_dataset"
model.save(model_name)

print(time.time() - start)
# Out:
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\gensim\utils.py:843: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# 2017-01-31 20:26:11,904 : INFO : 'pattern' package not found; tag filters are not available for English
# 2017-01-31 20:26:11,920 : INFO : collecting all words and their counts
# 2017-01-31 20:26:11,920 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-01-31 20:26:11,951 : INFO : PROGRESS: at sentence #10000, processed 124848 words, keeping 6190 word types
# 2017-01-31 20:26:11,982 : INFO : PROGRESS: at sentence #20000, processed 235880 words, keeping 8200 word types
# 2017-01-31 20:26:12,014 : INFO : PROGRESS: at sentence #30000, processed 373242 words, keeping 10331 word types
# 2017-01-31 20:26:12,029 : INFO : collected 10630 word types from a corpus of 414162 raw words and 35243 sentences
# 2017-01-31 20:26:12,029 : INFO : Loading a fresh vocabulary
# 2017-01-31 20:26:12,029 : INFO : min_count=40 retains 826 unique words (7% of original 10630, drops 9804)
# 2017-01-31 20:26:12,045 : INFO : min_count=40 leaves 372317 word corpus (89% of original 414162, drops 41845)
# 2017-01-31 20:26:12,045 : INFO : deleting the raw counts dictionary of 10630 items
# 2017-01-31 20:26:12,045 : INFO : sample=0.001 downsamples 74 most-common words
# 2017-01-31 20:26:12,045 : INFO : downsampling leaves estimated 237435 word corpus (63.8% of prior 372317)
# 2017-01-31 20:26:12,045 : INFO : estimated required memory for 826 words and 300 dimensions: 2395400 bytes
# 2017-01-31 20:26:12,045 : INFO : resetting layer weights
# 2017-01-31 20:26:12,060 : INFO : training model with 4 workers on 826 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-01-31 20:26:12,076 : INFO : expecting 35243 sentences, matching count from corpus used for vocabulary survey
# 2017-01-31 20:26:12,092 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,092 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# Training model...
# 2017-01-31 20:26:12,092 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,092 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,123 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,123 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,139 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,154 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,170 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,170 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,185 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,185 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,185 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,201 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,201 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,201 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,217 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,232 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,232 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,248 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,248 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,264 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,264 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,264 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,264 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,279 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,279 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,295 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,295 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,295 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,311 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,326 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,326 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,343 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,350 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,357 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,357 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,372 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,372 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,388 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,388 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,388 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,404 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,404 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,404 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,419 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,419 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,435 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,435 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,435 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,451 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,451 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,466 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,466 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,482 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,482 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,497 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,497 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,513 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,513 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,513 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,529 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,529 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,544 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,544 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,560 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,560 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,560 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,576 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,576 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,591 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,591 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,591 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,607 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,607 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,622 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,638 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,638 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,638 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,655 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,661 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,661 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,677 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,677 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,677 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,693 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,693 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,708 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,708 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,708 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,724 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,724 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,739 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,755 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,755 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,755 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,771 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,771 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,786 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,786 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,802 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,802 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,802 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,818 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,818 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,833 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,833 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,849 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,858 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,859 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,864 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,871 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,872 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,887 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,887 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,887 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,903 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,918 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,918 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,934 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,934 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,934 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,950 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,965 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,965 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,965 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,981 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,981 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,997 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,997 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:12,997 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,012 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,012 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,012 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,028 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,043 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,043 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,059 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,059 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,059 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,059 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,075 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,090 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,090 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,090 : INFO : PROGRESS: at 67.12% examples, 798458 words/s, in_qsize 7, out_qsize 0
# 2017-01-31 20:26:13,090 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,106 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,106 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,122 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,122 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,137 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,137 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,153 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,153 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,168 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,168 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,168 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,168 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,184 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,200 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,200 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,215 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,215 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,231 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,231 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,247 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,247 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,247 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,262 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,262 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,278 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,278 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,294 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,294 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,294 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,312 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,323 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,330 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,338 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,341 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,345 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,354 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,357 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,357 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,373 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,373 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,388 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,388 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,388 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,404 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,419 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,419 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,435 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,435 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,435 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,451 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,451 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,466 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,466 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,466 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,482 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,498 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,498 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,498 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,498 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,513 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,513 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,529 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,529 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 20:26:13,529 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-01-31 20:26:13,544 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-01-31 20:26:13,544 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-01-31 20:26:13,544 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-01-31 20:26:13,544 : INFO : training on 2070810 raw words (1186701 effective words) took 1.5s, 814225 effective words/s
# 2017-01-31 20:26:13,544 : INFO : precomputing L2-norms of word weight vectors
# 2017-01-31 20:26:13,560 : INFO : saving Word2Vec object under 300features_40minwords_10context_toy_dataset, separately None
# 2017-01-31 20:26:13,560 : WARNING : direct access to syn0norm will not be supported in future gensim releases, please use model.wv.syn0norm
# 2017-01-31 20:26:13,560 : WARNING : direct access to syn0norm will not be supported in future gensim releases, please use model.wv.syn0norm
# 2017-01-31 20:26:13,560 : WARNING : direct access to syn0norm will not be supported in future gensim releases, please use model.wv.syn0norm
# 2017-01-31 20:26:13,560 : INFO : not storing attribute syn0norm
# 2017-01-31 20:26:13,560 : INFO : not storing attribute cum_table
# 2017-01-31 20:26:13,591 : WARNING : direct access to syn0norm will not be supported in future gensim releases, please use model.wv.syn0norm
# 2017-01-31 20:26:13,591 : INFO : saved 300features_40minwords_10context_toy_dataset
# 1.9596436023712158

# %% [markdown]
# ## Exploration of the model we created

# %%
from gensim.models import Word2Vec

model = Word2Vec.load("300features_40minwords_10context_toy_dataset")
# Out:
# 2017-01-31 20:26:40,453 : INFO : loading Word2Vec object from 300features_40minwords_10context_toy_dataset
# 2017-01-31 20:26:40,468 : INFO : loading wv recursively from 300features_40minwords_10context_toy_dataset.wv.* with mmap=None
# 2017-01-31 20:26:40,468 : INFO : setting ignored attribute syn0norm to None
# 2017-01-31 20:26:40,468 : WARNING : direct access to syn0norm will not be supported in future gensim releases, please use model.wv.syn0norm
# 2017-01-31 20:26:40,484 : INFO : setting ignored attribute cum_table to None
# 2017-01-31 20:26:40,484 : INFO : loaded 300features_40minwords_10context_toy_dataset
# 2017-01-31 20:26:40,484 : WARNING : direct access to index2word will not be supported in future gensim releases, please use model.wv.index2word

# %%
# Size of the matrice created
model.syn0.shape
# Out:
# 2017-01-31 20:26:42,077 : WARNING : direct access to syn0 will not be supported in future gensim releases, please use model.wv.syn0
# (826, 300)

# %%
# Example of a word vector
model['good']
# Out:
# array([  1.34e-02,  -5.26e-02,   1.08e-01,   9.25e-03,  -3.45e-02,
#         -7.30e-02,  -7.94e-02,  -2.89e-02,  -5.01e-03,  -2.72e-02,
#          4.84e-02,   3.06e-02,   7.18e-03,   1.47e-02,  -4.60e-02,
#         -5.64e-02,  -3.42e-02,  -2.72e-02,  -1.28e-01,   6.53e-02,
#          6.77e-02,  -1.22e-01,  -2.24e-02,   2.88e-02,   1.46e-02,
#         -2.04e-03,   3.14e-02,  -3.15e-02,   1.19e-03,  -1.10e-02,
#          5.13e-02,  -2.08e-02,   1.55e-03,   2.71e-03,  -5.07e-02,
#         -5.62e-02,   5.96e-02,   5.57e-02,  -4.48e-02,   5.68e-02,
#         -1.55e-01,   1.89e-02,  -6.58e-02,   3.36e-02,  -5.14e-02,
#         -3.45e-02,   1.02e-02,   4.84e-02,   8.89e-03,  -4.22e-02,
#         -1.40e-01,   8.07e-02,  -1.35e-02,  -1.02e-02,   2.00e-02,
#          4.81e-02,   3.75e-02,  -5.14e-02,  -6.91e-02,   4.85e-02,
#          7.07e-02,   7.37e-02,  -5.63e-02,  -3.50e-02,   6.81e-02,
#         -3.91e-02,   2.76e-02,   7.02e-02,   6.14e-02,   1.94e-02,
#         -4.98e-02,  -1.14e-02,   1.12e-03,   1.07e-01,   2.50e-04,
#          8.34e-02,   1.19e-01,  -3.81e-02,   8.84e-02,   6.52e-02,
#          1.09e-01,   3.25e-02,  -3.75e-02,  -3.05e-02,  -5.69e-02,
#          1.45e-01,  -3.09e-03,  -4.48e-02,  -1.50e-01,  -1.98e-04,
#          2.83e-02,  -1.83e-02,  -6.61e-03,  -6.00e-04,   1.30e-01,
#         -8.34e-02,   1.16e-02,  -5.65e-02,  -6.48e-02,   1.15e-01,
#          8.69e-02,   7.45e-03,  -7.23e-02,  -6.63e-02,  -2.12e-03,
#          7.08e-02,   3.71e-02,   9.48e-02,  -5.40e-02,  -2.55e-02,
#         -3.65e-02,  -2.58e-02,   7.98e-03,  -1.09e-02,   1.56e-02,
#         -3.84e-02,   1.53e-01,   2.40e-02,   5.53e-02,   1.02e-02,
#          8.79e-02,  -4.50e-02,   7.22e-02,  -8.06e-02,  -7.21e-03,
#          1.44e-02,   5.72e-02,   4.64e-02,  -3.77e-02,  -5.02e-02,
#         -2.19e-02,  -8.43e-02,  -8.36e-02,   7.65e-02,  -1.06e-01,
#         -7.30e-02,   5.69e-02,   3.48e-02,  -3.27e-02,   8.27e-02,
#          1.72e-02,   3.07e-02,   9.91e-03,   9.21e-02,  -5.40e-02,
#          6.74e-02,   2.56e-02,   7.50e-02,   1.01e-01,   2.57e-02,
#          2.59e-02,   2.62e-02,  -2.06e-02,  -3.16e-02,  -4.17e-02,
#          1.89e-02,  -3.60e-02,  -7.85e-02,   6.27e-02,   6.31e-02,
#          6.18e-03,  -3.05e-03,   4.85e-02,  -2.53e-03,   3.16e-02,
#         -4.67e-02,   8.22e-02,  -3.77e-02,  -4.47e-03,  -8.28e-05,
#          2.29e-02,  -7.75e-02,  -2.69e-02,   6.67e-02,  -4.28e-02,
#          3.22e-02,   2.12e-02,   1.09e-02,   1.35e-01,   1.44e-01,
#         -1.03e-01,   1.12e-01,   1.48e-03,   6.96e-02,  -1.13e-02,
#          3.31e-02,  -6.57e-02,  -3.32e-02,  -1.56e-02,  -8.25e-02,
#         -6.54e-02,  -4.20e-02,   5.42e-03,  -6.37e-03,   2.45e-02,
#         -7.10e-02,  -8.26e-02,   1.12e-01,  -4.53e-02,  -1.38e-02,
#         -2.54e-02,  -1.33e-02,  -5.34e-02,  -6.87e-02,  -6.47e-04,
#         -2.09e-02,   3.71e-03,   6.24e-02,  -1.23e-02,  -8.73e-02,
#          7.60e-02,  -1.39e-01,   1.26e-02,  -1.13e-02,  -3.52e-02,
#          3.64e-02,  -9.88e-02,  -1.17e-01,   4.04e-02,   5.55e-02,
#          1.22e-02,   7.31e-02,   6.14e-02,   5.75e-02,   7.54e-02,
#          5.42e-02,   2.80e-02,  -1.78e-02,   6.47e-02,   4.73e-02,
#         -1.34e-02,  -7.56e-02,   7.71e-02,   7.08e-02,  -2.14e-02,
#          8.54e-02,   7.68e-02,  -4.93e-02,  -1.77e-02,   2.61e-02,
#          3.14e-02,   3.79e-02,  -2.48e-02,  -6.16e-02,  -4.10e-02,
#          3.06e-02,  -1.31e-02,  -9.13e-02,   7.01e-02,  -5.38e-02,
#         -1.32e-01,   7.63e-02,   6.80e-03,   4.43e-02,  -8.34e-02,
#          6.29e-02,   7.05e-02,   7.89e-02,  -4.51e-02,  -2.55e-02,
#         -6.19e-03,   1.18e-02,  -2.09e-03,   2.52e-02,  -4.05e-03,
#          3.66e-02,   4.88e-02,  -6.04e-02,  -4.88e-02,  -1.45e-02,
#          3.81e-02,  -2.08e-02,  -1.76e-02,  -5.93e-03,  -2.55e-02,
#          3.64e-02,  -2.12e-02,  -4.75e-02,   5.74e-02,  -5.89e-02,
#         -5.02e-02,  -4.10e-02,  -6.28e-02,   3.88e-02,  -4.89e-02,
#         -5.76e-02,  -2.67e-02,   2.08e-02,  -3.58e-02,   3.61e-02,
#         -2.09e-02,  -8.96e-02,  -1.03e-01,   7.98e-03,  -5.21e-03,
#         -3.86e-02,  -1.00e-02,  -4.67e-02,   9.62e-03,  -3.64e-02], dtype=float32)

# %%
# Example of word similarity
model.most_similar('have')
# Out:
# 2017-01-31 20:26:46,787 : INFO : precomputing L2-norms of word weight vectors
# [('wish', 0.7336536049842834),
#  ('ve', 0.7033239603042603),
#  ('believe', 0.6202813386917114),
#  ('maybe', 0.6190702319145203),
#  ('give', 0.5763474702835083),
#  ('been', 0.5753400921821594),
#  ('already', 0.5637931823730469),
#  ('given', 0.5521359443664551),
#  ('since', 0.5467914342880249),
#  ('ever', 0.5464085340499878)]

# %%
model.most_similar('good')
# Out:
# [('great', 0.8535372018814087),
#  ('decent', 0.8240993022918701),
#  ('fun', 0.7751692533493042),
#  ('entertaining', 0.7333318591117859),
#  ('enjoyable', 0.7160481214523315),
#  ('nice', 0.7060836553573608),
#  ('satisfying', 0.7029126882553101),
#  ('fantastic', 0.6745709776878357),
#  ('awesome', 0.6699577569961548),
#  ('thrilling', 0.6507682800292969)]

# %%
# Distinguished the most distant word between several words
print(model.doesnt_match("man woman child dog".split()))

print(model.doesnt_match("amazing wonderful great window".split()))
# Out:
# man
# window

# %% [markdown]
# Here, we see that the word embeddings seem not to be very good. This is due to the fact that we have trained the $Word2Vec$ model on a too small dataset. We will come back to this in a second part with the whole dataset.

# %% [markdown]
# #### Once we have word vectors, how can we create features for reviews?
# #### One possibility is to average all the word vectors from the review

# %%
def makeFeatureVec(words, model, num_features):
    ''' 
    Function to average all the word vectors in a given review
    '''
    # Initialize an empty array
    featureVec = np.zeros((num_features,),dtype="float32")
    
    nwords = 0.
    
    # Index2word is a list that contains the names of the words in the model's vocabulary. Convert it to a set, for speed (juyst as we did before)
    index2word_set = set(model.wv.index2word)
    
    # Loop over each word in the review and, if it is in the model's vocabulary, add its feature vector to the total
    for word in words:
        if word in index2word_set: 
            nwords = nwords + 1.
            featureVec = np.add(featureVec,model[word])
    
    # Divide the result by the number of words to get the average
    featureVec = np.divide(featureVec,nwords)
    
    return featureVec


def getAvgFeatureVecs(reviews, model, num_features):
    ''' 
    Given a set of reviews (each one a list of words), compute 
    the average feature vector for each one and return an array
    '''
    # Initialize a counter
    counter = 0
    
    # Preallocate a 2D numpy array, for speed
    reviewFeatureVecs = np.zeros((len(reviews),num_features),dtype="float32")
    
    # Loop through the reviews
    for review in reviews:
        
        # Print a status message every 1000th review
        if counter%1000. == 0.:
            print("Review %d of %d" % (counter, len(reviews)))
        
        # Call the function (defined above) that makes average feature vectors
        reviewFeatureVecs[counter] = makeFeatureVec(review, model, num_features)
        
        # Increment the counter
        counter = counter + 1
    return reviewFeatureVecs

# %%
# Compute the average feature vectors, using the functions we defined above.
start = time.time()
print("Creating average feature vecs for train reviews")

clean_train_reviews = []
for review in list(toy_data["review"]):
    clean_train_reviews.append(process(review, remove_stopwords=True))
print('reviews cleaned')
trainDataVecs = getAvgFeatureVecs(clean_train_reviews, model, num_features)

print(time.time() - start)
# Out:
# Creating average feature vecs for train reviews
# reviews cleaned
# Review 0 of 12489
# Review 1000 of 12489
# Review 2000 of 12489
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\ipykernel\__main__.py:20: RuntimeWarning: invalid value encountered in true_divide
# Review 3000 of 12489
# Review 4000 of 12489
# Review 5000 of 12489
# Review 6000 of 12489
# Review 7000 of 12489
# Review 8000 of 12489
# Review 9000 of 12489
# Review 10000 of 12489
# Review 11000 of 12489
# Review 12000 of 12489
# 14.493547916412354

# %% [markdown]
# # Classification

# %%
labels = toy_data['sentiment']
# Split the data into random train and test subsets. Here we use 30% of the data for testing
data_train, data_test, labels_train, labels_test = train_test_split(trainDataVecs, 
                                                                    labels, test_size=0.3, 
                                                                    random_state=42)

# %% [markdown]
# #### Logistic Regression

# %%
start = time.time()

# Initialize the model
clf = LogisticRegression(C = 0.001)

# Fit the model to the training data
y_score = clf.fit(data_train, labels_train).predict(data_test)
# Perform classific°ation of test data
labels_predicted = clf.predict(data_test)

print(time.time() - start)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-0e4fea4c1634> in <module>()
#       5
#       6 # Fit the model to the training data
# ----> 7 y_score = clf.fit(data_train, labels_train).predict(data_test)
#       8 # Perform classific°ation of test data
#       9 labels_predicted = clf.predict(data_test)
#
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1171
#    1172         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1173                          order="C")
#    1174         check_classification_targets(y)
#    1175         self.classes_ = np.unique(y)
#
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     519     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     520                     ensure_2d, allow_nd, ensure_min_samples,
# --> 521                     ensure_min_features, warn_on_dtype, estimator)
#     522     if multi_output:
#     523         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# It appears that some nans have been produced... How many?

# %%
np.isnan(data_train).sum() / (data_train.shape[0] * data_train.shape[1])
# Out:
# 0.0070921985815602835

# %%
X = pd.concat((pd.DataFrame(trainDataVecs), toy_data['sentiment']), axis=1).dropna()
train_data = X.ix[:, :-1]
train_label = X.ix[:, -1]

# Split the data into random train and test subsets. Here we use 30% of the data for testing
data_train, data_test, labels_train, labels_test = train_test_split(train_data, 
                                                                    train_label, test_size=0.3, 
                                                                    random_state=42)

# %%
start = time.time()
# Initialize the model
print('Initialize the model')
clf = LogisticRegression(C = .9)

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  1.3627712726593018
# Confusion matrix, without normalization
# [[350 478 415]
#  [341 480 381]
#  [314 446 512]]
#              precision    recall  f1-score   support
#
#    class -1       0.35      0.28      0.31      1243
#     class 0       0.34      0.40      0.37      1202
#     class 1       0.39      0.40      0.40      1272
#
# avg / total       0.36      0.36      0.36      3717
#
# The accuracy is:  0.361043852569

# %% [markdown]
# #### Random Forest

# %%
start = time.time()

# Initialize the model
print('Initialize the model')
clf = RandomForestClassifier(n_estimators = 30, class_weight="balanced")

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  5.015347480773926
# Confusion matrix, without normalization
# [[423 450 370]
#  [408 446 348]
#  [394 410 468]]
#              precision    recall  f1-score   support
#
#    class -1       0.35      0.34      0.34      1243
#     class 0       0.34      0.37      0.36      1202
#     class 1       0.39      0.37      0.38      1272
#
# avg / total       0.36      0.36      0.36      3717
#
# The accuracy is:  0.359698681733

# %% [markdown]
# #### Naive Bayes

# %%
start = time.time()
# Initialize the model
print('Initialize the model')
clf = GaussianNB()

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  0.1315310001373291
# Confusion matrix, without normalization
# [[132 725 386]
#  [129 762 311]
#  [127 679 466]]
#              precision    recall  f1-score   support
#
#    class -1       0.34      0.11      0.16      1243
#     class 0       0.35      0.63      0.45      1202
#     class 1       0.40      0.37      0.38      1272
#
# avg / total       0.36      0.37      0.33      3717
#
# The accuracy is:  0.365886467581

# %% [markdown]
# ## Clustering

# %% [markdown]
# Since we have embedded our vectors in a $300$ dimensions space, we have a metric, and we can make clustering of words, hence producing clusters of words. We will use these clusters to create features for the reviews.

# %%
from sklearn.cluster import KMeans

start = time.time()

# Set "k" (num_clusters) to be 1/5th of the vocabulary size (this is an arbitrary choice)
word_vectors = model.syn0
num_clusters = int(word_vectors.shape[0] / 5)

# Initalize a k-means object and use it to extract centroids
kmeans_clustering = KMeans(n_clusters = num_clusters)
idx = kmeans_clustering.fit_predict(word_vectors)

# Get the end time and print how long the process took
end = time.time()
elapsed = end - start
print("Time taken for K Means clustering: ", elapsed, "seconds.")
# Out:
# 2017-01-31 20:35:00,208 : WARNING : direct access to syn0 will not be supported in future gensim releases, please use model.wv.syn0
# Time taken for K Means clustering:  1.6585869789123535 seconds.

# %%
# Create a Word / Index dictionary, mapping each vocabulary word to a cluster number                                                                                            
word_centroid_map = dict(zip(model.index2word, idx))
# Out:
# 2017-01-31 20:35:35,858 : WARNING : direct access to index2word will not be supported in future gensim releases, please use model.wv.index2word

# %%
# Display the first 10 clusters
for cluster in range(0,10):
    
    # Print the cluster number  
    print("\nCluster %d" % cluster)
    
    # Find all of the words for that cluster number, and print them out
    words = []
    for i in range(0,len(word_centroid_map.values())):
        if(list(word_centroid_map.values())[i] == cluster):
            words.append(list(word_centroid_map.keys())[i])
    print(words)
# Out:
# Cluster 0
# ['reveal', 'who', 'guy', 'talking', 'murderer', 'killer', 'idea']
#
# Cluster 1
# ['dialogue', 'completely', 'totally', 'ultimately', 'unbelievable', 'flat', 'mostly', 'slightly', 'climax', 'complicated', 'action', 'itself', 'frustrating']
#
# Cluster 2
# ['hope', 'call']
#
# Cluster 3
# ['along', 'moves', 'unfolds', 'builds', 'and']
#
# Cluster 4
# ['beginning', 'start', 'hooked']
#
# Cluster 5
# ['constantly', 'pieces', 'names', 'clear', 'truth', 'sense', 'name', 'speaking', 'whom']
#
# Cluster 6
# ['police', 'married', 'marriage', 'him', 'memory', 'picture', 'fantasy', 'tom', 'alcohol', 'reality', 'feels', 'depressed', 'blackouts', 'scott', 'problem', 'baby', 'lost', 'blackout']
#
# Cluster 7
# ['rating', 'club', 'bought', 'star']
#
# Cluster 8
# ['then', 'up', 'night']
#
# Cluster 9
# ['kindle', 'wasted', 'finishing', 'waste', 'library', 'hours', 'spent', 'money', 'stayed', 'decided', 'expectations']

# %% [markdown]
# Now, let's create our bags of centroïds

# %%
def create_bag_of_centroids(wordlist, word_centroid_map):
    
    # The number of clusters is equal to the highest cluster index
    # in the word / centroid map
    num_centroids = max(word_centroid_map.values()) + 1
    #
    # Pre-allocate the bag of centroids vector (for speed)
    bag_of_centroids = np.zeros(num_centroids, dtype="float32")
    
    # Loop over the words in the review. If the word is in the vocabulary,
    # find which cluster it belongs to, and increment that cluster count 
    # by one
    for word in wordlist:
        if word in word_centroid_map:
            index = word_centroid_map[word]
            bag_of_centroids[index] += 1
    
    # Return the "bag of centroids"
    return bag_of_centroids

# Pre-allocate an array for the training set bags of centroids (for speed)
train_centroids = np.zeros((toy_data["sentiment"].size, num_clusters), dtype="float32")

# Transform the training set reviews into bags of centroids
counter = 0
for review in clean_train_reviews:
    train_centroids[counter] = create_bag_of_centroids(review, word_centroid_map)
    counter += 1

# %%
np.isnan(train_centroids).sum() # There are no missing values
# Out:
# 0

# %%
# Split the data into random train and test subsets. Here we use 30% of the data for testing
data_train, data_test, labels_train, labels_test = train_test_split(train_centroids, 
                                                                    toy_data['sentiment'], test_size=0.3)

# %% [markdown]
# # Classification

# %% [markdown]
# #### Logistic Regression

# %%
start = time.time()
# Initialize the model
print('Initialize the model')
clf = LogisticRegression(C = 1)

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  0.1177833080291748
# Confusion matrix, without normalization
# [[320 324 593]
#  [337 339 568]
#  [320 305 641]]
#              precision    recall  f1-score   support
#
#    class -1       0.33      0.26      0.29      1237
#     class 0       0.35      0.27      0.31      1244
#     class 1       0.36      0.51      0.42      1266
#
# avg / total       0.34      0.35      0.34      3747
#
# The accuracy is:  0.346944222044

# %% [markdown]
# #### Random Forest

# %%
start = time.time()

# Initialize the model
print('Initialize the model')
clf = RandomForestClassifier(n_estimators = 10, class_weight="balanced")

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  0.3072066307067871
# Confusion matrix, without normalization
# [[469 400 368]
#  [449 443 352]
#  [437 417 412]]
#              precision    recall  f1-score   support
#
#    class -1       0.35      0.38      0.36      1237
#     class 0       0.35      0.36      0.35      1244
#     class 1       0.36      0.33      0.34      1266
#
# avg / total       0.35      0.35      0.35      3747
#
# The accuracy is:  0.353349346144

# %% [markdown]
# #### Naive Bayes

# %%
start = time.time()
# Initialize the model
print('Initialize the model')
clf = GaussianNB()

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  0.06250762939453125
# Confusion matrix, without normalization
# [[209 162 866]
#  [198 164 882]
#  [143 153 970]]
#              precision    recall  f1-score   support
#
#    class -1       0.38      0.17      0.23      1237
#     class 0       0.34      0.13      0.19      1244
#     class 1       0.36      0.77      0.49      1266
#
# avg / total       0.36      0.36      0.30      3747
#
# The accuracy is:  0.358420069389

# %% [markdown]
# #### Conclusion of word embeddings: it seems that the methods dos not enable to have good results in the cllassification part.

# %% [markdown]
# # Whole dataset

# %% [markdown]
# From now on, we will carry out the same methodology as before, but this time with the whole dataset!
