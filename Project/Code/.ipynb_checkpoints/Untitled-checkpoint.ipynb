# %% [markdown]
# # Machine Learning: From Theory to Practise -- Project
# ## Master Data Science -- Université Paris Saclay
# ## Natural Naguage Processing Applied to Sentiment Analysis
# #### Authors: Johann Faouzi, Hicham Janati, Mélanie Finas, Peter Martigny
#
# #### Amazon Book Reviews - https://archive.ics.uci.edu/ml/datasets/Amazon+book+reviews

# %% [markdown]
# ### The goal of this project is to predict how much a reader would rate a book based on her/his textual review
# ### We will follow this methodology:
#
# #### Short exploration
#
# #### Cleaning of reviews
#
# #### Bag of words model to create features
#
# #### Classification & Regression algorithms to predict the ratings
#
# #### Using [word2vec](https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) to embed words into contextual vectors, then use average vectors or clustering to create features for ML algorithms

# %%
## Some useful package imports
import pandas as pd
from bs4 import BeautifulSoup
import time
import numpy as np

import nltk
from nltk.stem.porter import *
import string
from nltk.tokenize import TweetTokenizer
token = TweetTokenizer()
stemmer = PorterStemmer() 
from nltk.corpus import stopwords # Import the stop word list
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load the datasets

# %%
# Load the first book
data = pd.read_csv('Paula_Hawkins-The-Girl-On-The-Train.csv', sep = '\t', header = None)
# Rename columns
data.columns = ['rating', 'tail', 'title', 'review']
data['book'] = 'Paula_Hawkins-The-Girl-On-The-Train'

# Load the second book
data1 = pd.read_csv('Andy-Weir-The-Martian.csv', sep = '\t', header = None)
# Rename columns
data1.columns = ['rating', 'tail', 'title', 'review']
data1['book'] = 'Andy-Weir-The-Martian'

# Concatenate into one dataframe
data = pd.concat((data, data1))
# Reset index and remove the index column
data = data.reset_index().ix[:, 1:]


############## Concatenate the other books ########################

data1 = pd.read_csv('Donna-Tartt-The-Goldfinch.csv', sep = '\t', header = None)
data1.columns = ['rating', 'tail', 'title', 'review']
data1['book'] = 'Donna-Tartt-The-Goldfinch'

data = pd.concat((data, data1))
data = data.reset_index().ix[:, 1:]

data1 = pd.read_csv('EL-James-Fifty-Shades-of-Grey.csv', sep = '\t', header = None)
data1.columns = ['rating', 'tail', 'title', 'review']
data1['book'] = 'EL-James-Fifty-Shades-of-Grey'

data = pd.concat((data, data1))
data = data.reset_index().ix[:, 1:]

data1 = pd.read_csv('Fillian_Flynn-Gone_Girl.csv', sep = '\t', header = None)
data1.columns = ['rating', 'tail', 'title', 'review']
data1['book'] = 'Fillian_Flynn-Gone_Girl'

data = pd.concat((data, data1))
data = data.reset_index().ix[:, 1:]

data1 = pd.read_csv('John-Green-The-Fault-in-our-Stars.csv', sep = '\t', header = None)
data1.columns = ['rating', 'tail', 'title', 'review']
data1['book'] = 'John-Green-The-Fault-in-our-Stars'

data = pd.concat((data, data1))
data = data.reset_index().ix[:, 1:]

data1 = pd.read_csv('Laura-Hillenbrand-Unbroken.csv', sep = '\t', header = None)
data1.columns = ['rating', 'tail', 'title', 'review']
data1['book'] = 'Laura-Hillenbrand-Unbroken'

########## Final concatenation ##############
data = pd.concat((data, data1))
data = data.reset_index().ix[:, 1:]

print('The dataframe contains ', data.shape[0], ' rows, which consist of reviews from ', len(data.book.unique()), 
      ' different books\n')

for book in data.book.unique():
    print(book, ' has ', len(data[data.book == book]), ' reviews')
# Out:
# The dataframe contains  219242  rows, which consist of reviews from  7  different books
#
# Paula_Hawkins-The-Girl-On-The-Train  has  37139  reviews
# Andy-Weir-The-Martian  has  22571  reviews
# Donna-Tartt-The-Goldfinch  has  22861  reviews
# EL-James-Fifty-Shades-of-Grey  has  32977  reviews
# Fillian_Flynn-Gone_Girl  has  41974  reviews
# John-Green-The-Fault-in-our-Stars  has  35844  reviews
# Laura-Hillenbrand-Unbroken  has  25876  reviews

# %%
print("In total, we have {} reviews.".format(data.shape[0]))
# Out:
# In total, we have 219242 reviews.

# %%
plt.hist(data.rating)
plt.xlabel('Ratings')
plt.ylabel('Number of ratings')
plt.title('Histogram of ratings')
plt.show()

# %%
#Plot for the new dataset (preprocessed)
plt.figure(figsize=(22.0, 22.0))
cmptr=1
for book in data.book.unique():
    plt.subplot(10,3,cmptr)
    plt.hist(data[data.book == book]['rating'])
    plt.tight_layout(pad=0.6, w_pad=2, h_pad=1.0)
    plt.xlabel('Rating')
    plt.ylabel('Number of ratings')
    plt.title(book)
    cmptr+=1
plt.show()

# %% [markdown]
# We notice that some books have mostly good ratings (e.g. "Unbroken"), whereas some others have more uniform rating distributions (e.g. "Gone Girl").

# %% [markdown]
# # Toy Dataset

# %% [markdown]
# #### We will use only a part of the reviews from the book "The Girl on the Train", Paula Hawkins

# %%
# We select only one book
single_book = data[data.book == 'Paula_Hawkins-The-Girl-On-The-Train']

# # We sample 10% of the dataset, and we keep the distribution of ratings
# toy_data = pd.DataFrame()
# for rating in data.rating.unique():
#     aux_df = single_book[single_book.rating == rating]
#     rows = aux_df.sample(frac=0.1)
#     toy_data = pd.concat((toy_data, rows))

# %%
# Here we will define negative, neutral and positive reviews
def sentiment(x):
    if x < 3:
        return -1
    if x == 3:
        return 0
    else:
        return 1
single_book['sentiment'] = single_book['rating'].apply(lambda x: sentiment(x))
# Out:
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.hist(single_book.sentiment)
plt.show()

# %% [markdown]
# Before doing anything, we observe that the target variable is clearly imbalanced.
# One solution to imbalanced data, when we want to separare the data into train and test sets, is that we want to keep the same distribution of the data in both sets. This is feasable with stratified sampling using sklearn.
# However, here, since the target variable is too much imbalanced, there's a high risk that any predictor will always predict the dominant class! Indeed, whatever happens, this will produce a very decent accuracy, but it is likely to be not effective for being discriminant.
# One solution is to keep all instances of non dominant class, and sampling over the dominant classes such that all classes are equivalantly represented. We will then have more confidance in our classification algorithm. The downside is that we loose some data...

# %%
print(single_book.sentiment.value_counts())
print('Minimum representation for classes:', single_book.sentiment.value_counts().min())
# Out:
#  1    25577
# -1     7399
#  0     4163
# Name: sentiment, dtype: int64
# Minimum representation for classes: 4163

# %%
# Index of positive, negative and neutral data
index_positive = list(single_book[single_book.sentiment == 1].index)
index_negative = list(single_book[single_book.sentiment == -1].index)
index_neutral = list(single_book[single_book.sentiment == 0].index)

# Sample over the negative and positive data
min_class = single_book.sentiment.value_counts().min()
print(min_class)
index_positive_sample = list(single_book.ix[index_positive].sample(min_class).index)
index_negative_sample = list(single_book.ix[index_negative].sample(min_class).index)
index_final = index_negative_sample + index_positive_sample + index_neutral

# We define our toy dataset with balanced classes
toy_data = single_book.ix[index_final]
# Reset the index
toy_data = toy_data.reset_index().ix[:, 1:]

# Plot the histogram of classes
plt.hist(toy_data.sentiment)
plt.title('HIstogram of balanced classes')
plt.xlabel('Sentiment')
plt.ylabel('Number of occurrences')
plt.show()
# Out:
# 4163

# %%
# Size of the resulting toy dataset
print('Our toy dataset has now {} rows'.format(toy_data.shape[0]))
# Out:
# Our toy dataset has now 12489 rows

# %% [markdown]
# ## Let's have a look at the reviews

# %%
toy_data.review[10]
# Out:
# '<span class="a-size-base review-text">Interesting way to tell the story but can be a little confusing until the main characters and dates are understood.</span>'

# %% [markdown]
# It looks that the reviews are in HTML format! We will remove first remove html tages. As additional pre processing, we will also remove non-letters characters, use lowercases everywhere and remove stopwords (the words that occur too often like "the", "a", ... as they might not contain a lot of information and removing them reduces a lot the dimension of the problem.

# %%
def process(x):
    '''
    Function to clear the html tags, then remove non-letters characters, 
    lowercase, remove stopwords, then join the resulting as a full text
    '''

    # Clean html tags
    review = BeautifulSoup(x, "html.parser").get_text() 
    
    # Remove non letters     
    letters = re.sub("[^a-zA-Z]", " ", review) 
    
    # Lowercase and split to words
    words = letters.lower().split()                              
    
    # Join to produce the cleaned texts 

    return(" ".join(words))

# %% [markdown]
# We create the column with clean reviews (according to your machine, this can take a little time):

# %%
toy_data['processed'] = toy_data['review'].apply(lambda x: process(x))

# %%
# An example
toy_data.processed[10]
# Out:
# 'interesting way to tell the story but can be a little confusing until the main characters and dates are understood'

# %% [markdown]
# # Strategy 1:  Bag of Words Model

# %% [markdown]
# In the model of Bag of words, we simplify the text by summarizing it as a list of distinct words, each being described by its relative frequency. Hence, we get rid of word order dependency, and observe only if a word occurs often for positive ratings or for negative ratings, and we would like to investigate if this is sufficient to predict well the ratings.

# %% [markdown]
# We first use the Count Vectorizer from scikit learn. Moreover, we will restraint to the $5000$ most frequent words (computation time).

# %%
print("Wait, bags of words are being created!!\n")
from sklearn.feature_extraction.text import CountVectorizer
# Define the function that will compute the frequencies for all words
vectorizer = CountVectorizer(analyzer = "word", tokenizer = None, preprocessor = None, stop_words = None, max_features = 5000) 
# Use the fit_transform method to learn the vocabulary and then transform the training data into vectors
train_data_features = vectorizer.fit_transform(toy_data['processed'])
# Convert the result to an array
train_data_features = train_data_features.toarray()

print('The model has been learned!')
# Out:
# Wait, bags of words are being created!!
#
# The model has been learned!

# %% [markdown]
# As the words usually appear in only a few reviews, the matrix produced is likely to be very sparse!

# %%
# Examine the size and the sparsity of the tfidf_matrix
size = train_data_features.shape
sparsity = np.count_nonzero(train_data_features) / train_data_features.size

print('The matrix is of shape '+str(size)+' and its sparsity is '+str(sparsity))
# Out:
# The matrix is of shape (12489, 5000) and its sparsity is 0.004718392185122908

# %% [markdown]
# We observe that the matrix is constituted of around $99.6 \%$ zeros!

# %%
print('There are ', train_data_features.shape[0], ' rows and ', train_data_features.shape[1], ' features')
# Out:
# There are  12489  rows and  5000  features

# %%
# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print(vocab)
# Out:
# ['aa', 'abandon', 'abandoned', 'abandonment', 'abdic', 'ability', 'able', 'abnormal', 'aboard', 'abound', 'about', 'above', 'abrupt', 'absence', 'absent', 'absolute', 'absolutely', 'absorb', 'absorbed', 'absorbing', 'absorption', 'absurd', 'abundance', 'abuse', 'abused', 'abuser', 'abusers', 'abusive', 'abyss', 'accents', 'accept', 'acceptable', 'accessible', 'accident', 'accidental', 'acclaim', 'acclaimed', 'accomplish', 'accomplished', 'according', 'account', 'accounting', 'accounts', 'accurate', 'accurately', 'achieve', 'achieved', 'aching', 'acknowledge', 'acquainted', 'acquired', 'across', 'act', 'acted', 'acting', 'action', 'actions', 'active', 'actively', 'activities', 'actors', 'actress', 'actresses', 'acts', 'actual', 'actually', 'adaptation', 'add', 'added', 'addict', 'addicted', 'addicting', 'addiction', 'addictions', 'addictive', 'addicts', 'adding', 'addition', 'additional', 'additionally', 'addled', 'address', 'addressed', 'adds', 'ade', 'adept', 'adeptly', 'adjacent', 'adjectives', 'adjust', 'adjusted', 'admirable', 'admiration', 'admire', 'admiring', 'admit', 'admittedly', 'adore', 'adored', 'adult', 'adulterer', 'adultery', 'advance', 'advanced', 'advantage', 'adventure', 'adventures', 'advertised', 'advice', 'advise', 'afar', 'affair', 'affairs', 'affect', 'affected', 'affectionately', 'affects', 'affirming', 'afford', 'afraid', 'after', 'aftermath', 'afternoon', 'afterthought', 'afterwards', 'again', 'against', 'agatha', 'age', 'ages', 'aggressive', 'ago', 'agony', 'agree', 'agreed', 'agrees', 'ah', 'aha', 'ahead', 'aid', 'aimless', 'air', 'airplane', 'airport', 'aka', 'akin', 'al', 'ala', 'alarm', 'alas', 'albeit', 'alchoholic', 'alcholic', 'alcohol', 'alcoholic', 'alcoholics', 'alcoholism', 'alert', 'alfred', 'alike', 'alittle', 'alive', 'all', 'alley', 'allow', 'allowed', 'allowing', 'allows', 'almost', 'alone', 'along', 'alot', 'already', 'alright', 'also', 'altering', 'alternate', 'alternated', 'alternately', 'alternates', 'alternating', 'alternative', 'alternatively', 'although', 'altogether', 'always', 'am', 'amateur', 'amateurish', 'amazed', 'amazes', 'amazing', 'amazingly', 'amazon', 'ambivalent', 'american', 'amiss', 'amnesia', 'among', 'amongst', 'amount', 'amusing', 'amy', 'an', 'analysis', 'and', 'andy', 'anger', 'angle', 'angry', 'angst', 'anna', 'anne', 'annoy', 'annoyed', 'annoying', 'annoyingly', 'another', 'answer', 'answered', 'answers', 'antagonist', 'anti', 'anticipate', 'anticipated', 'anticipating', 'anticipation', 'anticlimactic', 'antics', 'antsy', 'anxiety', 'anxious', 'any', 'anybody', 'anyhow', 'anymore', 'anyone', 'anything', 'anytime', 'anyway', 'anywhere', 'apart', 'apparent', 'apparently', 'appeal', 'appealing', 'appear', 'appearances', 'appeared', 'appears', 'appointment', 'appreciate', 'appreciated', 'appreciation', 'approach', 'approached', 'approaching', 'appropriate', 'appropriately', 'apt', 'are', 'area', 'areas', 'aren', 'armchair', 'arms', 'around', 'arranged', 'arresting', 'arrive', 'arrived', 'art', 'artist', 'as', 'ashamed', 'ashbury', 'aside', 'ask', 'asked', 'asking', 'asks', 'asleep', 'aspect', 'aspects', 'assigned', 'assignment', 'assistant', 'association', 'assume', 'assumed', 'assuming', 'assumption', 'assumptions', 'at', 'ate', 'atmosphere', 'atmospheric', 'atop', 'attached', 'attacking', 'attempt', 'attempted', 'attempting', 'attempts', 'attention', 'attentive', 'attitude', 'attract', 'attracted', 'attraction', 'attractive', 'attributed', 'attributes', 'atypical', 'audible', 'audience', 'audio', 'audiobook', 'audiobooks', 'august', 'aunt', 'authentic', 'author', 'authoress', 'authors', 'available', 'average', 'avid', 'avidly', 'avoid', 'avoided', 'await', 'awaiting', 'awake', 'awakes', 'award', 'aware', 'awareness', 'away', 'awe', 'awesome', 'awful', 'awhile', 'awkward', 'awry', 'babies', 'baby', 'back', 'backdrop', 'background', 'backgrounds', 'backing', 'backs', 'backstory', 'backtrack', 'backward', 'backwards', 'backyard', 'backyards', 'bad', 'badly', 'ba ...

# %%
# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print(count, tag)
# Out:
# 5 aa
# 2 abandon
# 4 abandoned
# 2 abandonment
# 5 abdic
# 15 ability
# 153 able
# 4 abnormal
# 2 aboard
# 3 abound
# 1289 about
# 17 above
# 6 abrupt
# 3 absence
# 3 absent
# 7 absolute
# 98 absolutely
# 2 absorb
# 29 absorbed
# 29 absorbing
# 2 absorption
# 5 absurd
# 2 abundance
# 33 abuse
# 8 abused
# 2 abuser
# 3 abusers
# 16 abusive
# 3 abyss
# 2 accents
# 13 accept
# 4 acceptable
# 3 accessible
# 4 accident
# 2 accidental
# 4 acclaim
# 3 acclaimed
# 2 accomplish
# 6 accomplished
# 3 according
# 7 account
# 2 accounting
# 10 accounts
# 14 accurate
# 6 accurately
# 3 achieve
# 3 achieved
# 3 aching
# 2 acknowledge
# 2 acquainted
# 3 acquired
# 24 across
# 16 act
# 6 acted
# 2 acting
# 67 action
# 49 actions
# 6 active
# 5 actively
# 4 activities
# 6 actors
# 2 actress
# 2 actresses
# 8 acts
# 24 actual
# 161 actually
# 4 adaptation
# 35 add
# 27 added
# 4 addict
# 7 addicted
# 9 addicting
# 38 addiction
# 8 addictions
# 12 addictive
# 3 addicts
# 16 adding
# 12 addition
# 4 additional
# 2 additionally
# 2 addled
# 3 address
# 4 addressed
# 12 adds
# 2 ade
# 2 adept
# 2 adeptly
# 2 adjacent
# 2 adjectives
# 4 adjust
# 3 adjusted
# 7 admirable
# 2 admiration
# 7 admire
# 3 admiring
# 37 admit
# 6 admittedly
# 8 adore
# 2 adored
# 13 adult
# 5 adulterer
# 7 adultery
# 7 advance
# 3 advanced
# 6 advantage
# 3 adventure
# 2 adventures
# 10 advertised
# 7 advice
# 5 advise
# 2 afar
# 24 affair
# 9 affairs
# 4 affect
# 4 affected
# 2 affectionately
# 4 affects
# 2 affirming
# 3 afford
# 4 afraid
# 440 after
# 2 aftermath
# 21 afternoon
# 2 afterthought
# 3 afterwards
# 179 again
# 20 against
# 6 agatha
# 6 age
# 9 ages
# 3 aggressive
# 23 ago
# 2 agony
# 40 agree
# 4 agreed
# 2 agrees
# 4 ah
# 3 aha
# 33 ahead
# 3 aid
# 2 aimless
# 9 air
# 11 airplane
# 8 airport
# 3 aka
# 3 akin
# 2 al
# 2 ala
# 2 alarm
# 11 alas
# 7 albeit
# 4 alchoholic
# 2 alcholic
# 109 alcohol
# 316 alcoholic
# 18 alcoholics
# 126 alcoholism
# 16 alert
# 31 alfred
# 14 alike
# 2 alittle
# 14 alive
# 1804 all
# 7 alley
# 7 allow
# 5 allowed
# 5 allowing
# 11 allows
# 214 almost
# 21 alone
# 192 along
# 9 alot
# 76 already
# 5 alright
# 337 also
# 2 altering
# 7 alternate
# 3 alternated
# 3 alternately
# 10 alternates
# 81 alternating
# 2 alternative
# 2 alternatively
# 181 although
# 5 altogether
# 143 always
# 318 am
# 2 amateur
# 3 amateurish
# 11 amazed
# 2 amazes
# 138 amazing
# 10 amazingly
# 40 amazon
# 4 ambivalent
# 10 american
# 2 amiss
# 7 amnesia
# 28 among
# 6 amongst
# 18 amount
# 4 amusing
# 6 amy
# 1243 an
# 6 analysis
# 11094 and
# 4 andy
# 5 anger
# 5 angle
# 14 angry
# 12 angst
# 274 anna
# 6 anne
# 4 annoy
# 33 annoyed
# 80 annoying
# 2 annoyingly
# 348 another
# 11 answer
# 6 answered
# 20 answers
# 2 antagonist
# 12 anti
# 10 anticipate
# 8 anticipated
# 6 anticipating
# 6 anticipation
# 4 anticlimactic
# 3 antics
# 2 antsy
# 8 anxiety
# 19 anxious
# 493 any
# 2 anybody
# 2 anyhow
# 16 anymore
# 267 anyone
# 132 anything
# 8 anytime
# 42 anyway
# 18 anywhere
# 27 apart
# 8 apparent
# 10 apparently
# 19 appeal
# 14 appealing
# 18 appear
# 3 appearances
# 10 appeared
# 12 appears
# 3 appointment
# 24 appreciate
# 16 appreciated
# 3 appreciation
# 25 approach
# 3 approached
# 4 approaching
# 5 appropriate
# 3 appropriately
# 5 apt
# 1438 are
# 7 area
# 5 areas
# 39 aren
# 3 armchair
# 4 arms
# 195 around
# 4 arranged
# 3 arresting
# 3 arrive
# 4 arrived
# 7 art
# 3 artist
# 2173 as
# 5 ashamed
# 2 ashbury
# 33 aside
# 11 ask
# 6 asked
# 9 asking
# 2 asks
# 7 asleep
# 23 aspect
# 14 aspects
# 2 assigned
# 5 assignment
# 2 assistant
# 3 association
# 3 assume
# 4 assumed
# 4 assuming
# 2 assumption
# 11 assumptions
# 1602 at
# 2 ate
# 6 atmosphere
# 3 atmospheric
# 2 atop
# 5 attached
# 2 attacking
# 11 attempt
# 2 attempted
# 6 attempting
# 13 attempts
# 357 attention
# 3 attentive
# 7 attitude
# 2 attract
# 4 attracted
# 5 attraction
# 11 attractive
# 2 attributed
# 3 attributes
# 2 atypical
# 18 audible
# 9 audience
# 34 audio
# 14 audiobook
# 2 audiobooks
# 2 august
# 2 aunt
# 8 authentic
# 768 author
# 2 authoress
# 46 authors
# 10 available
# 21 average
# 23 avid
# 2 avidly
# 19 avoid
# 2 avoided
# 3 await
# 2 awaiting
# 4 awake
# 2 awakes
# 3 award
# 14 aware
# 3 awareness
# 173 away
# 3 awe
# 116 awesome
# 46 awful
# 63 awhile
# 4 awkward
# 2 awry
# 6 babies
# 58 baby
# 403 back
# 3 backdrop
# 12 background
# 4 backgrounds
# 2 backing
# 9 backs
# 7 backstory
# 3 backtrack
# 2 backward
# 2 backwards
# 4 backyard
# 4 backyards
# 274 bad
# 20 badly
# 4 baffled
# 8 bag
# 3 baggage
# 6 balance
# 4 balanced
# 3 balcony
# 3 baldacci
# 3 ball
# 2 baloney
# 4 bam
# 4 banal
# 2 band
# 4 bang
# 4 bank
# 2 bar
# 2 barbara
# 3 bare
# 27 barely
# 5 barren
# 4 base
# 57 based
# 13 basic
# 18 basically
# 2 basing
# 3 basis
# 2 basket
# 3 bastard
# 2 bath
# 2 battered
# 9 battle
# 3 battling
# 2 bbc
# 4 bc
# 1385 be
# 109 beach
# 3 beans
# 4 bear
# 2 bears
# 5 beat
# 2 beating
# 3 beats
# 25 beautiful
# 20 beautifully
# 5 beauty
# 146 became
# 784 because
# 93 become
# 97 becomes
# 14 becoming
# 16 bed
# 2 bedroom
# 11 bedtime
# 444 been
# 272 before
# 4 beforehand
# 2 befriend
# 3 beg
# 51 began
# 3 begging
# 34 begin
# 2 begining
# 404 beginning
# 32 begins
# 3 begs
# 6 behave
# 3 behaving
# 44 behavior
# 9 behaviors
# 2 behaviour
# 2 behaviours
# 35 behind
# 294 being
# 8 beings
# 2 belief
# 2 beliefs
# 5 believability
# 146 believable
# 2 believably
# 140 believe
# 3 believeable
# 14 believed
# 20 believes
# 8 believing
# 2 bell
# 5 belong
# 2 belonged
# 3 ben
# 4 bend
# 2 bends
# 4 beneath
# 4 benefit
# 2 bent
# 2 bereaved
# 4 beside
# 6 besides
# 539 best
# 31 bestseller
# 5 bestsellers
# 6 bet
# 4 betray
# 16 betrayal
# 2 betrayed
# 2 bette
# 491 better
# 192 between
# 4 beware
# 22 beyond
# 4 bias
# 109 big
# 6 bigger
# 15 biggest
# 2 bile
# 8 bill
# 5 billed
# 12 binding
# 5 binge
# 8 binges
# 2 bipolar
# 2 bird
# 552 bit
# 2 bitch
# 2 bitchy
# 7 biter
# 2 bites
# 4 biting
# 12 bits
# 10 bitter
# 12 bizarre
# 32 black
# 10 blacked
# 6 blacking
# 46 blackout
# 80 blackouts
# 10 blacks
# 13 blah
# 17 blame
# 4 blames
# 9 bland
# 4 blast
# 8 bleak
# 3 bleinham
# 5 blend
# 2 blended
# 6 blind
# 2 blinded
# 2 bliss
# 4 blissfully
# 3 blizzard
# 4 block
# 3 blockbuster
# 2 blocks
# 2 blog
# 6 blogspot
# 2 blonde
# 8 blood
# 2 bloodied
# 7 bloody
# 7 blow
# 3 blowing
# 6 blown
# 2 blue
# 3 blunders
# 6 blunt
# 4 blur
# 7 blurb
# 4 blurbs
# 2 blurred
# 2 blurry
# 9 board
# 2 bodies
# 10 body
# 3 bogged
# 2 bold
# 2 bomb
# 4 bond
# 2 bonded
# 4 bone
# 4 bones
# 2 bonus
# 7641 book
# 6 bookclub
# 3 booked
# 546 books
# 3 bookstore
# 4 boom
# 5 boot
# 11 booze
# 4 borderline
# 3 bore
# 69 bored
# 6 boredom
# 264 boring
# 3 born
# 8 borrow
# 4 borrowed
# 116 both
# 21 bother
# 15 bothered
# 5 bothering
# 12 bottle
# 13 bottom
# 68 bought
# 3 bounced
# 4 bounces
# 6 bouncing
# 5 bound
# 3 bow
# 3 box
# 12 boy
# 8 boyfriend
# 11 brain
# 3 brave
# 10 bravo
# 18 break
# 3 breakfast
# 3 breaking
# 7 breaks
# 5 brealey
# 8 breath
# 4 breathe
# 4 bridget
# 5 brief
# 4 briefly
# 6 bright
# 3 brilliance
# 42 brilliant
# 17 brilliantly
# 28 bring
# 5 bringing
# 18 brings
# 3 brit
# 48 british
# 6 broke
# 28 broken
# 4 brother
# 21 brought
# 3 bruised
# 4 brutal
# 2 bucks
# 2 buddies
# 3 buffs
# 50 build
# 37 building
# 50 builds
# 5 buildup
# 27 built
# 3 bulk
# 2 bully
# 2 bumbling
# 3 bummed
# 3 bummer
# 4 bump
# 3 bumped
# 24 bunch
# 2 bundle
# 2 buried
# 4 burn
# 8 bus
# 4 business
# 9 busy
# 3 busybody
# 4175 but
# 4 buttons
# 59 buy
# 25 buying
# 17 buzz
# 995 by
# 3 calendar
# 3 caliber
# 39 call
# 22 called
# 10 calling
# 17 calls
# 102 came
# 924 can
# 100 cannot
# 12 cant
# 11 capable
# 2 capitalize
# 4 captivate
# 24 captivated
# 3 captivates
# 66 captivating
# 5 captive
# 6 capture
# 21 captured
# 16 captures
# 2 capturing
# 20 car
# 5 card
# 2 cardboard
# 208 care
# 27 cared
# 6 career
# 2 careers
# 10 careful
# 14 carefully
# 8 cares
# 2 caricatures
# 21 caring
# 6 carried
# 3 carries
# 5 carry
# 58 case
# 8 cases
# 3 cash
# 28 cast
# 4 casting
# 4 casual
# 2 cat
# 24 catch
# 10 catches
# 5 catching
# 2 categories
# 10 category
# 32 cathy
# 2 catty
# 66 caught
# 17 cause
# 15 caused
# 10 causes
# 7 causing
# 4 caution
# 3 cautionary
# 2 cautiously
# 2 cd
# 3 cent
# 10 center
# 16 centered
# 7 centers
# 21 central
# 2 cereal
# 44 certain
# 114 certainly
# 2 chacters
# 3 chain
# 11 chair
# 2 chalk
# 13 challenge
# 3 challenged
# 9 challenges
# 13 challenging
# 39 chance
# 4 chances
# 56 change
# 37 changed
# 32 changes
# 46 changing
# 3 channel
# 2 chaotic
# 327 chapter
# 301 chapters
# 1458 character
# 9 characteristics
# 17 characterization
# 12 characterizations
# 2 characterizing
# 2732 characters
# 2 characterwho
# 2 charge
# 2 charges
# 3 charm
# 3 chart
# 2 charts
# 3 chase
# 8 cheap
# 5 cheat
# 19 cheated
# 5 cheater
# 3 cheaters
# 25 cheating
# 26 check
# 3 checked
# 5 checking
# 10 cheer
# 5 cheering
# 4 cheers
# 4 cheesy
# 5 chic
# 5 chicago
# 13 chick
# 37 child
# 2 childless
# 8 children
# 2 childs
# 15 chilling
# 4 chills
# 25 choice
# 45 choices
# 16 choose
# 2 choosing
# 3 choppy
# 2 chord
# 6 chore
# 2 chores
# 23 chose
# 12 chosen
# 6 christie
# 2 christmas
# 5 chronic
# 9 chronological
# 5 chronologically
# 5 chronology
# 4 chugging
# 2 chugs
# 2 churning
# 2 cinematic
# 2 circle
# 3 circles
# 2 circumstance
# 12 circumstances
# 11 city
# 4 claim
# 3 claims
# 3 clarify
# 6 clarity
# 2 clark
# 17 class
# 11 classic
# 4 classics
# 2 classify
# 2 classy
# 4 claustrophobia
# 2 claustrophobic
# 7 clean
# 3 cleaning
# 59 clear
# 10 clearer
# 34 clearly
# 90 clever
# 28 cleverly
# 6 clich
# 15 cliche
# 3 cliched
# 3 cliches
# 2 clicks
# 3 client
# 2 cliff
# 2 cliffhanger
# 3 climactic
# 10 climatic
# 44 climax
# 2 clinging
# 2 clip
# 2 clone
# 87 close
# 6 closed
# 2 closely
# 7 closer
# 4 closest
# 2 closing
# 6 closure
# 14 clothes
# 2 clothing
# 3 clouded
# 4 cloudy
# 191 club
# 3 clubs
# 11 clue
# 5 clueless
# 50 clues
# 2 clunky
# 3 co
# 2 coarse
# 18 coaster
# 3 coben
# 2 cocktail
# 7 coffee
# 3 coherent
# 3 cohesive
# 5 coincidences
# 14 cold
# 3 collection
# 8 college
# 4 color
# 3 colorful
# 12 com
# 9 combination
# 3 combine
# 6 combined
# 129 come
# 75 comes
# 4 comfort
# 9 comfortable
# 162 coming
# 3 command
# 7 comment
# 3 commentary
# 5 comments
# 4 commitment
# 18 committed
# 24 common
# 35 commute
# 60 commuter
# 4 commuters
# 9 commutes
# 13 commuting
# 7 comparable
# 37 compare
# 107 compared
# 17 comparing
# 55 comparison
# 48 comparisons
# 9 compassion
# 26 compelled
# 142 compelling
# 4 complain
# 3 complained
# 4 complaining
# 20 complaint
# 3 complaints
# 48 complete
# 10 completed
# 119 completely
# 3 completion
# 106 complex
# 3 complexities
# 12 complexity
# 29 complicated
# 4 complication
# 5 compliment
# 3 comprehend
# 3 compromised
# 7 compulsive
# 6 conceive
# 8 conceived
# 3 concentrate
# 3 concentration
# 36 concept
# 5 concerned
# 4 concerning
# 3 concerns
# 3 conclude
# 76 conclusion
# 7 conclusions
# 4 concrete
# 7 condition
# 4 conditions
# 6 confession
# 5 confidence
# 3 confirmation
# 6 confirmed
# 3 conflict
# 3 confront
# 3 confrontation
# 3 confronts
# 8 confuse
# 84 confused
# 325 confusing
# 3 confusingly
# 25 confusion
# 5 congratulations
# 5 conjured
# 20 connect
# 22 connected
# 6 connecting
# 20 connection
# 13 connections
# 3 conscience
# 3 conscious
# 5 consciousness
# 5 consequences
# 23 consider
# 15 considered
# 8 considering
# 3 considers
# 5 consistent
# 6 consistently
# 41 constant
# 54 constantly
# 15 constructed
# 5 consumed
# 3 consumption
# 4 contact
# 3 contain
# 3 contained
# 8 contains
# 12 contemporary
# 4 contempt
# 3 contemptible
# 17 content
# 6 contents
# 4 context
# 10 continually
# 48 continue
# 34 continued
# 32 continues
# 10 continuing
# 3 continuity
# 8 continuous
# 4 continuously
# 4 contributed
# 31 contrived
# 30 control
# 7 controlling
# 9 convenient
# 7 conveniently
# 4 conversation
# 7 conversations
# 3 convey
# 4 conveys
# 6 convince
# 11 convinced
# 12 convincing
# 18 convoluted
# 7 cool
# 5 cop
# 10 cope
# 3 coping
# 19 copy
# 5 copycat
# 6 core
# 8 corkscrew
# 5 corner
# 16 correct
# 7 correctly
# 3 cost
# 974 could
# 1225 couldn
# 13 couldnt
# 5 count
# 3 counted
# 4 country
# 246 couple
# 4 coupled
# 15 couples
# 51 course
# 30 cover
# 3 covered
# 3 covers
# 3 crack
# 46 crafted
# 7 crap
# 3 crash
# 4 craziness
# 103 crazy
# 22 create
# 27 created
# 15 creates
# 18 creating
# 28 creative
# 5 creatively
# 3 creativity
# 3 creature
# 14 credibility
# 9 credible
# 8 credit
# 3 credits
# 6 creeps
# 34 creepy
# 3 cried
# 59 crime
# 9 criminal
# 9 cringe
# 3 cringed
# 5 cringing
# 4 crisp
# 3 critic
# 13 critical
# 14 criticism
# 7 critics
# 3 critique
# 9 cross
# 4 crosses
# 6 crucial
# 3 crude
# 6 cruel
# 4 cry
# 22 culprit
# 4 culture
# 3 cumbersome
# 21 cup
# 16 curiosity
# 28 curious
# 22 current
# 9 currently
# 4 curve
# 4 customer
# 7 cut
# 84 daily
# 9 damage
# 29 damaged
# 3 damien
# 7 damn
# 11 danger
# 10 dangerous
# 8 dare
# 190 dark
# 10 darker
# 5 darkest
# 11 darkness
# 4 darn
# 29 date
# 3 dated
# 122 dates
# 20 daughter
# 386 day
# 4 daydreaming
# 3 daydreams
# 223 days
# 3 de
# 23 dead
# 35 deal
# 8 dealing
# 7 dealt
# 4 dear
# 14 death
# 3 deaths
# 3 debating
# 35 debut
# 4 decade
# 10 deceit
# 55 decent
# 11 deception
# 5 deceptive
# 13 decide
# 55 decided
# 3 decidedly
# 11 decides
# 4 decipher
# 18 decision
# 44 decisions
# 3 decline
# 3 dedicate
# 5 deed
# 42 deep
# 4 deepens
# 32 deeper
# 35 deeply
# 4 def
# 3 defense
# 7 definately
# 16 defined
# 24 definite
# 362 definitely
# 4 definition
# 4 deftly
# 13 degree
# 3 deleted
# 4 delicate
# 3 delicious
# 4 deliciously
# 3 delight
# 3 delightful
# 12 deliver
# 13 delivered
# 5 delivers
# 5 delivery
# 8 delusional
# 3 delusions
# 7 delve
# 4 delves
# 13 demons
# 3 denial
# 11 denouement
# 3 department
# 3 dependency
# 7 dependent
# 3 depending
# 6 depicted
# 8 depiction
# 51 depressed
# 252 depressing
# 29 depression
# 4 depressive
# 50 depth
# 6 deranged
# 5 derivative
# 3 descent
# 15 describe
# 28 described
# 13 describes
# 8 describing
# 27 description
# 37 descriptions
# 24 descriptive
# 10 deserve
# 13 deserved
# 16 deserves
# 3 deserving
# 4 design
# 4 desirable
# 16 desire
# 4 desired
# 9 despair
# 22 desperate
# 16 desperately
# 8 desperation
# 12 despicable
# 3 despise
# 4 despised
# 64 despite
# 3 despondent
# 4 destination
# 3 destroy
# 4 destroyed
# 3 destruct
# 7 destruction
# 14 destructive
# 38 detail
# 13 detailed
# 3 detailing
# 67 details
# 16 detective
# 8 detectives
# 3 deter
# 6 determination
# 14 determine
# 12 determined
# 3 detract
# 4 detracted
# 7 devastating
# 20 develop
# 194 developed
# 34 developing
# 210 development
# 23 develops
# 23 device
# 3 devious
# 6 devoid
# 3 devolves
# 3 devoted
# 6 devour
# 7 devoured
# 3 dialing
# 4 dialog
# 41 dialogue
# 3 diaries
# 11 diary
# 1210 did
# 927 didn
# 10 didnt
# 8 die
# 8 died
# 3 dies
# 11 difference
# 7 differences
# 562 different
# 4 differentiate
# 10 differently
# 211 difficult
# 20 difficulty
# 4 dig
# 5 dimension
# 32 dimensional
# 3 dimensions
# 5 dinner
# 5 direct
# 25 direction
# 7 directions
# 4 directly
# 3 dirt
# 3 dirty
# 3 dis
# 9 disagree
# 33 disappearance
# 16 disappeared
# 24 disappears
# 31 disappoint
# 211 disappointed
# 76 disappointing
# 45 disappointment
# 3 disappoints
# 5 disbelief
# 3 discern
# 4 disclaimer
# 3 disconcerting
# 3 disconnected
# 23 discover
# 11 discovered
# 3 discovering
# 9 discovers
# 8 discovery
# 16 discuss
# 4 discussed
# 5 discussing
# 26 discussion
# 10 disease
# 6 disfunctional
# 3 disguised
# 5 disgust
# 8 disgusted
# 5 disgusting
# 3 disillusioned
# 26 disjointed
# 3 dislikable
# 23 dislike
# 28 disliked
# 3 dislikes
# 7 dismal
# 3 disorder
# 5 display
# 3 disregard
# 3 dissapointed
# 7 distance
# 4 distinct
# 5 distinctive
# 4 distinctly
# 6 distinguish
# 3 distorted
# 4 distract
# 3 distracted
# 4 distracting
# 8 distraction
# 4 distrust
# 18 disturbed
# 35 disturbing
# 3 dive
# 4 diverse
# 6 diversion
# 4 divided
# 22 divorce
# 33 divorced
# 7 divorcee
# 4 divulge
# 414 do
# 7 doctor
# 238 does
# 148 doesn
# 7 dog
# 53 doing
# 12 domestic
# 3 dominated
# 624 don
# 353 done
# 11 dont
# 8 door
# 22 doors
# 4 dots
# 8 double
# 24 doubt
# 4 doubts
# 2153 down
# 5 downer
# 3 downfall
# 4 downhill
# 4 download
# 18 downloaded
# 5 downs
# 3 downside
# 3 downtrodden
# 8 downward
# 4 dozen
# 5 dr
# 32 drag
# 66 dragged
# 9 dragging
# 6 draggy
# 6 dragon
# 18 drags
# 69 drama
# 3 dramas
# 17 dramatic
# 9 drank
# 18 draw
# 4 drawback
# 7 drawing
# 118 drawn
# 24 draws
# 5 dreadful
# 12 dream
# 3 dreamed
# 3 dreaming
# 12 dreams
# 4 dreamworks
# 16 dreary
# 26 drew
# 42 drink
# 4 drinker
# 159 drinking
# 21 drinks
# 4 drip
# 12 drive
# 5 drivel
# 19 driven
# 9 drives
# 6 driving
# 6 drop
# 7 dropped
# 3 drops
# 11 drove
# 3 drowning
# 4 drug
# 191 drunk
# 45 drunken
# 4 drunkenness
# 4 drunks
# 4 dry
# 3 dual
# 51 due
# 37 dull
# 17 dumb
# 3 dumbest
# 11 dun
# 26 dunnit
# 58 during
# 3 duties
# 6 dying
# 4 dynamic
# 17 dysfunction
# 71 dysfunctional
# 3 dysfunctionality
# 519 each
# 6 eager
# 22 earlier
# 97 early
# 3 earned
# 12 earth
# 25 easier
# 46 easily
# 425 easy
# 4 eat
# 3 eating
# 5 ebook
# 176 edge
# 5 edgy
# 4 edited
# 10 editing
# 4 edition
# 5 editor
# 3 educated
# 3 eerie
# 9 effect
# 6 effective
# 3 effectively
# 9 effects
# 36 effort
# 4 effortlessly
# 6 eh
# 5 eight
# 95 either
# 4 elaborate
# 14 element
# 18 elements
# 96 else
# 4 elsewhere
# 6 embarrassed
# 5 embedded
# 8 emerge
# 4 emily
# 13 emotion
# 39 emotional
# 16 emotionally
# 26 emotions
# 7 empathetic
# 15 empathize
# 38 empathy
# 3 emphasis
# 6 employed
# 3 employs
# 8 empty
# 3 enabler
# 4 encounters
# 3 encourage
# 3 encouraged
# 1735 end
# 5 endearing
# 3 endeavor
# 110 ended
# 1048 ending
# 9 endings
# 12 endless
# 50 ends
# 3 endure
# 3 enduring
# 3 enemy
# 4 energy
# 5 engage
# 67 engaged
# 120 engaging
# 26 england
# 29 english
# 25 engrossed
# 55 engrossing
# 3 enhanced
# 4 enhances
# 311 enjoy
# 206 enjoyable
# 1051 enjoyed
# 18 enjoying
# 11 enjoyment
# 31 enjoys
# 4 enormous
# 283 enough
# 8 entangled
# 4 enter
# 5 entertain
# 33 entertained
# 237 entertaining
# 18 entertainment
# 18 enthralled
# 14 enthralling
# 8 enticing
# 111 entire
# 24 entirely
# 3 entirety
# 3 entrance
# 7 entries
# 4 entwined
# 3 envision
# 3 envy
# 7 episode
# 5 episodes
# 3 epitome
# 15 equally
# 3 er
# 3 ereader
# 6 errors
# 11 escape
# 133 especially
# 5 esque
# 3 essence
# 5 essential
# 3 essentially
# 5 established
# 12 esteem
# 46 etc
# 501 even
# 28 evening
# 5 evenings
# 20 event
# 110 events
# 44 eventually
# 187 ever
# 337 every
# 4 everybody
# 44 everyday
# 176 everyone
# 105 everything
# 3 everytime
# 15 everywhere
# 4 evidence
# 3 evident
# 5 evie
# 14 evil
# 6 evoke
# 4 evolve
# 10 evolved
# 9 evolves
# 3 evolving
# 178 ex
# 7 exact
# 42 exactly
# 4 exaggerated
# 28 example
# 3 examples
# 3 exasperating
# 3 exceeded
# 429 excellent
# 12 excellently
# 61 except
# 5 exception
# 9 exceptional
# 6 exceptionally
# 7 excessive
# 3 exchange
# 28 excited
# 22 excitement
# 164 exciting
# 3 excruciatingly
# 10 excuse
# 9 executed
# 3 execution
# 3 exhausted
# 7 exhausting
# 4 exhilarating
# 5 existence
# 96 expect
# 4 expectation
# 51 expectations
# 140 expected
# 53 expecting
# 3 expects
# 52 experience
# 11 experienced
# 20 experiences
# 5 experiencing
# 5 expert
# 10 expertly
# 12 explain
# 5 explained
# 8 explaining
# 5 explains
# 9 explanation
# 3 explicit
# 6 exploration
# 4 explored
# 5 explores
# 3 exploring
# 5 exposed
# 4 expressed
# 5 extent
# 12 extra
# 4 extraneous
# 8 extraordinary
# 11 extreme
# 59 extremely
# 16 eye
# 56 eyes
# 3 fabricated
# 40 fabulous
# 3 facade
# 21 face
# 6 facebook
# 4 faces
# 3 facet
# 4 facets
# 142 fact
# 4 factor
# 11 facts
# 3 factual
# 7 fail
# 25 failed
# 10 failure
# 3 faint
# 20 fair
# 55 fairly
# 5 fairy
# 3 fake
# 33 fall
# 4 fallen
# 14 falling
# 13 falls
# 6 false
# 18 familiar
# 41 family
# 3 famous
# 64 fan
# 4 fanciful
# 3 fancy
# 30 fans
# 7 fantasies
# 3 fantasized
# 8 fantasizes
# 4 fantasizing
# 111 fantastic
# 48 fantasy
# 128 far
# 4 farther
# 9 fascinated
# 62 fascinating
# 3 fascination
# 8 fashion
# 5 fashioned
# 403 fast
# 27 faster
# 11 fat
# 4 fatal
# 3 fate
# 5 fateful
# 4 fathom
# 12 fault
# 6 faults
# 7 faulty
# 3 fav
# 7 favor
# 3 favorable
# 66 favorite
# 17 favorites
# 3 favourite
# 13 fear
# 5 fears
# 4 feature
# 5 featured
# 10 features
# 4 featuring
# 4 february
# 5 fed
# 304 feel
# 90 feeling
# 48 feelings
# 42 feels
# 6 feet
# 34 fell
# 4 fellow
# 355 felt
# 166 female
# 8 females
# 3 fertility
# 16 fetched
# 304 few
# 68 fiction
# 4 fictional
# 3 fictions
# 4 fifty
# 5 fighting
# 3 figuratively
# 237 figure
# 232 figured
# 19 figuring
# 13 fill
# 39 filled
# 9 filler
# 37 film
# 6 films
# 50 final
# 7 finale
# 138 finally
# 362 find
# 19 finding
# 19 finds
# 48 fine
# 3 finest
# 6 finger
# 391 finish
# 359 finished
# 45 finishing
# 12 fire
# 11 fired
# 841 first
# 3 fist
# 14 fit
# 6 fits
# 7 fitting
# 57 five
# 4 fix
# 5 fizzled
# 10 flash
# 18 flashbacks
# 5 flashes
# 49 flat
# 5 flatmate
# 3 flavor
# 9 flaw
# 189 flawed
# 4 flawless
# 55 flaws
# 8 fleshed
# 3 fleshing
# 9 flew
# 3 flick
# 21 flight
# 4 flimsy
# 14 flip
# 3 flippant
# 3 flipped
# 15 flipping
# 21 flow
# 14 flowed
# 6 flows
# 3 fluff
# 5 fly
# 5 flying
# 116 flynn
# 26 focus
# 8 focused
# 5 focuses
# 4 focusing
# 7 fog
# 3 foibles
# 10 folks
# 204 follow
# 6 followed
# 36 following
# 14 follows
# 10 fond
# 9 fool
# 12 fooled
# 3 foolish
# 2803 for
# 20 force
# 29 forced
# 4 forces
# 3 foreign
# 4 foresee
# 8 foreshadowing
# 23 forever
# 23 forget
# 4 forgettable
# 6 forgot
# 5 forgotten
# 17 form
# 50 format
# 4 formed
# 18 former
# 3 forms
# 5 formula
# 6 formulaic
# 3 formulate
# 135 forth
# 5 fortunately
# 145 forward
# 6 foul
# 617 found
# 63 four
# 5 fourth
# 3 fragile
# 5 frailties
# 11 frame
# 8 frames
# 3 frank
# 19 frankly
# 4 freak
# 15 free
# 3 french
# 7 frequent
# 20 frequently
# 10 fresh
# 3 friday
# 92 friend
# 122 friends
# 11 frightening
# 1542 from
# 12 front
# 31 frustrated
# 37 frustrating
# 7 frustration
# 8 fueled
# 3 fulfill
# 3 fulfilled
# 153 full
# 31 fully
# 268 fun
# 13 funny
# 46 further
# 3 furthermore
# 20 fuss
# 36 future
# 5 gain
# 7 gained
# 3 gains
# 4 gal
# 5 galore
# 10 game
# 10 gaps
# 4 garbage
# 8 garden
# 3 gardens
# 4 gasp
# 3 gather
# 4 gathering
# 134 gave
# 7 gem
# 4 gender
# 15 general
# 24 generally
# 3 generated
# 4 generous
# 7 genius
# 89 genre
# 4 genres
# 5 genuine
# 7 genuinely
# 947 get
# 136 gets
# 172 getting
# 10 gg
# 13 gift
# 3 gifted
# 93 gillian
# 6 gimmicky
# 18 gin
# 1987 girl
# 3 girlfriends
# 3 girlish
# 15 girls
# 3 gist
# 189 give
# 78 given
# 50 gives
# 64 giving
# 149 glad
# 4 gladly
# 5 glass
# 13 glimpse
# 4 glimpsed
# 6 glimpses
# 3 gloomy
# 8 glowing
# 21 glued
# 238 go
# 5 goal
# 9 god
# 105 goes
# 515 going
# 9 golden
# 1384 gone
# 6 gonna
# 2758 good
# 9 goodness
# 8 goodreads
# 4 google
# 3 gore
# 551 got
# 4 gotta
# 22 gotten
# 27 grab
# 23 grabbed
# 4 grabber
# 3 grabbing
# 29 grabs
# 4 grace
# 3 grade
# 14 gradually
# 3 grammar
# 3 grammatically
# 9 grand
# 3 granted
# 11 graphic
# 5 grasp
# 3 grass
# 6 grateful
# 5 grating
# 5 grave
# 6 gray
# 2109 great
# 10 greatest
# 13 greatly
# 3 greener
# 7 grew
# 3 grey
# 6 grief
# 4 grieving
# 3 grim
# 9 grip
# 3 griping
# 17 gripped
# 140 gripping
# 5 grips
# 7 grisham
# 6 gritty
# 3 grossly
# 9 ground
# 31 group
# 8 grow
# 3 growing
# 3 grown
# 5 grows
# 3 gruesome
# 129 guess
# 62 guessed
# 7 guesses
# 670 guessing
# 4 guest
# 10 guilt
# 36 guilty
# 4 gut
# 59 guy
# 11 guys
# 3 gym
# 14 ha
# 1297 had
# 21 hadn
# 6 hair
# 8 haired
# 215 half
# 70 halfway
# 21 hand
# 5 handful
# 6 handle
# 8 handled
# 3 handles
# 17 hands
# 22 hang
# 20 hanging
# 3 hangover
# 4 hapless
# 141 happen
# 256 happened
# 56 happening
# 6 happenings
# 96 happens
# 11 happier
# 9 happily
# 12 happiness
# 88 happy
# 3 harassed
# 3 harasses
# 5 harassing
# 738 hard
# 10 harder
# 3 hardest
# 42 hardly
# 3 harm
# 3 harrowing
# 5 harsh
# 736 has
# 13 hasn
# 74 hate
# 69 hated
# 4 hates
# 7 hating
# 3 hatred
# 8 haunted
# 9 haunting
# 3 haunts
# 1511 have
# 58 haven
# 116 having
# 3 havoc
# 7 hawkin
# 450 hawkins
# 4 haze
# 143 he
# 70 head
# 13 headed
# 12 heading
# 15 headings
# 3 headlong
# 10 heads
# 7 health
# 31 hear
# 71 heard
# 25 hearing
# 31 heart
# 8 heartbreaking
# 3 hearted
# 3 heavier
# 8 heavily
# 11 heavy
# 6 heck
# 3 heightened
# 177 held
# 8 hell
# 100 help
# 19 helped
# 7 helpful
# 15 helpless
# 16 helps
# 3 hence
# 2001 her
# 115 here
# 16 hero
# 5 heroes
# 3 heroin
# 74 heroine
# 7 heroines
# 6 herring
# 24 herrings
# 9 hers
# 164 herself
# 7 hesitant
# 5 hesitate
# 6 hey
# 11 hidden
# 5 hide
# 7 hiding
# 73 high
# 3 higher
# 4 highlight
# 3 highlighted
# 393 highly
# 4 highsmith
# 3 hilarious
# 4 hill
# 46 him
# 3 hinges
# 10 hint
# 10 hints
# 5 hipwell
# 152 his
# 10 historical
# 10 history
# 21 hit
# 105 hitchcock
# 23 hitchcockian
# 3 hitchockian
# 3 hmmm
# 7 ho
# 51 hold
# 12 holding
# 33 holds
# 9 hole
# 10 holes
# 9 holiday
# 15 hollywood
# 4 holy
# 100 home
# 27 homes
# 34 honest
# 48 honestly
# 3 honesty
# 5 hook
# 148 hooked
# 13 hooks
# 15 hoopla
# 129 hope
# 20 hoped
# 8 hopeful
# 8 hopefully
# 15 hopeless
# 4 hopelessness
# 29 hopes
# 71 hoping
# 32 horrible
# 6 horribly
# 4 horrid
# 5 horrific
# 7 horror
# 3 horse
# 23 hot
# 19 hour
# 84 hours
# 107 house
# 3 housemate
# 66 houses
# 5 housewife
# 6 housewives
# 663 how
# 288 however
# 5 http
# 34 huge
# 6 hum
# 74 human
# 11 humanity
# 4 humans
# 5 humble
# 14 humor
# 5 hundred
# 4 hundreds
# 9 hung
# 4 hurried
# 7 hurry
# 8 hurt
# 257 husband
# 13 husbands
# 167 hype
# 19 hyped
# 4 hypnotic
# 3 icky
# 91 idea
# 10 ideal
# 3 idealized
# 8 ideas
# 4 identical
# 5 identified
# 38 identify
# 7 identifying
# 4 identities
# 14 identity
# 5 idiot
# 3 idiots
# 7 idyllic
# 3 ie
# 1040 if
# 4 ignore
# 3 ii
# 7 ill
# 6 illness
# 3 illusion
# 3 illustrates
# 3 im
# 6 image
# 6 imagery
# 8 imaginary
# 43 imagination
# 3 imaginations
# 10 imaginative
# 44 imagine
# 22 imagined
# 22 imagines
# 12 imagining
# 4 imho
# 4 imitation
# 3 immature
# 47 immediately
# 17 immensely
# 3 immersed
# 5 immoral
# 3 imo
# 8 impact
# 8 impatient
# 6 imperfect
# 8 implausible
# 3 importance
# 36 important
# 3 importantly
# 42 impossible
# 34 impressed
# 7 impression
# 6 impressive
# 5 improbable
# 10 improve
# 4 improved
# 3 improvement
# 4417 in
# 9 inability
# 3 inadvertently
# 5 inane
# 4 incident
# 5 included
# 23 including
# 4 incompetent
# 3 inconsistencies
# 3 increased
# 3 increasingly
# 21 incredible
# 36 incredibly
# 12 indeed
# 4 indistinguishable
# 22 individual
# 12 individuals
# 8 induced
# 3 inducing
# 3 inebriated
# 3 inebriation
# 4 inept
# 7 inevitable
# 3 infant
# 3 infertility
# 20 infidelity
# 3 influence
# 5 influenced
# 6 info
# 40 information
# 5 infuriating
# 4 ingenious
# 4 ingredients
# 5 inhabitants
# 8 initial
# 35 initially
# 11 inner
# 5 innocent
# 5 innovative
# 3 input
# 3 ins
# 4 insane
# 4 insanely
# 4 insecure
# 4 insecurities
# 6 insert
# 4 inserting
# 9 inserts
# 27 inside
# 26 insight
# 13 insightful
# 9 insights
# 4 insinuates
# 3 insipid
# 3 inspiration
# 6 inspired
# 4 inspiring
# 7 instance
# 3 instant
# 3 instantly
# 71 instead
# 3 insufferable
# 3 insult
# 3 insulting
# 3 intellectual
# 3 intelligence
# 7 intelligent
# 15 intended
# 53 intense
# 4 intensely
# 13 intensity
# 6 intent
# 3 intention
# 4 intentionally
# 3 intentions
# 3 inter
# 5 interact
# 7 interaction
# 7 interactions
# 3 interacts
# 378 interest
# 202 interested
# 974 interesting
# 11 interestingly
# 7 interests
# 3 interject
# 4 intermingled
# 11 internal
# 3 interpretation
# 6 intersect
# 3 interspersed
# 7 intertwine
# 30 intertwined
# 6 intertwining
# 3 interview
# 4 interweaving
# 13 interwoven
# 3 intimate
# 3 intimately
# 952 into
# 3 intoxicated
# 5 intoxicating
# 3 intricacy
# 17 intricate
# 5 intricately
# 4 intriging
# 57 intrigue
# 56 intrigued
# 237 intriguing
# 5 introduce
# 16 introduced
# 3 introducing
# 6 introduction
# 4 introspective
# 11 inventive
# 4 invents
# 20 invested
# 3 investigate
# 31 investigation
# 6 investigator
# 3 invite
# 4 involve
# 118 involved
# 9 involvement
# 12 involves
# 10 involving
# 4 irrational
# 9 irritated
# 12 irritating
# 4559 is
# 6 ish
# 84 isn
# 8 issue
# 73 issues
# 11924 it
# 212 its
# 66 itself
# 3 ive
# 4 jacket
# 7 james
# 3 jarring
# 56 jason
# 8 jealous
# 5 jealousy
# 3 jerk
# 92 jess
# 6 jesse
# 3 jilted
# 3 jimmy
# 193 job
# 6 jobless
# 4 jobs
# 4 jodi
# 5 john
# 3 join
# 2 joined
# 3 joke
# 6 jones
# 8 journal
# 3 journalism
# 4 journalist
# 2 journalistic
# 36 journey
# 6 journeys
# 16 joy
# 5 judge
# 5 judgement
# 4 judgemental
# 7 judgment
# 2 judgmental
# 2 juggles
# 5 juicy
# 2 july
# 3 jumbled
# 16 jump
# 24 jumped
# 33 jumping
# 29 jumps
# 3 june
# 2 junk
# 1281 just
# 8 justice
# 2 justification
# 4 justified
# 7 justify
# 4 juvenile
# 12 kamal
# 2 kansas
# 2 kate
# 4 keen
# 570 keep
# 80 keeping
# 460 keeps
# 2 keira
# 1229 kept
# 28 key
# 4 kick
# 2 kicked
# 2 kicking
# 2 kid
# 4 kidding
# 8 kids
# 6 kill
# 28 killed
# 122 killer
# 2 killers
# 4 killing
# 2 kilter
# 218 kind
# 11 kinda
# 113 kindle
# 2 kindness
# 10 kinds
# 11 king
# 3 kiss
# 23 kissing
# 2 kitchen
# 137 knew
# 2 knit
# 5 knock
# 2 knocked
# 2 knots
# 608 know
# 29 knowing
# 7 knowledge
# 20 known
# 46 knows
# 2 kudo
# 8 kudos
# 6 la
# 2 label
# 2 labeled
# 3 laborious
# 40 lack
# 14 lacked
# 17 lacking
# 4 lackluster
# 11 lacks
# 4 laden
# 11 ladies
# 12 lady
# 2 lagged
# 15 laid
# 9 lame
# 3 landing
# 10 landlady
# 6 landlord
# 28 language
# 2 lapse
# 5 lapses
# 8 large
# 3 largely
# 2 larger
# 308 last
# 3 lasting
# 55 late
# 11 lately
# 54 later
# 3 latest
# 4 latter
# 3 laugh
# 4 laughing
# 6 law
# 4 lay
# 5 layer
# 3 layered
# 16 layers
# 2 laying
# 3 layout
# 2 lays
# 11 lazy
# 72 lead
# 26 leading
# 15 leads
# 8 league
# 2 leaked
# 2 leaned
# 5 leaps
# 47 learn
# 21 learned
# 8 learning
# 14 learns
# 121 least
# 50 leave
# 38 leaves
# 17 leaving
# 25 led
# 2 lee
# 2 leery
# 145 left
# 2 legal
# 2 leisurely
# 9 length
# 2 lens
# 127 less
# 3 lesser
# 8 lesson
# 2 lessons
# 113 let
# 5 letdown
# 12 lets
# 10 letting
# 30 level
# 7 levels
# 9 liar
# 4 liars
# 39 library
# 3 librarything
# 11 lie
# 2 lied
# 51 lies
# 514 life
# 2 lifeless
# 21 lifetime
# 3 lifted
# 57 light
# 3 lighter
# 2 lighthearted
# 5 lightly
# 2 lights
# 3 lightweight
# 2 likability
# 124 likable
# 1638 like
# 95 likeable
# 575 liked
# 26 likely
# 2 likened
# 51 likes
# 28 liking
# 11 limited
# 4 limits
# 228 line
# 5 linear
# 30 lines
# 2 lingers
# 4 linked
# 2 links
# 2 lip
# 2 lips
# 3 liquor
# 166 list
# 4 listed
# 24 listen
# 36 listened
# 2 listener
# 34 listening
# 3 listing
# 17 lists
# 6 lit
# 32 literally
# 38 literary
# 37 literature
# 750 little
# 93 live
# 54 lived
# 6 lively
# 353 lives
# 62 living
# 207 ll
# 2 llewellyn
# 3 loaned
# 2 loathe
# 2 loathed
# 10 loathing
# 9 local
# 5 location
# 2 lock
# 3 locked
# 3 logic
# 6 logical
# 9 lol
# 99 london
# 9 loneliness
# 15 lonely
# 402 long
# 3 longed
# 39 longer
# 2 longest
# 4 longing
# 2 loo
# 143 look
# 26 looked
# 236 looking
# 2 lookout
# 27 looks
# 2 looky
# 4 loop
# 24 loose
# 2 looseness
# 2 loosing
# 19 lose
# 12 loser
# 8 losers
# 5 loses
# 12 losing
# 21 loss
# 5 losses
# 122 lost
# 319 lot
# 231 lots
# 5 loud
# 5 louise
# 2 lounging
# 5 lovable
# 516 love
# 1002 loved
# 9 lovely
# 17 lover
# 8 lovers
# 31 loves
# 21 loving
# 26 low
# 3 lower
# 3 lows
# 2 loyalty
# 4 luck
# 3 luckiest
# 6 luckily
# 5 lucky
# 4 lust
# 2 luster
# 26 lying
# 2 ma
# 2 machina
# 12 mad
# 2 madame
# 2 maddening
# 404 made
# 3 madness
# 4 magazine
# 3 magnificent
# 723 main
# 7 mainly
# 6 maintain
# 4 maintained
# 4 maintains
# 35 major
# 10 majority
# 390 make
# 214 makes
# 106 making
# 41 male
# 5 males
# 103 man
# 10 manage
# 13 managed
# 9 manages
# 3 manic
# 7 manipulated
# 10 manipulation
# 9 manipulative
# 2 mankind
# 17 manner
# 580 many
# 2 map
# 2 marathon
# 2 march
# 6 marital
# 16 mark
# 2 market
# 2 marketed
# 10 marketing
# 2 marks
# 48 marriage
# 3 marriages
# 42 married
# 2 marries
# 2 marry
# 2 marrying
# 3 marvelous
# 2 marvelously
# 5 mary
# 2 mass
# 8 master
# 12 masterful
# 9 masterfully
# 10 masterpiece
# 7 match
# 4 mate
# 8 material
# 37 matter
# 3 matters
# 4 mature
# 141 may
# 143 maybe
# 2 maze
# 2 mccarthy
# 2297 me
# 16 meagan
# 29 mean
# 5 meandering
# 12 meaning
# 5 meaningless
# 19 means
# 10 meant
# 6 measure
# 7 meat
# 3 meddling
# 18 mediocre
# 23 meet
# 13 meeting
# 12 meets
# 367 megan
# 11 meghan
# 19 meh
# 3 melancholy
# 4 melodrama
# 8 members
# 6 memorable
# 44 memories
# 55 memory
# 119 men
# 33 mental
# 13 mentally
# 13 mention
# 24 mentioned
# 6 merely
# 5 merit
# 3 mesmerized
# 10 mesmerizing
# 50 mess
# 5 message
# 3 messages
# 24 messed
# 4 messes
# 7 messy
# 12 met
# 3 metaphor
# 6 method
# 12 mid
# 106 middle
# 6 midnight
# 17 midway
# 121 might
# 8 mild
# 8 mildly
# 10 mile
# 3 miles
# 5 mill
# 161 mind
# 4 mindless
# 19 minds
# 12 mine
# 3 minimal
# 3 minimum
# 13 minor
# 7 minority
# 46 minute
# 10 minutes
# 3 mis
# 7 misdirection
# 25 miserable
# 3 miserably
# 6 misery
# 3 misfortune
# 3 mislead
# 9 misleading
# 3 misplaced
# 41 miss
# 30 missed
# 111 missing
# 2 missteps
# 13 mistake
# 4 mistaken
# 22 mistakes
# 2 mistery
# 20 mistress
# 9 mix
# 33 mixed
# 2 mixing
# 2 mixture
# 2 moaning
# 2 moderate
# 6 moderately
# 21 modern
# 2 modest
# 2 molly
# 5 mom
# 45 moment
# 28 moments
# 13 momentum
# 2 monday
# 77 money
# 6 monologue
# 4 monologues
# 12 monotonous
# 2 monster
# 18 month
# 36 months
# 11 mood
# 2 moral
# 4 morality
# 5 morally
# 2 morals
# 6 morbid
# 1105 more
# 65 morning
# 3 mornings
# 3 morose
# 337 most
# 45 mostly
# 19 mother
# 5 mothers
# 3 motif
# 5 motion
# 2 motions
# 2 motivate
# 5 motivated
# 11 motivation
# 11 motivations
# 5 motive
# 7 motives
# 3 mould
# 3 mourns
# 6 mouth
# 37 move
# 60 moved
# 2 movement
# 47 moves
# 325 movie
# 10 movies
# 102 moving
# 5 mr
# 68 ms
# 857 much
# 2 muck
# 2 muddled
# 11 multi
# 76 multiple
# 9 mundane
# 239 murder
# 22 murdered
# 70 murderer
# 2 murderous
# 3 murders
# 2 musing
# 2 musings
# 244 must
# 3 muster
# 1703 my
# 215 myself
# 102 mysteries
# 24 mysterious
# 2 mysteriously
# 963 mystery
# 2 mystifying
# 2 na
# 11 nail
# 2 nailed
# 7 nails
# 45 name
# 30 named
# 77 names
# 2 nanny
# 4 narcissist
# 8 narcissistic
# 5 narcissists
# 8 narrate
# 28 narrated
# 31 narrating
# 74 narration
# 6 narrations
# 116 narrative
# 33 narratives
# 136 narrator
# 127 narrators
# 4 narrow
# 2 narrowed
# 8 nasty
# 3 national
# 5 natural
# 3 naturally
# 10 nature
# 2 nauseating
# 2 navigate
# 4 nd
# 71 near
# 6 nearby
# 2 neared
# 35 nearly
# 5 neat
# 8 neatly
# 13 necessarily
# 23 necessary
# 6 neck
# 101 need
# 75 needed
# 5 needing
# 2 needless
# 3 needlessly
# 35 needs
# 10 needy
# 28 negative
# 18 neighbor
# 33 neighborhood
# 12 neighbors
# 16 neither
# 7 nerves
# 5 nervous
# 2 ness
# 2 netflix
# 17 neurotic
# 2 neurotics
# 398 never
# 13 nevertheless
# 215 new
# 2 newly
# 6 news
# 2 newspaper
# 338 next
# 116 nice
# 36 nicely
# 2 nick
# 2 nicknames
# 155 night
# 6 nightmare
# 4 nightmares
# 26 nights
# 3 nit
# 2 njoyed
# 594 no
# 8 nobody
# 7 noir
# 3 noise
# 40 non
# 123 none
# 24 nonetheless
# 4 nonfiction
# 3 nonsense
# 2 nook
# 7 nope
# 31 nor
# 3 norm
# 31 normal
# 31 normally
# 3 nose
# 2 nosiness
# 2 nostalgic
# 3 nosy
# 3457 not
# 3 notch
# 12 note
# 6 noted
# 7 notes
# 3 noteworthy
# 177 nothing
# 17 notice
# 9 noticed
# 7 notices
# 683 novel
# 2 novelist
# 2 novella
# 105 novels
# 199 now
# 3 nowadays
# 10 nowhere
# 4 nt
# 2 nuance
# 5 nuanced
# 3 nuances
# 46 number
# 2 numbers
# 4 numbing
# 7 numerous
# 3 nursery
# 4 nut
# 2 nutcase
# 8 nuts
# 14 ny
# 2 nyc
# 3 nymphomaniac
# 10 nyt
# 2 nytimes
# 2 obfuscation
# 3 object
# 2 objectively
# 8 objects
# 3 oblivion
# 2 obscure
# 5 observation
# 12 observations
# 6 observe
# 10 observed
# 10 observer
# 24 observes
# 9 observing
# 3 obsess
# 25 obsessed
# 6 obsessing
# 22 obsession
# 6 obsessions
# 6 obsessive
# 2 obstacle
# 52 obvious
# 21 obviously
# 2 occasional
# 9 occasionally
# 6 occupants
# 6 occupied
# 2 occupy
# 5 occur
# 11 occurred
# 2 occurrence
# 3 occurrences
# 6 occurs
# 27 odd
# 11 oddly
# 3 odds
# 7644 of
# 202 off
# 2 offended
# 5 offensive
# 5 offer
# 5 offered
# 4 offering
# 6 offers
# 3 office
# 2 officers
# 120 often
# 43 oh
# 183 ok
# 114 okay
# 5 ol
# 97 old
# 4 older
# 13 omg
# 3 ominous
# 2 omitted
# 2568 on
# 391 once
# 2 oncoming
# 1820 one
# 30 ones
# 3 oneself
# 4 ongoing
# 6 onion
# 3 online
# 435 only
# 2 onset
# 12 onto
# 2 onward
# 3 oops
# 17 open
# 3 opened
# 2 opener
# 8 opening
# 6 opens
# 19 opera
# 69 opinion
# 10 opinions
# 2 opportunities
# 10 opportunity
# 3 opposed
# 6 opposite
# 3 option
# 2 optioned
# 3 options
# 830 or
# 46 order
# 12 ordered
# 12 ordinary
# 6 organization
# 3 organized
# 43 original
# 3 originality
# 8 originally
# 405 other
# 162 others
# 35 otherwise
# 3 ought
# 136 our
# 14 ourselves
# 1407 out
# 2 outbound
# 72 outcome
# 2 outcomes
# 2 outer
# 2 outlandish
# 2 outlook
# 17 outs
# 3 outset
# 24 outside
# 3 outsider
# 2 outskirts
# 18 outstanding
# 318 over
# 188 overall
# 5 overcome
# 5 overdone
# 2 overhyped
# 4 overlap
# 16 overly
# 21 overrated
# 3 overseas
# 2 overt
# 6 overweight
# 2 overwhelmed
# 8 overwhelming
# 204 own
# 2 oz
# 111 pace
# 183 paced
# 22 pacing
# 4 packed
# 3 pad
# 887 page
# 2 pager
# 302 pages
# 3 pageturner
# 13 paid
# 22 pain
# 22 painful
# 7 painfully
# 2 pains
# 3 paint
# 3 painted
# 2 painting
# 2 paintings
# 5 paints
# 3 pair
# 3 pale
# 5 pants
# 4 panty
# 11 paper
# 4 paperback
# 10 par
# 12 paragraph
# 7 paragraphs
# 4 parallel
# 8 paranoid
# 3 park
# 180 part
# 3 partially
# 3 participants
# 38 particular
# 75 particularly
# 4 partly
# 78 parts
# 17 party
# 40 pass
# 6 passages
# 22 passed
# 5 passenger
# 7 passengers
# 42 passes
# 25 passing
# 3 passive
# 147 past
# 16 path
# 106 pathetic
# 5 pathological
# 3 pathos
# 4 paths
# 17 patience
# 8 patient
# 3 patiently
# 3 patio
# 5 patricia
# 3 patterns
# 6 patterson
# 5 paul
# 270 paula
# 95 pay
# 11 paying
# 6 payoff
# 6 peace
# 4 peeking
# 3 peeks
# 3 peel
# 3 penny
# 611 people
# 6 peoples
# 4 perceive
# 5 perceived
# 3 percent
# 8 perception
# 3 perceptions
# 153 perfect
# 5 perfection
# 25 perfectly
# 87 perhaps
# 17 period
# 9 periods
# 4 permanent
# 4 perp
# 10 perpetrator
# 2 perplexed
# 2 perplexing
# 2 perseverance
# 2 persevere
# 5 persevered
# 2 persistence
# 4 persistent
# 346 person
# 2 persona
# 37 personal
# 30 personalities
# 36 personality
# 30 personally
# 2 personas
# 20 persons
# 150 perspective
# 134 perspectives
# 2 pest
# 4 petty
# 2 pg
# 7 phenomenal
# 2 phenomenally
# 5 phone
# 2 phones
# 2 phony
# 3 phrase
# 2 phrases
# 10 physical
# 82 pick
# 92 picked
# 18 picking
# 39 picks
# 42 picture
# 3 pictures
# 44 piece
# 3 pieced
# 35 pieces
# 5 piecing
# 10 pile
# 2 piles
# 2 pinching
# 3 pining
# 2 pink
# 4 piqued
# 2 pissed
# 2 pit
# 4 pitched
# 4 pitiable
# 11 pitiful
# 34 pity
# 6 pitying
# 85 place
# 7 placed
# 3 placement
# 35 places
# 18 plain
# 11 plan
# 29 plane
# 9 planned
# 6 planning
# 2 planted
# 10 plausible
# 34 play
# 15 played
# 11 players
# 13 playing
# 11 plays
# 11 pleasant
# 11 pleasantly
# 18 please
# 8 pleased
# 12 pleasure
# 30 plenty
# 3 plight
# 3 plod
# 5 plodded
# 12 plodding
# 926 plot
# 25 plots
# 17 plotted
# 13 plotting
# 2 plow
# 2 plowed
# 2 plunges
# 19 plus
# 5 pm
# 3 poetic
# 2 poignant
# 259 point
# 2 pointedly
# 3 pointing
# 6 pointless
# 132 points
# 2 poison
# 2 polar
# 48 police
# 2 polished
# 3 ponder
# 2 ponderous
# 8 pool
# 61 poor
# 35 poorly
# 6 pop
# 3 popping
# 45 popular
# 11 popularity
# 2 populate
# 2 porn
# 3 portion
# 3 portions
# 5 portrait
# 3 portray
# 11 portrayal
# 2 portrayals
# 28 portrayed
# 3 portraying
# 3 portrays
# 4 position
# 38 positive
# 4 positively
# 2 possess
# 5 possibilities
# 4 possibility
# 38 possible
# 22 possibly
# 11 post
# 6 posted
# 2 pot
# 2 potboiler
# 21 potential
# 3 potentially
# 4 pounding
# 3 pour
# 41 pov
# 12 povs
# 13 power
# 13 powerful
# 3 powerless
# 2 pp
# 5 practically
# 18 praise
# 4 praised
# 2 pray
# 2 praying
# 3 pre
# 2 preceding
# 6 precious
# 4 predicable
# 43 predict
# 7 predictability
# 344 predictable
# 6 predictably
# 17 predicted
# 2 predictions
# 16 prefer
# 3 preference
# 8 preferred
# 5 pregnancy
# 8 pregnant
# 2 prejudice
# 86 premise
# 2 preoccupation
# 4 prepare
# 17 prepared
# 3 preposterous
# 43 present
# 6 presentation
# 30 presented
# 4 presenting
# 4 presents
# 4 press
# 2 pressing
# 4 pressure
# 2 presumably
# 2 presumed
# 7 pretend
# 10 pretending
# 5 pretends
# 3 pretense
# 2 pretentious
# 245 pretty
# 10 previous
# 5 previously
# 12 price
# 2 priced
# 3 pride
# 8 primarily
# 23 primary
# 3 prime
# 7 principal
# 4 print
# 2 printed
# 6 prior
# 5 private
# 2 prize
# 125 probably
# 94 problem
# 4 problematic
# 67 problems
# 2 procedural
# 3 proceeds
# 11 process
# 6 processes
# 7 produce
# 2 producing
# 6 product
# 2 products
# 4 profanity
# 3 professional
# 2 profile
# 3 profiles
# 7 profound
# 2 profoundly
# 4 progress
# 22 progressed
# 7 progresses
# 2 progressing
# 4 progression
# 4 progressively
# 3 projects
# 3 prominent
# 2 promiscuous
# 11 promise
# 10 promised
# 4 promises
# 10 promising
# 2 promoted
# 3 promotion
# 2 prone
# 2 propelled
# 3 proper
# 3 props
# 19 prose
# 4 prospective
# 132 protagonist
# 24 protagonists
# 3 protect
# 6 prove
# 3 proved
# 3 proverbial
# 4 proves
# 8 provide
# 8 provided
# 8 provides
# 3 providing
# 4 provocative
# 20 provoking
# 4 proximity
# 2 prying
# 3 pseudo
# 2 psych
# 9 psyche
# 2 psyches
# 4 psychiatrist
# 15 psycho
# 196 psychological
# 13 psychologically
# 5 psychologist
# 12 psychology
# 4 psychopath
# 3 psychopaths
# 5 psychosis
# 9 psychotic
# 4 public
# 2 publication
# 6 publicity
# 2 publish
# 18 published
# 8 publisher
# 5 publishers
# 2 publishing
# 2 puffy
# 19 pull
# 28 pulled
# 12 pulling
# 36 pulls
# 8 pun
# 5 punch
# 2 punishment
# 14 purchase
# 33 purchased
# 5 purchasing
# 9 pure
# 3 purely
# 15 purpose
# 4 purposely
# 3 pursue
# 3 pursuit
# 8 push
# 6 pushed
# 6 pushing
# 2007 put
# 2 putit
# 10 puts
# 81 putting
# 16 puzzle
# 2 puzzled
# 4 puzzles
# 5 puzzling
# 2 qualifies
# 55 qualities
# 39 quality
# 28 quarter
# 5 quarters
# 40 question
# 6 questionable
# 11 questioning
# 33 questions
# 2 quibbles
# 283 quick
# 2 quicker
# 152 quickly
# 6 quiet
# 2 quietly
# 2 quilty
# 3 quirks
# 8 quirky
# 48 quit
# 300 quite
# 2 quits
# 3 quitting
# 2 rach
# 66 rachael
# 1302 rachel
# 10 racing
# 2 racy
# 7 rage
# 6 raging
# 6 rail
# 5 railroad
# 2 rails
# 4 railway
# 4 rain
# 2 rains
# 15 rainy
# 2 raises
# 2 raison
# 2 rambles
# 11 rambling
# 9 ramblings
# 3 rampant
# 6 ran
# 7 random
# 4 range
# 2 ranks
# 2 ranting
# 5 rapid
# 3 rapidly
# 18 rare
# 18 rarely
# 24 rate
# 26 rated
# 2 raters
# 2 rates
# 143 rather
# 49 rating
# 9 ratings
# 2 rational
# 2 rattles
# 2 ravages
# 25 rave
# 7 raved
# 2 raves
# 12 raving
# 12 raw
# 2 rd
# 180 re
# 27 reach
# 19 reached
# 2 reaches
# 5 reaching
# 2 react
# 2 reacted
# 4 reaction
# 5177 read
# 19 readable
# 400 reader
# 125 readers
# 1453 reading
# 45 reads
# 35 ready
# 410 real
# 8 realise
# 4 realised
# 2 realises
# 4 realism
# 60 realistic
# 5 realistically
# 2 realities
# 61 reality
# 2 realization
# 53 realize
# 37 realized
# 7 realizes
# 4 realizing
# 1412 really
# 2 realy
# 2 reap
# 63 rear
# 81 reason
# 3 reasonable
# 8 reasonably
# 2 reasoning
# 26 reasons
# 11 recall
# 4 recalling
# 2 recalls
# 2 recap
# 24 received
# 5 receiving
# 9 recent
# 19 recently
# 5 reckless
# 3 recognizable
# 7 recognize
# 2 recollection
# 898 recommend
# 21 recommendation
# 8 recommendations
# 181 recommended
# 15 recommending
# 2 reconstruct
# 2 recount
# 2 recovered
# 3 recovering
# 3 recovery
# 51 red
# 8 redeem
# 11 redeemable
# 9 redeemed
# 84 redeeming
# 2 redeems
# 16 redemption
# 3 reduced
# 13 redundant
# 3 reel
# 5 reeling
# 2 reels
# 2 refer
# 4 reference
# 3 referenced
# 7 references
# 5 referred
# 3 referring
# 2 refers
# 2 reflect
# 2 reflected
# 3 reflecting
# 4 reflection
# 2 reflections
# 3 reflects
# 15 refreshing
# 5 refreshingly
# 5 refused
# 3 regain
# 7 regard
# 17 regarding
# 8 regardless
# 24 regret
# 12 regular
# 8 regularly
# 3 rehash
# 3 rehashing
# 31 relatable
# 65 relate
# 10 related
# 3 relates
# 8 relating
# 3 relations
# 24 relationship
# 56 relationships
# 4 relative
# 8 relatively
# 3 relax
# 6 relaxing
# 6 release
# 4 released
# 4 relentless
# 2 relentlessly
# 8 relevant
# 3 reliability
# 15 reliable
# 3 reliance
# 9 relief
# 4 relies
# 4 relieved
# 3 rely
# 10 remain
# 9 remained
# 4 remaining
# 9 remains
# 8 remarkable
# 5 remarkably
# 2 remarks
# 6 remarried
# 107 remember
# 4 remembered
# 12 remembering
# 9 remembers
# 11 remind
# 97 reminded
# 2 reminder
# 2 reminding
# 36 reminds
# 32 reminiscent
# 9 remotely
# 3 removed
# 5 rendell
# 3 rendered
# 2 rendition
# 4 rent
# 2 rented
# 11 repeat
# 13 repeated
# 10 repeatedly
# 11 repeating
# 2 repeats
# 2 repetetive
# 11 repetition
# 18 repetitious
# 77 repetitive
# 4 replace
# 2 replacement
# 2 replica
# 3 report
# 6 reported
# 3 reports
# 6 represent
# 4 represents
# 2 reprieve
# 3 repugnant
# 2 repulsive
# 11 required
# 3 requirement
# 6 requires
# 2 requisite
# 11 reread
# 2 rereading
# 2 resented
# 2 reservation
# 2 reside
# 2 residents
# 6 resist
# 23 resolution
# 4 resolve
# 8 resolved
# 3 resolves
# 9 respect
# 3 respective
# 2 respond
# 2 responded
# 7 response
# 3 responses
# 2 responsibilities
# 5 responsibility
# 12 responsible
# 46 rest
# 2 restart
# 3 restless
# 2 restored
# 10 result
# 3 resulting
# 6 results
# 2 retain
# 2 retell
# 2 retelling
# 7 return
# 4 returned
# 48 reveal
# 62 revealed
# 17 revealing
# 27 reveals
# 2 reveiw
# 8 revelation
# 3 revelations
# 4 revenge
# 103 review
# 8 reviewed
# 17 reviewer
# 40 reviewers
# 3 reviewing
# 285 reviews
# 2 revise
# 2 revisit
# 3 revisiting
# 7 revolve
# 5 revolves
# 5 rewarded
# 2 rewarding
# 2 rhyme
# 4 rhythm
# 8 rich
# 2 richly
# 2 richness
# 2 rid
# 5 ridden
# 2 riddled
# 171 ride
# 2 rider
# 71 rides
# 25 ridiculous
# 5 ridiculously
# 48 riding
# 255 right
# 10 rights
# 2 riley
# 6 ring
# 3 rings
# 4 rip
# 5 ripped
# 2 ripping
# 4 rising
# 4 risk
# 2 risky
# 3 riverhead
# 13 riveted
# 75 riveting
# 19 road
# 2 robbed
# 2 robert
# 6 rock
# 2 rode
# 19 role
# 4 roles
# 8 roll
# 6 rolled
# 17 roller
# 6 rollercoaster
# 9 rolling
# 16 romance
# 2 romances
# 8 romantic
# 2 romanticized
# 5 romp
# 20 room
# 2 roomate
# 28 roommate
# 39 root
# 2 rooted
# 36 rooting
# 3 roots
# 3 rose
# 2 rotating
# 2 rote
# 12 round
# 7 rounded
# 14 route
# 2 routes
# 2 routinely
# 2 routines
# 2 routing
# 10 row
# 3 rude
# 3 rug
# 10 ruin
# 8 ruined
# 2 ruining
# 2 ruins
# 5 rule
# 4 ruled
# 27 run
# 8 runaway
# 10 running
# 6 runs
# 8 rush
# 14 rushed
# 5 rushing
# 7 ruth
# 4 sack
# 161 sad
# 20 sadly
# 12 sadness
# 6 safe
# 3 saga
# 144 said
# 5 sake
# 4 sale
# 308 same
# 9 sample
# 5 sane
# 7 sanity
# 4 sarah
# 7 sat
# 4 satisfaction
# 5 satisfactory
# 12 satisfied
# 8 satisfy
# 90 satisfying
# 8 saturday
# 20 save
# 5 saved
# 3 saving
# 4 savor
# 90 saw
# 312 say
# 25 saying
# 19 says
# 2 scale
# 2 scales
# 2 scanning
# 5 scared
# 15 scary
# 5 scenario
# 9 scenarios
# 23 scene
# 4 scenery
# 25 scenes
# 5 schedule
# 4 schizophrenic
# 7 school
# 3 score
# 5 scorned
# 89 scott
# 5 scream
# 3 screaming
# 3 screams
# 12 screen
# 5 screenplay
# 15 screwed
# 4 seamlessly
# 4 search
# 6 searching
# 145 seat
# 78 second
# 4 secondary
# 2 secondly
# 2 seconds
# 17 secret
# 2 secretive
# 28 secrets
# 9 section
# 4 sections
# 2 seducing
# 3 seductive
# 582 see
# 2 seed
# 50 seeing
# 8 seek
# 5 seeking
# 2 seeks
# 117 seem
# 165 seemed
# 2 seeming
# 25 seemingly
# 102 seems
# 70 seen
# 111 sees
# 2 segment
# 3 segments
# 6 seldom
# 2 selected
# 8 selection
# 3 selections
# 162 self
# 21 selfish
# 2 selfishness
# 2 sell
# 185 seller
# 25 sellers
# 7 selling
# 3 selves
# 6 semi
# 2 sending
# 2 sends
# 2 sensational
# 90 sense
# 6 senses
# 2 sensible
# 2 sensical
# 3 sensitive
# 4 sent
# 18 sentence
# 6 sentences
# 17 separate
# 5 separated
# 2 separately
# 4 separating
# 6 september
# 10 sequel
# 4 sequence
# 2 sequences
# 4 sequencing
# 2 sequential
# 2 serial
# 10 series
# 25 serious
# 19 seriously
# 3 serve
# 8 served
# 2 service
# 7 serving
# 2 sessions
# 73 set
# 12 sets
# 57 setting
# 8 settings
# 5 settle
# 5 settled
# 5 setup
# 2 seven
# 163 several
# 6 severe
# 5 severely
# 2 sewn
# 17 sex
# 3 sexist
# 14 sexual
# 10 shades
# 3 shadow
# 2 shaggy
# 19 shake
# 2 shakes
# 5 shaking
# 4 shall
# 35 shallow
# 3 shambles
# 10 shame
# 6 shape
# 2 shaped
# 16 share
# 15 shared
# 3 shares
# 13 sharp
# 4 shattered
# 2 shattering
# 2 shatters
# 1903 she
# 5 sheer
# 2 shelf
# 2 shell
# 3 sherlock
# 6 shift
# 2 shifted
# 17 shifting
# 12 shifts
# 3 shipping
# 2 shiver
# 10 shock
# 23 shocked
# 6 shocker
# 38 shocking
# 3 shockingly
# 66 short
# 10 shorter
# 2 shortly
# 6 shot
# 175 should
# 18 shouldn
# 3 shout
# 26 show
# 10 showed
# 9 showing
# 7 shown
# 32 shows
# 2 shrink
# 25 sick
# 52 side
# 7 sides
# 8 sigh
# 5 sight
# 7 sign
# 13 signal
# 8 significant
# 13 silly
# 166 similar
# 23 similarities
# 10 similarity
# 4 similarly
# 24 simple
# 9 simplistic
# 53 simply
# 8 simultaneously
# 145 since
# 51 single
# 3 singular
# 13 sinister
# 11 sister
# 12 sit
# 3 site
# 3 sits
# 51 sitting
# 14 sittings
# 37 situation
# 18 situations
# 4 six
# 6 skeptical
# 6 skill
# 5 skilled
# 4 skillful
# 8 skillfully
# 8 skills
# 3 skim
# 6 skimmed
# 8 skimming
# 3 skin
# 24 skip
# 11 skipped
# 11 skipping
# 4 skips
# 3 slang
# 6 slap
# 52 sleep
# 9 sleeping
# 3 slept
# 5 sleuth
# 4 slight
# 40 slightly
# 8 slog
# 3 slogged
# 3 slogging
# 12 sloppy
# 682 slow
# 3 slowed
# 4 slower
# 4 slowing
# 128 slowly
# 8 slows
# 7 smack
# 31 small
# 17 smart
# 3 smarter
# 3 smidge
# 7 smooth
# 4 smoothly
# 3 snail
# 5 sneaking
# 3 sniveling
# 3 snowed
# 1777 so
# 5 soaked
# 20 soap
# 14 sober
# 3 sobriety
# 9 social
# 11 society
# 12 sociopath
# 3 sociopathic
# 4 sociopaths
# 5 socks
# 3 solace
# 8 sold
# 28 solid
# 3 solidly
# 17 solution
# 36 solve
# 25 solved
# 22 solving
# 3 somber
# 703 some
# 34 somehow
# 143 someone
# 305 something
# 3 somethings
# 10 sometime
# 109 sometimes
# 162 somewhat
# 15 somewhere
# 85 soon
# 8 sooner
# 3 sooo
# 3 soooooo
# 3 sophisticated
# 6 sordid
# 5 sorrow
# 135 sorry
# 80 sort
# 5 sorted
# 6 sorting
# 9 sorts
# 8 soul
# 21 sound
# 21 sounded
# 3 sounding
# 12 sounds
# 5 space
# 4 span
# 8 spare
# 5 spark
# 10 speak
# 3 speaker
# 6 speakers
# 44 speaking
# 6 speaks
# 19 special
# 8 specific
# 4 specifically
# 9 spectacular
# 5 speculation
# 49 speed
# 3 speeding
# 3 speeds
# 18 spell
# 11 spellbinding
# 3 spelling
# 30 spend
# 12 spending
# 12 spends
# 50 spent
# 3 spies
# 5 spin
# 9 spinning
# 4 spins
# 9 spiral
# 3 spirals
# 8 spirit
# 16 spite
# 8 split
# 17 spoil
# 40 spoiler
# 26 spoilers
# 7 spoiling
# 8 spoke
# 13 spot
# 14 spots
# 4 spousal
# 3 spouse
# 8 spouses
# 4 spring
# 7 spun
# 3 squandered
# 15 st
# 4 stable
# 7 stage
# 9 stalker
# 9 stalking
# 4 stalks
# 21 stand
# 5 standard
# 3 standing
# 3 standpoint
# 6 stands
# 99 star
# 5 staring
# 5 starring
# 230 stars
# 341 start
# 375 started
# 6 starter
# 15 starting
# 142 starts
# 25 state
# 3 stated
# 4 statement
# 3 states
# 5 stating
# 12 station
# 3 stations
# 5 status
# 61 stay
# 51 stayed
# 13 staying
# 7 stays
# 8 steadily
# 13 steady
# 6 steam
# 5 stellar
# 17 step
# 7 stephen
# 4 steps
# 5 stereotypes
# 3 stereotypical
# 3 steven
# 5 stewart
# 31 stick
# 6 sticking
# 320 still
# 4 stomach
# 5 stood
# 251 stop
# 42 stopped
# 5 stopping
# 29 stops
# 8 store
# 184 stories
# 2951 story
# 114 storyline
# 3 storylines
# 5 storyteller
# 33 storytelling
# 61 straight
# 3 straighten
# 5 straightforward
# 38 strange
# 8 strangely
# 13 stranger
# 22 strangers
# 8 stream
# 32 street
# 3 streets
# 17 strength
# 5 strengths
# 4 stress
# 18 stretch
# 4 stretched
# 3 stretches
# 62 strong
# 9 stronger
# 7 strongly
# 6 struck
# 30 structure
# 12 structured
# 30 struggle
# 24 struggled
# 23 struggles
# 18 struggling
# 38 stuck
# 3 student
# 5 studies
# 25 study
# 14 stuff
# 4 stumble
# 4 stumbles
# 5 stumbling
# 3 stumped
# 7 stunning
# 50 stupid
# 3 stupidity
# 11 stupor
# 3 stupors
# 243 style
# 4 styles
# 6 sub
# 11 subject
# 3 subjects
# 3 subplots
# 15 substance
# 10 subtle
# 5 subtly
# 4 suburb
# 18 suburban
# 9 suburbs
# 7 succeed
# 4 succeeds
# 13 success
# 10 successful
# 3 successfully
# 224 such
# 3 suck
# 33 sucked
# 3 sucker
# 10 sucks
# 11 sudden
# 40 suddenly
# 6 suffer
# 11 suffered
# 9 suffering
# 14 suffers
# 4 suffice
# 3 sufficient
# 16 suggest
# 12 suggested
# 3 suitable
# 5 sum
# 5 summary
# 174 summer
# 3 sums
# 5 sunday
# 3 sunshine
# 30 super
# 17 superb
# 8 superbly
# 9 superficial
# 9 superior
# 4 support
# 6 supported
# 5 supporting
# 20 suppose
# 27 supposed
# 280 sure
# 9 surely
# 9 surface
# 3 surgery
# 263 surprise
# 164 surprised
# 109 surprises
# 103 surprising
# 8 surprisingly
# 9 surrounding
# 5 survive
# 3 survives
# 41 suspect
# 18 suspected
# 32 suspects
# 5 suspence
# 4 suspenceful
# 6 suspend
# 3 suspenful
# 540 suspense
# 498 suspenseful
# 6 suspensful
# 3 suspension
# 14 suspicion
# 9 suspicions
# 5 suspicious
# 3 swallow
# 7 sweet
# 3 swept
# 4 swing
# 10 switch
# 7 switched
# 18 switches
# 45 switching
# 62 sympathetic
# 27 sympathize
# 4 sympathized
# 58 sympathy
# 3 sync
# 6 synopsis
# 5 system
# 5 table
# 19 tad
# 8 tail
# 146 take
# 32 taken
# 147 takes
# 32 taking
# 104 tale
# 5 talent
# 11 talented
# 4 talents
# 4 tales
# 21 talk
# 6 talked
# 39 talking
# 4 talks
# 3 tangle
# 11 tangled
# 4 tantalizing
# 3 tasks
# 23 taste
# 5 tattoo
# 8 taut
# 3 te
# 17 tea
# 4 teacher
# 19 technique
# 91 tedious
# 4 telegraphed
# 4 television
# 114 tell
# 6 teller
# 149 telling
# 26 tells
# 4 tempted
# 8 ten
# 7 tend
# 3 tended
# 5 tendencies
# 8 tendency
# 4 tends
# 14 tense
# 40 tension
# 6 term
# 15 terms
# 10 terrace
# 59 terrible
# 11 terribly
# 41 terrific
# 4 terrifying
# 6 test
# 4 testament
# 3 tgott
# 15 th
# 492 than
# 35 thank
# 5 thankful
# 9 thankfully
# 20 thanks
# 3724 that
# 6 thats
# 22781 the
# 3 theaters
# 666 their
# 499 them
# 21 theme
# 9 themes
# 40 themselves
# 574 then
# 8 theories
# 6 theory
# 17 therapist
# 6 therapy
# 912 there
# 14 therefore
# 215 these
# 674 they
# 4 thickens
# 12 thin
# 149 thing
# 198 things
# 503 think
# 141 thinking
# 24 thinks
# 82 third
# 17 thirds
# 8 thirty
# 6561 this
# 6 tho
# 4 thorough
# 109 thoroughly
# 262 those
# 339 though
# 616 thought
# 8 thoughtful
# 58 thoughts
# 7 thousands
# 7 thread
# 4 threads
# 499 three
# 9 threw
# 27 thrill
# 10 thrilled
# 494 thriller
# 94 thrillers
# 111 thrilling
# 6 thrills
# 4 throttle
# 745 through
# 5 throughly
# 192 throughout
# 14 throw
# 5 throwing
# 15 thrown
# 7 throws
# 42 thru
# 3 thrust
# 7 thumbs
# 17 thus
# 5 ticket
# 5 tie
# 29 tied
# 9 ties
# 13 tight
# 5 tighter
# 17 tightly
# 39 til
# 113 till
# 1096 time
# 43 timeline
# 13 timelines
# 336 times
# 7 timing
# 7 tiny
# 58 tired
# 13 tiresome
# 7 tiring
# 43 title
# 6 titled
# 10 titles
# 10528 to
# 21 today
# 52 toes
# 229 together
# 358 told
# 177 tom
# 16 tone
# 7 tonic
# 4 tonics
# 6 tons
# 748 too
# 326 took
# 73 top
# 3 topic
# 4 topics
# 4 torn
# 4 tortured
# 4 tossed
# 31 total
# 122 totally
# 10 touch
# 6 touched
# 26 tough
# 7 touted
# 51 toward
# 53 towards
# 11 town
# 3 trace
# 89 track
# 44 tracks
# 12 tragedy
# 18 tragic
# 4 trail
# 1250 train
# 35 trains
# 3 trait
# 7 traits
# 4 transition
# 3 transitions
# 5 transparent
# 3 transported
# 4 trapped
# 3 trash
# 5 trashy
# 14 travel
# 15 traveling
# 3 travelling
# 15 travels
# 10 treat
# 6 treated
# 6 treatment
# 4 tree
# 6 trend
# 4 triangle
# 4 trick
# 5 tricked
# 3 tricks
# 6 tricky
# 55 tried
# 24 tries
# 29 trip
# 7 trips
# 5 trite
# 60 trouble
# 22 troubled
# 5 troubles
# 4 troubling
# 4 trudged
# 109 true
# 100 truly
# 36 trust
# 6 trusted
# 68 truth
# 8 truths
# 77 try
# 164 trying
# 3 tuned
# 3 tuner
# 94 turn
# 68 turned
# 609 turner
# 123 turning
# 626 turns
# 5 turny
# 17 tv
# 6 twenty
# 27 twice
# 400 twist
# 88 twisted
# 26 twisting
# 911 twists
# 33 twisty
# 4 twits
# 283 two
# 5 tying
# 77 type
# 10 types
# 31 typical
# 15 typically
# 5 typos
# 12 ugh
# 8 ugly
# 7 uk
# 10 ultimate
# 44 ultimately
# 12 un
# 52 unable
# 6 unanswered
# 11 unappealing
# 3 unattractive
# 45 unbelievable
# 3 uncaring
# 3 uncertain
# 4 uncertainty
# 13 uncomfortable
# 4 uncover
# 3 undecided
# 26 under
# 3 underneath
# 146 understand
# 5 understandable
# 26 understanding
# 4 understands
# 3 understatement
# 20 understood
# 5 underwhelmed
# 5 underwhelming
# 3 undone
# 4 undoubtedly
# 4 uneasy
# 16 unemployed
# 138 unexpected
# 3 unexpectedly
# 5 unfair
# 4 unfaithful
# 3 unfaithfulness
# 26 unfold
# 16 unfolded
# 21 unfolding
# 50 unfolds
# 4 unfortunate
# 44 unfortunately
# 16 unhappy
# 3 uninterested
# 24 uninteresting
# 97 unique
# 10 unknown
# 33 unless
# 82 unlikable
# 26 unlike
# 66 unlikeable
# 14 unlikely
# 4 unlimited
# 2 unloveable
# 6 unnecessary
# 2 unnerving
# 3 unoriginal
# 13 unpleasant
# 5 unpredictability
# 44 unpredictable
# 4 unputdownable
# 11 unravel
# 2 unraveled
# 6 unraveling
# 2 unravelled
# 4 unravelling
# 6 unravels
# 2 unreadable
# 2 unreal
# 31 unrealistic
# 2 unrelatable
# 4 unreliability
# 118 unreliable
# 2 unremarkable
# 2 unsatisfactory
# 3 unsatisfied
# 7 unsatisfying
# 2 unsettled
# 4 unsettling
# 6 unsolved
# 13 unstable
# 3 unsuccessful
# 10 unsure
# 2 unsurprising
# 3 unsurprisingly
# 2 unsuspecting
# 18 unsympathetic
# 2 unthinkable
# 792 until
# 4 unto
# 56 unusual
# 3 unusually
# 2 unwanted
# 2 unwind
# 1130 up
# 2 upbeat
# 12 uplifting
# 32 upon
# 8 ups
# 4 upset
# 2 upsetting
# 2 upside
# 2 uptake
# 6 urge
# 124 us
# 4 usa
# 2 usage
# 67 use
# 95 used
# 2 useful
# 7 useless
# 14 uses
# 26 using
# 25 usual
# 101 usually
# 2 ut
# 7 utter
# 29 utterly
# 2 vaca
# 57 vacation
# 2 vacay
# 7 vague
# 2 vaguely
# 3 valid
# 18 value
# 5 valued
# 5 values
# 2 vanished
# 3 vanishes
# 4 vantage
# 2 vapid
# 2 variety
# 38 various
# 4 varying
# 2 vast
# 362 ve
# 3 vehicle
# 20 vein
# 3 verge
# 58 version
# 2467 very
# 2 vested
# 2 vey
# 12 via
# 3 vibe
# 2 vicarious
# 7 vicariously
# 2 vice
# 2 vices
# 27 victim
# 2 victimized
# 18 victims
# 230 view
# 3 viewed
# 4 viewing
# 20 viewpoint
# 30 viewpoints
# 43 views
# 34 villain
# 35 violence
# 19 violent
# 5 virtually
# 4 visceral
# 7 vision
# 3 visit
# 3 visits
# 6 visual
# 4 vital
# 17 vivid
# 7 vividly
# 12 vocabulary
# 71 voice
# 92 voices
# 5 void
# 7 vomiting
# 4 voracious
# 2 vow
# 11 voyeur
# 3 voyeurism
# 13 voyeuristic
# 6 vs
# 2 vulnerabilities
# 11 vulnerable
# 4 wa
# 2 wade
# 4 wading
# 2 waist
# 272 wait
# 10 waited
# 55 waiting
# 8 wake
# 5 wakes
# 2 waking
# 10 walk
# 2 walked
# 3 walking
# 2 walks
# 4 wall
# 2 wallow
# 2 wallowed
# 3 wallowing
# 7 wander
# 3 wandering
# 2 wanders
# 4 wanna
# 6 wannabe
# 520 want
# 256 wanted
# 147 wanting
# 31 wants
# 8 warm
# 2 warmed
# 4 warming
# 4 warn
# 7 warned
# 2 warner
# 5 warning
# 3 warnings
# 4 warped
# 2 warranted
# 6691 was
# 2 wash
# 325 wasn
# 3 wasnt
# 112 waste
# 43 wasted
# 10 wasting
# 30 watch
# 19 watched
# 4 watcher
# 38 watches
# 2 watchful
# 64 watching
# 4 water
# 29 watson
# 2 waves
# 919 way
# 57 ways
# 452 we
# 80 weak
# 2 weaker
# 2 weakly
# 16 weakness
# 17 weaknesses
# 3 weapon
# 2 wear
# 4 weather
# 13 weave
# 5 weaved
# 14 weaves
# 9 weaving
# 9 web
# 3 webs
# 4 wednesday
# 9 wee
# 34 week
# 37 weekend
# 34 weeks
# 2 weepy
# 6 weight
# 41 weird
# 3 weirdly
# 4 welcome
# 2 welcomed
# 1396 well
# 97 went
# 903 were
# 38 weren
# 2 wet
# 1458 what
# 9 whatever
# 4 whats
# 10 whatsoever
# 3 wheels
# 687 when
# 10 whenever
# 302 where
# 2 whereabouts
# 8 whereas
# 41 whether
# 3 whew
# 535 which
# 448 while
# 5 whilst
# 3 whine
# 5 whiney
# 15 whining
# 12 whiny
# 2 whip
# 3 whipped
# 7 white
# 1569 who
# 4 whoa
# 40 whodunit
# 37 whodunnit
# 193 whole
# 53 whom
# 72 whose
# 300 why
# 4 wicked
# 5 wide
# 190 wife
# 22 wild
# 4 wildly
# 834 will
# 10 willing
# 6 win
# 5 wind
# 4 winded
# 127 window
# 20 windows
# 3 winds
# 11 wine
# 5 winner
# 4 winning
# 8 winter
# 2 wise
# 2 wisely
# 85 wish
# 22 wished
# 4 wishes
# 9 wishing
# 3 wit
# 2557 with
# 3 withholding
# 41 within
# 124 without
# 22 witness
# 10 witnessed
# 14 witnesses
# 4 witnessing
# 3 witney
# 2 witty
# 8 wives
# 7 woke
# 340 woman
# 502 women
# 162 won
# 51 wonder
# 27 wondered
# 119 wonderful
# 28 wonderfully
# 112 wondering
# 4 wonders
# 6 wont
# 2 wooden
# 2 woods
# 48 word
# 2 wordiness
# 3 wording
# 48 words
# 11 wordy
# 3 wore
# 174 work
# 20 worked
# 2 workers
# 10 working
# 32 works
# 2 workshop
# 85 world
# 6 worried
# 2 worries
# 8 worry
# 2 worrying
# 34 worse
# 55 worst
# 303 worth
# 6 worthless
# 16 worthwhile
# 30 worthy
# 1290 would
# 95 wouldn
# 3 wouldnt
# 8 wound
# 3 wounded
# 2 wounds
# 6 wove
# 33 woven
# 83 wow
# 2 wowed
# 10 wrap
# 27 wrapped
# 2 wrapping
# 3 wraps
# 36 wreck
# 2 wrecked
# 5 wrecks
# 6 wrenching
# 2 wrists
# 75 write
# 100 writer
# 11 writers
# 31 writes
# 514 writing
# 1006 written
# 85 wrong
# 18 wrote
# 2 wrought
# 5 www
# 2 ya
# 8 yard
# 3 yards
# 8 yarn
# 3 yawn
# 9 yeah
# 85 year
# 2 yearly
# 69 years
# 4 yell
# 3 yep
# 55 yes
# 5 yesterday
# 153 yet
# 2 yhe
# 5 yikes
# 15 york
# 3913 you
# 59 young
# 4 younger
# 473 your
# 64 yourself
# 2 youth
# 2 ypu
# 3 yuck
# 2 yuk
# 7 zero
# 3 zimbabwe
# 2 zone

# %% [markdown]
# Let's have a look at the most used words in our corpus:

# %%
import seaborn as sns
ex = pd.DataFrame(data = {'word': vocab, 'number of appearance': dist}).sort_values(by = 'number of appearance', 
                                                                                    ascending = False).head(40)
sns.set_style("whitegrid")
ax = sns.barplot( x="number of appearance", y="word", data=ex)

# %% [markdown]
# We remark that the most used words are stopwords, hence we will remove them!

# %%
def remove_stop_words(review):
    review = review.split()
    stops = set(stopwords.words("english"))                  
    text = [w for w in review if not w in stops]   
    return(" ".join(text))  
toy_data['processed'] = toy_data['processed'].apply(lambda x: remove_stop_words(x))

# %%
print("Wait, bags of words are being created!!\n")
from sklearn.feature_extraction.text import CountVectorizer
# Define the function that will compute the frequencies for all words
vectorizer = CountVectorizer(analyzer = "word", tokenizer = None, preprocessor = None, stop_words = None, max_features = 5000) 
# Use the fit_transform method to learn the vocabulary and then transform the training data into vectors
train_data_features = vectorizer.fit_transform(toy_data['processed'])
# Convert the result to an array
train_data_features = train_data_features.toarray()

print('The model has been learned!')
size = train_data_features.shape
sparsity = np.count_nonzero(train_data_features) / train_data_features.size
vocab = vectorizer.get_feature_names()
dist = np.sum(train_data_features, axis=0)

ex = pd.DataFrame(data = {'word': vocab, 'number of appearance': dist}).sort_values(by = 'number of appearance', 
                                                                                    ascending = False).head(40)
sns.set_style("whitegrid")
ax = sns.barplot( x="number of appearance", y="word", data=ex)
plt.title('Frequency of words')
plt.show()
# Out:
# Wait, bags of words are being created!!
#
# The model has been learned!

# %% [markdown]
# We observe that some of the most represented words are related to emotions ("great", "like", "enjoyed", "loved", ... which is important for our application).
#
# We also observe that the number of appearance is rapidly deacreasing.

# %%
ex = pd.DataFrame(data = {'word': vocab, 'number of appearance': dist}).sort_values(by = 'number of appearance', 
                                                                                    ascending = False).head(500)
sns.set_style("whitegrid")
ax = sns.barplot( x="number of appearance", y="word", data=ex)
plt.title('Frequency of words')
plt.show()

# %% [markdown]
# # Classification

# %% [markdown]
# We will now build models to predict the rating based on the reviews' features.

# %%
import time
from sklearn.model_selection import train_test_split
labels = toy_data['sentiment']

# We split the data into train and test data. Here we keep 30% of the data for testing
data_train, data_test, labels_train, labels_test = train_test_split(train_data_features, 
                                                                    labels, test_size=0.3, 
                                                                    random_state=42)

# %%
data_train.shape
# Out:
# (8742, 5000)

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

start = time.time()
# Initialize the model
print('Initialize the model')
clf = LogisticRegression()

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  1.015862226486206

# %%
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
plt.hist(labels_predicted, color = 'b')
plt.xlabel('rating')
plt.title('Predicted ratings')
plt.show()

plt.hist(labels_test, color = 'b')
plt.xlabel('rating')
plt.title('True ratings')
plt.show()
# Out:
# The accuracy is:  0.35201494529

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[374 375 515]
#  [353 392 475]
#  [358 352 553]]

# %%
from sklearn.metrics import classification_report
target_names = ['class -1', 'class 0', 'class 1']
print(classification_report(labels_test, labels_predicted, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#    class -1       0.34      0.30      0.32      1264
#     class 0       0.35      0.32      0.34      1220
#     class 1       0.36      0.44      0.39      1263
#
# avg / total       0.35      0.35      0.35      3747

# %%
start = time.time()
# Initialize the model
print('Initialize the model')
clf = LogisticRegression(C=.01)
# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)
# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)
print("Computation time: ", time.time() - start)

print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  0.5939004421234131
# The accuracy is:  0.360821990926
# Confusion matrix, without normalization
# [[339 369 556]
#  [316 385 519]
#  [298 337 628]]
#              precision    recall  f1-score   support
#
#    class -1       0.36      0.27      0.31      1264
#     class 0       0.35      0.32      0.33      1220
#     class 1       0.37      0.50      0.42      1263
#
# avg / total       0.36      0.36      0.35      3747
#
# The accuracy is:  0.360821990926

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

start = time.time()

# Initialize the model
print('Initialize the model')
clf = RandomForestClassifier(n_estimators = 20, class_weight="balanced")

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  10.876319169998169
# Confusion matrix, without normalization
# [[397 463 404]
#  [351 494 375]
#  [409 414 440]]
#              precision    recall  f1-score   support
#
#    class -1       0.34      0.31      0.33      1264
#     class 0       0.36      0.40      0.38      1220
#     class 1       0.36      0.35      0.35      1263
#
# avg / total       0.35      0.36      0.35      3747
#
# The accuracy is:  0.355217507339

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

start = time.time()
# Initialize the model
print('Initialize the model')
clf = GaussianNB()

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  2.234630823135376
# Confusion matrix, without normalization
# [[ 139  137  988]
#  [ 136  157  927]
#  [ 103  116 1044]]
#              precision    recall  f1-score   support
#
#    class -1       0.37      0.11      0.17      1264
#     class 0       0.38      0.13      0.19      1220
#     class 1       0.35      0.83      0.49      1263
#
# avg / total       0.37      0.36      0.29      3747
#
# The accuracy is:  0.357619428876

# %% [markdown]
# #### What if we used TF-IDF instead of Count Vectorizer?
#
# In TF-IDF (Term Frequency - Inverse Document Frequency), we take into account both the frequency of the word in the text and the relative frequency within different texts.

# %%
print("Wait, bags of words are being created!!\n")
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the function that will compute the frequencies for all words
vectorizer = TfidfVectorizer(analyzer = "word", tokenizer = None, preprocessor = None, stop_words = None, max_features = 5000) 

# Use the fit_transform method to learn the vocabulary and then transform the training data into vectors
train_data_features = vectorizer.fit_transform(toy_data['processed'])

# Convert the result to an array
train_data_features = train_data_features.toarray()

# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

ex = pd.DataFrame(data = {'word': vocab, 'number of appearance': dist}).sort_values(by = 'number of appearance', 
                                                                                    ascending = False).head(40)

import seaborn as sns
sns.set_style("whitegrid")
ax = sns.barplot( x="number of appearance", y="word", data=ex)
plt.title('Frequency of words')
plt.show()
# Out:
# Wait, bags of words are being created!!

# %% [markdown]
# # Classification

# %%
labels = toy_data['sentiment']
# We split the data into train and test data. Here we keep 30% of the data for testing
data_train, data_test, labels_train, labels_test = train_test_split(train_data_features, 
                                                                    labels, test_size=0.3, 
                                                                    random_state=42)

# %% [markdown]
# #### Logistic Regression

# %%
start = time.time()
# Initialize the model
print('Initialize the model')
clf = LogisticRegression(C = 10)

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  0.5520172119140625
# Confusion matrix, without normalization
# [[426 397 441]
#  [385 420 415]
#  [402 370 491]]
#              precision    recall  f1-score   support
#
#    class -1       0.35      0.34      0.34      1264
#     class 0       0.35      0.34      0.35      1220
#     class 1       0.36      0.39      0.38      1263
#
# avg / total       0.36      0.36      0.36      3747
#
# The accuracy is:  0.356818788364

# %% [markdown]
# #### Random Forest

# %%
start = time.time()

# Initialize the model
print('Initialize the model')
clf = RandomForestClassifier(n_estimators = 30, class_weight="balanced")

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  17.939597368240356
# Confusion matrix, without normalization
# [[395 465 404]
#  [387 451 382]
#  [385 438 440]]
#              precision    recall  f1-score   support
#
#    class -1       0.34      0.31      0.32      1264
#     class 0       0.33      0.37      0.35      1220
#     class 1       0.36      0.35      0.35      1263
#
# avg / total       0.34      0.34      0.34      3747
#
# The accuracy is:  0.343207899653

# %% [markdown]
# #### Naive Bayes

# %%
start = time.time()
# Initialize the model
print('Initialize the model')
clf = GaussianNB()

# Fit the model to the train data
print("Wait, the model is being learned!")
y_score = clf.fit(data_train, labels_train).predict(data_test)

# Apply the model on test data
print('Using the model to make predictions')
labels_predicted = clf.predict(data_test)

print("Computation time: ", time.time() - start)

# Use the plotting function
cnf_matrix = confusion_matrix(labels_test, labels_predicted)
np.set_printoptions(precision=2)
class_names = sorted(toy_data.sentiment.unique())
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()

print(classification_report(labels_test, labels_predicted, target_names=target_names))
print("The accuracy is: ", np.sum(labels_predicted == labels_test) / len(labels_test))
# Out:
# Initialize the model
# Wait, the model is being learned!
# Using the model to make predictions
# Computation time:  2.2517433166503906
# Confusion matrix, without normalization
# [[167 177 920]
#  [179 215 826]
#  [138 160 965]]
#              precision    recall  f1-score   support
#
#    class -1       0.35      0.13      0.19      1264
#     class 0       0.39      0.18      0.24      1220
#     class 1       0.36      0.76      0.49      1263
#
# avg / total       0.36      0.36      0.31      3747
#
# The accuracy is:  0.359487590072

# %% [markdown]
# #### Remarks
#
# We remark that the features resulted from both count vectorizer and tf-idf vectorizer give approximately the same results. If the classification algorithms provide better results than a random guess ($33.33\%$ accuracy), the performance here is not very good, with a best accuracy of $30\%$ for the logistic regression.

# %% [markdown]
# # Strategy 2: Word Embedding

# %% [markdown]
# [Mikolov](https://scholar.google.com/citations?user=oBu8kMMAAAAJ) has contributed a lot in the field of [word embedding](https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) using deep learning. His first models skip-gram and CBOW have lead to lots of work to imrove the way we embed objects into vectors (including words, in our contexts).
#
# We will use the implementation of $Word2Vec$ from the package [Gensim](https://radimrehurek.com/gensim/).

# %% [markdown]
# ### Prepare the data for gensim $Word2Vec$ model

# %%
def process(x, remove_stopwords=False):
    '''
    Function to clear the html tags, then remove non-letters characters, 
    lowercase, remove stopwords, then join the resulting as a full text
    '''
    # Clean html tags
    review = BeautifulSoup(x, "html.parser").get_text() 
    # Remove non letters     
    letters = re.sub("[^a-zA-Z]", " ", review) 
    # Lowercase and split to words
    words = letters.lower().split()                             
    # It appears that searching in a set in Python is much more efficient than searching in a list
    stops = set(stopwords.words("english"))                  
    # Optionally remove stop words
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]

    return words 

import nltk.data
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# Function that splits reviews into sentences
def review_to_sentences(review, tokenizer, remove_stopwords=False ):
    '''Function to split a review into parsed sentences. Returns a 
    list of sentences, where each sentence is a list of words
    '''
    
    # Split into sentences
    raw_sentences = tokenizer.tokenize(review.strip())
    
    # Loop over each sentence
    sentences = []
    for raw_sentence in raw_sentences:
        # If a sentence is empty, skip it
        if len(raw_sentence) > 0:
            # Otherwise, call review_to_wordlist to get a list of words
            sentences.append(process(raw_sentence, remove_stopwords))
            
    # Return the list of sentences (each sentence is a list of words, so this returns a list of lists
    return sentences

# %%
# Apply the function to the whole toy dataset
start = time.time()

sentences = []  # Initialize an empty list of sentences

print("Parsing sentences from training set")
for review in toy_data["review"]:
    sentences += review_to_sentences(review, tokenizer)
      
print(time.time() - start)
# Out:
# Parsing sentences from training set
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You shouldprobably open this file and pass the filehandle intoBeautiful Soup.
#   'Beautiful Soup.' % markup)
# 22.63961362838745

# %% [markdown]
# ### Build the $Word2Vec$ model and save it
#
# We will embed words into $300$ dimensions vectors, with a context of size $10$. We only keep words which appear at least $40$ times.

# %%
start = time.time()
# The logging package enables to output messages during preparation

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)


# Set values for various parameters
num_features = 300    # Word vector dimensionality                      
min_word_count = 40   # Minimum word count                        
num_workers = 4       # Number of threads to run in parallel
context = 10          # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

# Initialize and train the model. This is the most costly in computation time!
from gensim.models import word2vec
print("Training model...")
model = word2vec.Word2Vec(sentences, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)

model.init_sims(replace=True)

# Save the model
model_name = "300features_40minwords_10context_toy_dataset"
model.save(model_name)

print(time.time() - start)
# Out:
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\gensim\utils.py:843: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# 2017-01-31 19:15:53,272 : INFO : 'pattern' package not found; tag filters are not available for English
# 2017-01-31 19:15:53,280 : INFO : collecting all words and their counts
# 2017-01-31 19:15:53,280 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-01-31 19:15:53,305 : INFO : PROGRESS: at sentence #10000, processed 121538 words, keeping 6061 word types
# 2017-01-31 19:15:53,336 : INFO : PROGRESS: at sentence #20000, processed 233415 words, keeping 8183 word types
# 2017-01-31 19:15:53,383 : INFO : PROGRESS: at sentence #30000, processed 372105 words, keeping 10485 word types
# 2017-01-31 19:15:53,383 : INFO : collected 10783 word types from a corpus of 415269 raw words and 35453 sentences
# 2017-01-31 19:15:53,383 : INFO : Loading a fresh vocabulary
# 2017-01-31 19:15:53,398 : INFO : min_count=40 retains 829 unique words (7% of original 10783, drops 9954)
# 2017-01-31 19:15:53,398 : INFO : min_count=40 leaves 372979 word corpus (89% of original 415269, drops 42290)
# 2017-01-31 19:15:53,398 : INFO : deleting the raw counts dictionary of 10783 items
# 2017-01-31 19:15:53,398 : INFO : sample=0.001 downsamples 72 most-common words
# 2017-01-31 19:15:53,414 : INFO : downsampling leaves estimated 238040 word corpus (63.8% of prior 372979)
# 2017-01-31 19:15:53,414 : INFO : estimated required memory for 829 words and 300 dimensions: 2404100 bytes
# 2017-01-31 19:15:53,414 : INFO : resetting layer weights
# 2017-01-31 19:15:53,430 : INFO : training model with 4 workers on 829 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-01-31 19:15:53,430 : INFO : expecting 35453 sentences, matching count from corpus used for vocabulary survey
# 2017-01-31 19:15:53,445 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,445 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,445 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# Training model...
# 2017-01-31 19:15:53,445 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,477 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,492 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,492 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,508 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,508 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,523 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,523 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,539 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,539 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,555 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,555 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,555 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,570 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,570 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,586 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,586 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,586 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,602 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,602 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,617 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,617 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,617 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,633 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,648 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,648 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,648 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,664 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,664 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,680 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,680 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,695 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,695 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,711 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,711 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,711 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,727 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,742 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,742 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,758 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,758 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,758 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,758 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,773 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,789 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,789 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,805 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,805 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,805 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,820 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,820 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,836 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,836 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,836 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,852 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,852 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,867 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,867 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,883 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,883 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,883 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,898 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,898 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,898 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,914 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,930 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,930 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,930 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,930 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,945 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,961 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,961 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,961 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,977 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,977 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,992 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,992 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:53,992 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,008 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,008 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,023 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,023 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,039 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,039 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,055 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,055 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,055 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,070 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,070 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,086 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,086 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,086 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,102 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,117 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,117 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,117 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,117 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,133 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,149 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,149 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,149 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,164 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,164 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,180 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,180 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,195 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,195 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,195 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,211 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,211 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,227 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,227 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,242 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,242 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,258 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,258 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,274 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,274 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,274 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,289 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,305 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,305 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,320 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,320 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,320 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,336 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,352 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,352 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,352 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,367 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,383 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,383 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,383 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,399 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,414 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,414 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,414 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,430 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,430 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,445 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,445 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,445 : INFO : PROGRESS: at 67.09% examples, 798861 words/s, in_qsize 7, out_qsize 0
# 2017-01-31 19:15:54,461 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,461 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,461 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,477 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,477 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,492 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,492 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,508 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,508 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,524 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,524 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,524 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,524 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,539 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,555 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,555 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,555 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,570 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,570 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,586 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,586 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,602 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,602 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,617 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,617 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,633 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,633 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,649 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,649 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,649 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,664 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,680 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,680 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,680 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,695 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,695 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,711 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,711 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,727 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,727 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,727 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,727 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,742 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,758 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,758 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,758 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,774 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,774 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,789 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,789 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,805 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,805 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,805 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,820 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,820 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,836 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,836 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,852 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,852 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,867 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,867 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,867 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,883 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,883 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# 2017-01-31 19:15:54,883 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-01-31 19:15:54,899 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-01-31 19:15:54,899 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-01-31 19:15:54,899 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-01-31 19:15:54,899 : INFO : training on 2076345 raw words (1189292 effective words) took 1.5s, 813706 effective words/s
# 2017-01-31 19:15:54,899 : INFO : precomputing L2-norms of word weight vectors
# 2017-01-31 19:15:54,914 : INFO : saving Word2Vec object under 300features_40minwords_10context_toy_dataset, separately None
# 2017-01-31 19:15:54,914 : WARNING : direct access to syn0norm will not be supported in future gensim releases, please use model.wv.syn0norm
# 2017-01-31 19:15:54,914 : WARNING : direct access to syn0norm will not be supported in future gensim releases, please use model.wv.syn0norm
# 2017-01-31 19:15:54,914 : WARNING : direct access to syn0norm will not be supported in future gensim releases, please use model.wv.syn0norm
# 2017-01-31 19:15:54,914 : INFO : not storing attribute syn0norm
# 2017-01-31 19:15:54,914 : INFO : not storing attribute cum_table
# 2017-01-31 19:15:54,945 : WARNING : direct access to syn0norm will not be supported in future gensim releases, please use model.wv.syn0norm
# 2017-01-31 19:15:54,945 : INFO : saved 300features_40minwords_10context_toy_dataset
# 1.957967758178711

# %% [markdown]
# ## Exploration of the model we created

# %%
from gensim.models import Word2Vec

model = Word2Vec.load("300features_40minwords_10context_toy_dataset")
# Out:
# 2017-01-31 19:17:44,426 : INFO : loading Word2Vec object from 300features_40minwords_10context_toy_dataset
# 2017-01-31 19:17:44,457 : INFO : loading wv recursively from 300features_40minwords_10context_toy_dataset.wv.* with mmap=None
# 2017-01-31 19:17:44,457 : INFO : setting ignored attribute syn0norm to None
# 2017-01-31 19:17:44,457 : WARNING : direct access to syn0norm will not be supported in future gensim releases, please use model.wv.syn0norm
# 2017-01-31 19:17:44,457 : INFO : setting ignored attribute cum_table to None
# 2017-01-31 19:17:44,457 : INFO : loaded 300features_40minwords_10context_toy_dataset
# 2017-01-31 19:17:44,457 : WARNING : direct access to index2word will not be supported in future gensim releases, please use model.wv.index2word

# %%
# Size of the matrice created
model.syn0.shape
# Out:
# 2017-01-31 19:17:47,996 : WARNING : direct access to syn0 will not be supported in future gensim releases, please use model.wv.syn0
# (829, 300)

# %%
# Example of a word vector
model['good']
# Out:
# array([  4.49e-02,  -3.40e-02,   4.34e-03,   1.76e-02,   7.91e-03,
#         -3.85e-02,  -6.25e-02,   7.30e-02,   1.60e-02,  -2.50e-02,
#          3.43e-02,  -1.39e-01,   6.43e-02,  -6.11e-02,  -3.02e-02,
#          2.63e-02,   6.03e-02,  -2.69e-02,   1.21e-01,  -7.09e-02,
#          3.37e-02,   4.03e-02,  -8.16e-03,  -3.15e-02,  -2.97e-03,
#          6.21e-02,  -2.62e-02,  -1.85e-02,  -6.91e-02,  -6.12e-02,
#         -3.36e-02,  -1.07e-02,   4.47e-02,  -3.12e-02,   3.35e-02,
#         -7.26e-03,  -1.09e-01,  -9.37e-02,  -1.39e-03,  -1.09e-01,
#          2.77e-02,   4.30e-02,  -2.28e-02,  -9.87e-02,   3.45e-03,
#          2.16e-02,   4.96e-02,   2.19e-03,   2.89e-02,   6.29e-03,
#          4.65e-02,  -1.72e-02,   1.01e-02,  -6.81e-02,  -4.11e-02,
#         -1.95e-04,  -4.56e-02,   6.54e-03,   4.32e-02,  -6.58e-02,
#          6.06e-02,   1.69e-02,  -3.67e-02,  -7.64e-03,  -4.47e-02,
#          7.56e-03,  -1.58e-01,   2.31e-02,   1.96e-02,  -5.40e-02,
#         -4.27e-02,   2.69e-02,  -1.56e-02,  -2.19e-03,  -1.58e-02,
#         -8.12e-02,   6.00e-02,   5.79e-02,  -1.72e-02,  -2.25e-03,
#         -3.02e-02,  -6.46e-02,  -3.74e-02,  -6.01e-02,  -8.54e-02,
#         -6.84e-02,  -4.55e-02,   1.50e-04,  -2.28e-02,  -1.22e-02,
#         -9.00e-04,   2.06e-02,   7.27e-02,   1.19e-01,   3.88e-02,
#          3.28e-02,  -9.34e-03,   2.17e-04,  -1.04e-01,  -1.21e-01,
#          7.30e-02,  -3.61e-02,  -6.55e-02,  -7.33e-02,   9.55e-02,
#         -2.84e-02,   2.48e-02,   4.76e-02,  -6.48e-02,   4.18e-02,
#         -1.10e-02,  -5.49e-02,   1.84e-02,  -2.88e-02,   2.45e-02,
#          6.18e-02,  -1.71e-03,  -1.88e-02,  -5.97e-02,   1.17e-01,
#         -4.64e-02,  -2.55e-02,  -4.76e-02,   5.76e-03,  -9.39e-03,
#         -1.06e-03,  -3.15e-02,  -1.23e-02,   3.17e-02,   2.58e-02,
#          7.79e-02,  -2.85e-02,   3.49e-02,   2.10e-02,  -2.79e-02,
#         -1.34e-01,  -1.19e-01,  -1.49e-02,  -3.24e-02,   2.86e-02,
#          1.16e-01,   2.91e-02,  -2.33e-02,  -1.85e-02,   1.95e-02,
#         -8.31e-02,  -2.34e-02,  -3.90e-02,   2.91e-02,  -9.95e-02,
#         -4.02e-02,  -1.02e-02,  -2.45e-02,  -1.20e-01,   1.67e-02,
#          2.97e-02,  -1.64e-02,   9.90e-02,  -8.58e-02,   3.32e-02,
#         -1.03e-01,   1.21e-02,  -6.46e-02,  -5.20e-02,   2.36e-02,
#          7.24e-02,  -9.05e-02,   5.80e-02,  -5.59e-03,   3.17e-02,
#         -1.99e-03,   9.03e-02,  -3.22e-02,  -1.09e-01,   7.63e-03,
#         -6.31e-02,   7.86e-02,  -2.37e-02,   3.26e-02,  -4.20e-02,
#          8.56e-02,   1.07e-03,   3.30e-02,   6.80e-02,  -5.29e-03,
#         -6.58e-02,  -5.74e-02,   1.03e-01,   3.82e-02,   4.66e-03,
#          6.36e-02,   1.10e-01,   3.58e-02,   3.73e-02,   4.53e-02,
#         -2.71e-02,   2.82e-02,   4.03e-02,   4.47e-02,   3.78e-02,
#         -3.27e-02,  -6.88e-02,   5.79e-02,  -1.72e-02,   1.12e-02,
#         -3.08e-03,  -8.05e-02,  -5.46e-02,  -6.76e-02,  -9.14e-02,
#         -2.25e-02,  -3.12e-02,  -9.41e-02,   8.56e-02,  -7.43e-02,
#          5.85e-02,   6.44e-02,   2.59e-02,   6.85e-02,  -2.01e-02,
#          2.91e-02,   5.73e-03,  -2.68e-02,  -6.44e-02,  -5.88e-02,
#          3.56e-02,   5.63e-02,  -7.24e-02,  -3.44e-02,   9.71e-02,
#          2.84e-02,   6.35e-02,  -2.00e-02,  -5.40e-02,  -1.34e-01,
#         -3.01e-02,  -4.53e-02,   2.64e-02,  -1.26e-02,  -1.29e-01,
#         -2.28e-02,   1.05e-01,  -8.67e-02,   3.10e-02,   4.22e-02,
#         -1.23e-02,  -4.12e-02,  -7.34e-02,  -4.79e-02,   3.26e-02,
#          1.34e-01,   5.45e-02,  -5.59e-03,   7.07e-02,  -8.08e-02,
#          2.50e-02,   4.86e-03,  -1.93e-02,   5.01e-02,  -8.68e-02,
#          3.54e-03,  -6.76e-02,  -1.26e-01,  -1.74e-02,   1.12e-02,
#         -1.57e-02,   1.26e-01,   4.80e-02,   9.27e-02,   6.27e-03,
#          1.40e-03,   3.50e-02,  -1.19e-01,  -4.23e-02,  -1.26e-01,
#         -1.40e-01,   4.36e-02,   7.94e-02,   2.60e-02,   2.39e-02,
#          1.01e-01,  -5.46e-03,   1.07e-02,  -4.62e-04,   1.68e-02,
#         -1.43e-01,  -7.11e-02,   8.62e-02,  -4.04e-02,   1.43e-02,
#         -1.03e-02,  -7.48e-03,   4.07e-02,  -5.31e-02,  -9.43e-02,
#          8.74e-03,   4.29e-02,  -6.19e-02,  -6.91e-02,   1.32e-02], dtype=float32)

# %%
# Example of word similarity
model.most_similar('have')
# Out:
# [('ve', 0.7183361649513245),
#  ('write', 0.6847274899482727),
#  ('give', 0.6723474264144897),
#  ('wish', 0.6674484610557556),
#  ('since', 0.6264169812202454),
#  ('believe', 0.6131330132484436),
#  ('maybe', 0.6113722920417786),
#  ('buy', 0.5961000323295593),
#  ('ever', 0.5937027335166931),
#  ('be', 0.5813376903533936)]

# %%
model.most_similar('good')
# Out:
# [('great', 0.8403876423835754),
#  ('fun', 0.7632432579994202),
#  ('enjoyable', 0.7503557205200195),
#  ('satisfying', 0.7136569619178772),
#  ('decent', 0.6831263899803162),
#  ('entertaining', 0.6738607883453369),
#  ('compelling', 0.6595152020454407),
#  ('fantastic', 0.653302788734436),
#  ('nice', 0.6375294923782349),
#  ('quick', 0.6347706317901611)]

# %%
# Distinguished the most distant word between several words
print(model.doesnt_match("man woman child dog".split()))

print(model.doesnt_match("amazing wonderful great window".split()))
# Out:
# man
# window

# %% [markdown]
# Here, we see that the word embeddings seem not to be very good. This is due to the fact that we have trained the $Word2Vec$ model on a too small dataset. We will come back to this in a second part with the whole dataset.

# %% [markdown]
# #### Once we have word vectors, how can we create features for reviews?
# #### One possibility is to average all the word vectors from the review

# %%
def makeFeatureVec(words, model, num_features):
    ''' 
    Function to average all the word vectors in a given review
    '''
    # Initialize an empty array
    featureVec = np.zeros((num_features,),dtype="float32")
    
    nwords = 0.
    
    # Index2word is a list that contains the names of the words in the model's vocabulary. Convert it to a set, for speed (juyst as we did before)
    index2word_set = set(model.wv.index2word)
    
    # Loop over each word in the review and, if it is in the model's vocabulary, add its feature vector to the total
    for word in words:
        if word in index2word_set: 
            nwords = nwords + 1.
            featureVec = np.add(featureVec,model[word])
    
    # Divide the result by the number of words to get the average
    featureVec = np.divide(featureVec,nwords)
    
    return featureVec


def getAvgFeatureVecs(reviews, model, num_features):
    ''' 
    Given a set of reviews (each one a list of words), compute 
    the average feature vector for each one and return an array
    '''
    # Initialize a counter
    counter = 0
    
    # Preallocate a 2D numpy array, for speed
    reviewFeatureVecs = np.zeros((len(reviews),num_features),dtype="float32")
    
    # Loop through the reviews
    for review in reviews:
        
        # Print a status message every 1000th review
        if counter%1000. == 0.:
            print("Review %d of %d" % (counter, len(reviews)))
        
        # Call the function (defined above) that makes average feature vectors
        reviewFeatureVecs[counter] = makeFeatureVec(review, model, num_features)
        
        # Increment the counter
        counter = counter + 1
    return reviewFeatureVecs

# %%
# Compute the average feature vectors, using the functions we defined above.
start = time.time()
print("Creating average feature vecs for train reviews")

clean_train_reviews = []
for review in list(toy_data["review"]):
    clean_train_reviews.append(process(review, remove_stopwords=True))
print('reviews cleaned')
trainDataVecs = getAvgFeatureVecs(clean_train_reviews, model, num_features)

print(time.time() - start)
# Out:
# Creating average feature vecs for train reviews
# reviews cleaned
# Review 0 of 12489
# Review 1000 of 12489
# Review 2000 of 12489
# C:\Users\Peter martigny\Anaconda3\envs\py35\lib\site-packages\ipykernel\__main__.py:20: RuntimeWarning: invalid value encountered in true_divide
# Review 3000 of 12489
# Review 4000 of 12489
# Review 5000 of 12489
# Review 6000 of 12489
# Review 7000 of 12489
# Review 8000 of 12489
# Review 9000 of 12489
# Review 10000 of 12489
# Review 11000 of 12489
# Review 12000 of 12489
# 15.272671937942505
